# %%
import vtk
import os
import numpy as np
import itertools
import math, random
import data_process_ml
random.seed = 42
import copy

import torch
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
from torchvision import transforms, utils

import scipy.spatial.distance
# import plotly.graph_objects as go
# import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
device = "cuda"

# %% [markdown]
# load the dataset

# %%
root = "..\..\msc_data\models-v1.0\models"
IA = "aneurysms\\remeshed\\area-001"
Vessel = "vessels\\remeshed\\area-001"
IA_root = os.path.join(root,IA)
Vessel_root = os.path.join(root,Vessel)
list1 = os.listdir(Vessel_root)
list2 = os.listdir(IA_root)

# %%
morpho_path = ".\AneuX\data-v1.0\data\morpho-per-cut.csv"
patient_path = ".\AneuX\data-v1.0\data\clinical.csv"
morpho_data_patient = data_process_ml.read_and_combine_data(morpho_path,patient_path)
merged_dataset = data_process_ml.encode_column(morpho_data_patient)
merged_dataset = data_process_ml.drop_columns(merged_dataset)
morpho_data_cut1,morpho_data_dome = data_process_ml.output_cut1anddome(merged_dataset)
# Out:
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_dome.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)

# %%
import pandas as pd
from pointnetfunct.PointNet_dataset import Aneux_Dataset_load
df = pd.DataFrame()
# Aneux_Dataset = Aneuxmodel_Dataset(root = root,
#                                    df=morpho_data_patient[morpho_data_patient["cuttype"] == "dome"],
#                                    transform = transforms.ToTensor(),
#                                    mesh = "area-001",
#                                    cuttype = "dome",
#                                    crop = False)

Aneux_Dataset = Aneux_Dataset_load('./Aneux_Dataset_1000pt_sample_600train.pt')
Aneux_Dataset_test = Aneux_Dataset_load('./Aneux_Dataset_1000pt_sample_100test.pt')
Aneux_Dataset.paraout = True
Aneux_Dataset.cuttype = "cut1"
Aneux_Dataset_test.cuttype = "cut1"
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_dome.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_dome.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)

# %%
from torch.utils.data import Subset

seed = torch.seed()
print(seed)
torch.manual_seed(32381912834800)
#12984260249700
#16912914325100

train_size = int(len(Aneux_Dataset) * 0.8) # 80% training data
valid_size = len(Aneux_Dataset) - train_size
train_data, valid_data = random_split(Aneux_Dataset, [train_size, valid_size])

train_loader = torch.utils.data.DataLoader(
    train_data,
    batch_size=50,
    shuffle=True,
    #num_workers=2, 
    pin_memory=True
)

valid_loader = torch.utils.data.DataLoader(
    valid_data,
    batch_size=50, # Forward pass only so batch size can be larger
    shuffle=False,
    #num_workers=2, 
    pin_memory=True
)

test_loader = torch.utils.data.DataLoader(
    Aneux_Dataset_test,
    batch_size=50, # Forward pass only so batch size can be larger
    shuffle=False,
    #num_workers=2, 
    pin_memory=True
)
# Out:
# 46110236855500

# %% [markdown]
# Test vaildation

# %% [markdown]
# # PointNet model

# %%
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torch import optim
from pointnetfunct.PointNet_struct import Tnet,Transform,PointNet,PointNet_2Multihead,PointNet_3Multihead

# %% [markdown]
# Run model

# %%
import functions
from pointnetfunct.PointNet_trainingfunct import run_model_get, load_model

pointnet = PointNet(classes=2)
run_model_get(train_loader_input = train_loader,
                        vaild_loader_input = valid_loader,
                        nepochs = 100, 
                        modelnet = pointnet,
                        results_path = "./result", 
                        filename = "/dome_1000pt_unform_test.pt",
                        model_name= "pointnet_dome_unform_1000pt_test.pth")
pointnet.to("cpu")
# Out:
# epoch: 0 training loss:  0.693 training accuracy:  57.5%  test loss:  0.703 test accuracy:  62.2%
# epoch: 1 training loss:  0.701 training accuracy:  65.2%  test loss:  0.716 test accuracy:  64.6%
# epoch: 2 training loss:  0.708 training accuracy:  65.9%  test loss:  0.733 test accuracy:  62.2%
# epoch: 3 training loss:  0.676 training accuracy:  67.7%  test loss:  0.642 test accuracy:  68.5%
# epoch: 4 training loss:  0.700 training accuracy:  68.5%  test loss:  0.691 test accuracy:  63.8%
# epoch: 5 training loss:  0.682 training accuracy:  67.3%  test loss:  0.677 test accuracy:  65.4%
# epoch: 6 training loss:  0.688 training accuracy:  65.4%  test loss:  0.649 test accuracy:  70.1%
# epoch: 7 training loss:  0.709 training accuracy:  64.4%  test loss:  0.660 test accuracy:  68.5%
# epoch: 8 training loss:  0.669 training accuracy:  66.3%  test loss:  0.659 test accuracy:  68.5%
# epoch: 9 training loss:  0.699 training accuracy:  65.6%  test loss:  0.645 test accuracy:  69.3%
# epoch: 10 training loss:  0.683 training accuracy:  67.1%  test loss:  0.658 test accuracy:  69.3%
# epoch: 11 training loss:  0.692 training accuracy:  66.5%  test loss:  0.658 test accuracy:  66.1%
# epoch: 12 training loss:  0.672 training accuracy:  67.3%  test loss:  0.663 test accuracy:  67.7%
# epoch: 13 training loss:  0.700 training accuracy:  65.7%  test loss:  0.675 test accuracy:  67.7%
# epoch: 14 training loss:  0.659 training accuracy:  67.7%  test loss:  0.687 test accuracy:  68.5%
# epoch: 15 training loss:  0.692 training accuracy:  67.7%  test loss:  0.659 test accuracy:  69.3%
# epoch: 16 training loss:  0.671 training accuracy:  64.0%  test loss:  0.667 test accuracy:  66.1%
# epoch: 17 training loss:  0.656 training accuracy:  67.7%  test loss:  0.679 test accuracy:  68.5%
# epoch: 18 training loss:  0.690 training accuracy:  66.7%  test loss:  0.693 test accuracy:  67.7%
# epoch: 19 training loss:  0.677 training accuracy:  66.1%  test loss:  0.649 test accuracy:  68.5%
# epoch: 20 training loss:  0.692 training accuracy:  67.7%  test loss:  0.650 test accuracy:  67.7%
# epoch: 21 training loss:  0.681 training accuracy:  65.2%  test loss:  0.682 test accuracy:  69.3%
# epoch: 22 training loss:  0.681 training accuracy:  67.7%  test loss:  0.671 test accuracy:  66.1%
# epoch: 23 training loss:  0.691 training accuracy:  66.3%  test loss:  0.650 test accuracy:  70.1%
# epoch: 24 training loss:  0.688 training accuracy:  68.5%  test loss:  0.663 test accuracy:  66.1%
# epoch: 25 training loss:  0.656 training accuracy:  67.9%  test loss:  0.670 test accuracy:  69.3%
# epoch: 26 training loss:  0.687 training accuracy:  67.3%  test loss:  0.668 test accuracy:  66.9%
# epoch: 27 training loss:  0.697 training accuracy:  64.2%  test loss:  0.668 test accuracy:  64.6%
# epoch: 28 training loss:  0.689 training accuracy:  66.7%  test loss:  0.667 test accuracy:  69.3%
# epoch: 29 training loss:  0.666 training accuracy:  66.3%  test loss:  0.664 test accuracy:  70.1%
# epoch: 30 training loss:  0.680 training accuracy:  65.6%  test loss:  0.667 test accuracy:  66.1%
# epoch: 31 training loss:  0.681 training accuracy:  66.5%  test loss:  0.660 test accuracy:  70.1%
# epoch: 32 training loss:  0.674 training accuracy:  65.6%  test loss:  0.687 test accuracy:  66.1%
# epoch: 33 training loss:  0.675 training accuracy:  66.7%  test loss:  0.651 test accuracy:  70.1%
# epoch: 34 training loss:  0.684 training accuracy:  67.1%  test loss:  0.672 test accuracy:  67.7%
# epoch: 35 training loss:  0.683 training accuracy:  65.7%  test loss:  0.672 test accuracy:  66.9%
# epoch: 36 training loss:  0.693 training accuracy:  66.3%  test loss:  0.698 test accuracy:  64.6%
# epoch: 37 training loss:  0.681 training accuracy:  67.7%  test loss:  0.640 test accuracy:  68.5%
# epoch: 38 training loss:  0.699 training accuracy:  66.5%  test loss:  0.706 test accuracy:  64.6%
# epoch: 39 training loss:  0.674 training accuracy:  67.5%  test loss:  0.675 test accuracy:  68.5%
# epoch: 40 training loss:  0.691 training accuracy:  65.9%  test loss:  0.692 test accuracy:  70.1%
# epoch: 41 training loss:  0.668 training accuracy:  68.3%  test loss:  0.666 test accuracy:  69.3%
# epoch: 42 training loss:  0.687 training accuracy:  67.7%  test loss:  0.641 test accuracy:  70.1%
# epoch: 43 training loss:  0.671 training accuracy:  66.9%  test loss:  0.651 test accuracy:  73.2%
# epoch: 44 training loss:  0.691 training accuracy:  66.9%  test loss:  0.674 test accuracy:  67.7%
# epoch: 45 training loss:  0.661 training accuracy:  65.7%  test loss:  0.679 test accuracy:  68.5%
# epoch: 46 training loss:  0.653 training accuracy:  68.5%  test loss:  0.654 test accuracy:  70.1%
# epoch: 47 training loss:  0.684 training accuracy:  68.3%  test loss:  0.645 test accuracy:  69.3%
# epoch: 48 training loss:  0.670 training accuracy:  67.1%  test loss:  0.662 test accuracy:  70.1%
# epoch: 49 training loss:  0.663 training accuracy:  67.3%  test loss:  0.652 test accuracy:  71.7%
# epoch: 50 training loss:  0.686 training accuracy:  68.5%  test loss:  0.681 test accuracy:  67.7%
# epoch: 51 training loss:  0.681 training accuracy:  66.3%  test loss:  0.675 test accuracy:  69.3%
# epoch: 52 training loss:  0.701 training accuracy:  66.5%  test loss:  0.678 test accuracy:  67.7%
# epoch: 53 training loss:  0.683 training accuracy:  66.7%  test loss:  0.644 test accuracy:  70.1%
# epoch: 54 training loss:  0.662 training accuracy:  67.1%  test loss:  0.679 test accuracy:  68.5%
# epoch: 55 training loss:  0.667 training accuracy:  66.5%  test loss:  0.662 test accuracy:  66.9%
# epoch: 56 training loss:  0.663 training accuracy:  67.1%  test loss:  0.674 test accuracy:  68.5%
# epoch: 57 training loss:  0.672 training accuracy:  66.9%  test loss:  0.640 test accuracy:  66.1%
# epoch: 58 training loss:  0.670 training accuracy:  67.1%  test loss:  0.663 test accuracy:  67.7%
# epoch: 59 training loss:  0.685 training accuracy:  65.7%  test loss:  0.662 test accuracy:  69.3%
# epoch: 60 training loss:  0.652 training accuracy:  67.9%  test loss:  0.682 test accuracy:  68.5%
# epoch: 61 training loss:  0.676 training accuracy:  68.3%  test loss:  0.680 test accuracy:  68.5%
# epoch: 62 training loss:  0.667 training accuracy:  66.9%  test loss:  0.653 test accuracy:  66.1%
# epoch: 63 training loss:  0.666 training accuracy:  69.9%  test loss:  0.671 test accuracy:  68.5%
# epoch: 64 training loss:  0.689 training accuracy:  67.3%  test loss:  0.681 test accuracy:  63.8%
# epoch: 65 training loss:  0.671 training accuracy:  68.5%  test loss:  0.663 test accuracy:  65.4%
# epoch: 66 training loss:  0.651 training accuracy:  66.7%  test loss:  0.658 test accuracy:  63.8%
# epoch: 67 training loss:  0.655 training accuracy:  67.3%  test loss:  0.681 test accuracy:  64.6%
# epoch: 68 training loss:  0.686 training accuracy:  66.9%  test loss:  0.680 test accuracy:  63.0%
# epoch: 69 training loss:  0.658 training accuracy:  67.9%  test loss:  0.659 test accuracy:  63.8%
# epoch: 70 training loss:  0.680 training accuracy:  67.5%  test loss:  0.649 test accuracy:  67.7%
# epoch: 71 training loss:  0.681 training accuracy:  68.1%  test loss:  0.657 test accuracy:  66.9%
# epoch: 72 training loss:  0.666 training accuracy:  67.3%  test loss:  0.657 test accuracy:  67.7%
# epoch: 73 training loss:  0.673 training accuracy:  67.5%  test loss:  0.677 test accuracy:  66.1%
# epoch: 74 training loss:  0.659 training accuracy:  66.9%  test loss:  0.640 test accuracy:  68.5%
# epoch: 75 training loss:  0.662 training accuracy:  67.3%  test loss:  0.637 test accuracy:  67.7%
# epoch: 76 training loss:  0.659 training accuracy:  67.7%  test loss:  0.649 test accuracy:  66.9%
# epoch: 77 training loss:  0.666 training accuracy:  68.7%  test loss:  0.657 test accuracy:  69.3%
# epoch: 78 training loss:  0.672 training accuracy:  68.3%  test loss:  0.677 test accuracy:  64.6%
# epoch: 79 training loss:  0.673 training accuracy:  66.5%  test loss:  0.673 test accuracy:  68.5%
# epoch: 80 training loss:  0.668 training accuracy:  67.3%  test loss:  0.628 test accuracy:  66.9%
# epoch: 81 training loss:  0.666 training accuracy:  67.1%  test loss:  0.678 test accuracy:  64.6%
# epoch: 82 training loss:  0.643 training accuracy:  66.3%  test loss:  0.662 test accuracy:  66.1%
# epoch: 83 training loss:  0.664 training accuracy:  67.5%  test loss:  0.654 test accuracy:  64.6%
# epoch: 84 training loss:  0.671 training accuracy:  66.3%  test loss:  0.645 test accuracy:  66.9%
# epoch: 85 training loss:  0.666 training accuracy:  69.7%  test loss:  0.656 test accuracy:  66.9%
# epoch: 86 training loss:  0.664 training accuracy:  69.3%  test loss:  0.657 test accuracy:  65.4%
# epoch: 87 training loss:  0.661 training accuracy:  68.1%  test loss:  0.681 test accuracy:  66.1%
# epoch: 88 training loss:  0.678 training accuracy:  67.1%  test loss:  0.648 test accuracy:  66.1%
# epoch: 89 training loss:  0.662 training accuracy:  67.9%  test loss:  0.674 test accuracy:  65.4%
# epoch: 90 training loss:  0.674 training accuracy:  66.7%  test loss:  0.673 test accuracy:  63.0%
# epoch: 91 training loss:  0.670 training accuracy:  67.3%  test loss:  0.698 test accuracy:  63.8%
# epoch: 92 training loss:  0.680 training accuracy:  68.9%  test loss:  0.672 test accuracy:  65.4%
# epoch: 93 training loss:  0.649 training accuracy:  69.7%  test loss:  0.676 test accuracy:  63.8%
# epoch: 94 training loss:  0.684 training accuracy:  69.3%  test loss:  0.654 test accuracy:  63.0%
# epoch: 95 training loss:  0.678 training accuracy:  66.9%  test loss:  0.676 test accuracy:  64.6%
# epoch: 96 training loss:  0.645 training accuracy:  69.3%  test loss:  0.671 test accuracy:  65.4%
# epoch: 97 training loss:  0.684 training accuracy:  67.9%  test loss:  0.688 test accuracy:  66.9%
# epoch: 98 training loss:  0.674 training accuracy:  67.1%  test loss:  0.665 test accuracy:  65.4%
# epoch: 99 training loss:  0.656 training accuracy:  68.7%  test loss:  0.670 test accuracy:  66.1%
# PointNet(
#   (transform): Transform(
#     (input_transform): Tnet(
#       (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=9, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (feature_transform): Tnet(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=4096, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=3, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=64, bias=True)
#     (fc4): Linear(in_features=64, out_features=128, bias=True)
#     (fc5): Linear(in_features=128, out_features=1024, bias=True)
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=2, bias=True)
#   (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (logsoftmax): LogSoftmax(dim=1)
#   (loss_fn): CrossEntropyLoss()
# )

# %%
def show_graph(path,device):
    data = torch.load(path, map_location=device) # by doing map_location=device, you can use trained model on GPU --> to test on CPU
    statsrec = data["stats"]
    fig, ax1 = plt.subplots()
    plt.plot(statsrec[0], 'r', label = 'training loss', )
    plt.plot(statsrec[2], 'g', label = 'test loss' )
    plt.legend(loc='lower right')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training and test loss, and test accuracy')
    ax2=ax1.twinx()
    ax2.plot(statsrec[1], 'm', label = 'training accuracy')
    ax2.plot(statsrec[3], 'b', label = 'test accuracy')
    ax2.set_ylabel('accuracy')
    plt.legend(loc='upper right')
    fig.savefig("roc.svg")
    plt.show()

# %%
device = torch.device('cuda:0')
show_graph(path ="./result/dome_1000pt_unform_test.pt",device = "cuda")

# %%
model_path = "pointnet_dome_test.pth"
torch.save(pointnet.state_dict(), model_path)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import functions as fun
pointnet_copy = PointNet(classes=2)
model_path = "./pointnet_dome_unform_1000pt_test.pth"
load_model(pointnet_copy,model_path)
y_true = []
y_pred = []
y_pred_result = []
y_probs = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,_,_,labels in test_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels)
        y_probs.extend(outputs)

# %%
from pointnetfunct.evaluation import show_cm_dl,show_graph,print_values,draw_rocgraph

draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_pointnet_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_pointnet_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.49
# F1 score: 0.19047619047619047
# Rupture Recall: 0.13636363636363635
# Rupture Precision: 0.3157894736842105
# UnRupture Recall: 0.7678571428571429
# UnRupture Precision: 0.5308641975308642

# %%
y_true = []
y_pred = []
y_pred_result = []
y_probs = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,_,_,labels in valid_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels)
        y_probs.extend(outputs)

# %%
draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_pointnet_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_pointnet_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.6771653543307087
# F1 score: 0.2807017543859649
# Rupture Recall: 0.2
# Rupture Precision: 0.47058823529411764
# UnRupture Recall: 0.896551724137931
# UnRupture Precision: 0.7090909090909091

# %% [markdown]
# Multi head

# %% [markdown]
# 2 multihead

# %%
import functions
from pointnetfunct.PointNet_struct import PointNet_2Multimodal_withDNN
from pointnetfunct.PointNet_trainingfunct import run_model_2multi_head_dnn
pointnet_mh = PointNet_2Multimodal_withDNN(classes=2)
run_model_2multi_head_dnn(train_loader_input = train_loader,
                        vaild_loader_input = valid_loader,
                        nepochs = 100, 
                        modelnet = pointnet_mh,
                        results_path = "./result", 
                        filename = "/2multimodel_uniform_1000pt_test.pt",
                        model_name= "pointnet_2multimodal_uniform_1000pt_test.pth")
# Out:
# epoch: 0 training loss:  0.737 training accuracy:  54.9%  test loss:  0.651 test accuracy:  66.1%
# epoch: 1 training loss:  0.676 training accuracy:  66.1%  test loss:  0.703 test accuracy:  64.6%
# epoch: 2 training loss:  0.642 training accuracy:  66.1%  test loss:  0.639 test accuracy:  70.1%
# epoch: 3 training loss:  0.659 training accuracy:  67.7%  test loss:  0.609 test accuracy:  70.9%
# epoch: 4 training loss:  0.641 training accuracy:  70.9%  test loss:  0.642 test accuracy:  70.9%
# epoch: 5 training loss:  0.659 training accuracy:  68.7%  test loss:  0.660 test accuracy:  70.1%
# epoch: 6 training loss:  0.624 training accuracy:  68.9%  test loss:  0.586 test accuracy:  74.0%
# epoch: 7 training loss:  0.625 training accuracy:  68.1%  test loss:  0.579 test accuracy:  73.2%
# epoch: 8 training loss:  0.607 training accuracy:  70.1%  test loss:  0.609 test accuracy:  74.0%
# epoch: 9 training loss:  0.607 training accuracy:  69.9%  test loss:  0.559 test accuracy:  77.2%
# epoch: 10 training loss:  0.582 training accuracy:  72.4%  test loss:  0.529 test accuracy:  76.4%
# epoch: 11 training loss:  0.574 training accuracy:  71.5%  test loss:  0.589 test accuracy:  78.0%
# epoch: 12 training loss:  0.609 training accuracy:  71.7%  test loss:  0.569 test accuracy:  74.8%
# epoch: 13 training loss:  0.616 training accuracy:  71.9%  test loss:  0.604 test accuracy:  76.4%
# epoch: 14 training loss:  0.613 training accuracy:  70.1%  test loss:  0.579 test accuracy:  75.6%
# epoch: 15 training loss:  0.565 training accuracy:  71.5%  test loss:  0.544 test accuracy:  78.0%
# epoch: 16 training loss:  0.573 training accuracy:  72.8%  test loss:  0.549 test accuracy:  74.8%
# epoch: 17 training loss:  0.587 training accuracy:  73.2%  test loss:  0.530 test accuracy:  75.6%
# epoch: 18 training loss:  0.558 training accuracy:  72.8%  test loss:  0.545 test accuracy:  78.0%
# epoch: 19 training loss:  0.594 training accuracy:  70.7%  test loss:  0.548 test accuracy:  74.0%
# epoch: 20 training loss:  0.555 training accuracy:  71.9%  test loss:  0.607 test accuracy:  78.7%
# epoch: 21 training loss:  0.551 training accuracy:  71.9%  test loss:  0.539 test accuracy:  76.4%
# epoch: 22 training loss:  0.575 training accuracy:  72.8%  test loss:  0.526 test accuracy:  78.0%
# epoch: 23 training loss:  0.568 training accuracy:  72.4%  test loss:  0.517 test accuracy:  78.7%
# epoch: 24 training loss:  0.613 training accuracy:  73.8%  test loss:  0.531 test accuracy:  72.4%
# epoch: 25 training loss:  0.580 training accuracy:  72.6%  test loss:  0.534 test accuracy:  80.3%
# epoch: 26 training loss:  0.546 training accuracy:  73.4%  test loss:  0.536 test accuracy:  79.5%
# epoch: 27 training loss:  0.639 training accuracy:  71.1%  test loss:  0.515 test accuracy:  78.0%
# epoch: 28 training loss:  0.591 training accuracy:  72.8%  test loss:  0.524 test accuracy:  76.4%
# epoch: 29 training loss:  0.557 training accuracy:  74.2%  test loss:  0.572 test accuracy:  78.7%
# epoch: 30 training loss:  0.624 training accuracy:  73.6%  test loss:  0.581 test accuracy:  74.0%
# epoch: 31 training loss:  0.566 training accuracy:  74.0%  test loss:  0.561 test accuracy:  79.5%
# epoch: 32 training loss:  0.589 training accuracy:  74.2%  test loss:  0.523 test accuracy:  77.2%
# epoch: 33 training loss:  0.573 training accuracy:  73.4%  test loss:  0.534 test accuracy:  77.2%
# epoch: 34 training loss:  0.573 training accuracy:  69.9%  test loss:  0.520 test accuracy:  75.6%
# epoch: 35 training loss:  0.586 training accuracy:  72.2%  test loss:  0.538 test accuracy:  78.7%
# epoch: 36 training loss:  0.579 training accuracy:  71.3%  test loss:  0.532 test accuracy:  80.3%
# epoch: 37 training loss:  0.624 training accuracy:  69.9%  test loss:  0.516 test accuracy:  75.6%
# epoch: 38 training loss:  0.581 training accuracy:  72.6%  test loss:  0.543 test accuracy:  74.8%
# epoch: 39 training loss:  0.561 training accuracy:  75.6%  test loss:  0.512 test accuracy:  78.7%
# epoch: 40 training loss:  0.604 training accuracy:  69.1%  test loss:  0.531 test accuracy:  75.6%
# epoch: 41 training loss:  0.579 training accuracy:  73.0%  test loss:  0.537 test accuracy:  78.0%
# epoch: 42 training loss:  0.559 training accuracy:  72.0%  test loss:  0.548 test accuracy:  75.6%
# epoch: 43 training loss:  0.553 training accuracy:  75.2%  test loss:  0.524 test accuracy:  76.4%
# epoch: 44 training loss:  0.593 training accuracy:  71.3%  test loss:  0.550 test accuracy:  73.2%
# epoch: 45 training loss:  0.554 training accuracy:  72.2%  test loss:  0.540 test accuracy:  77.2%
# epoch: 46 training loss:  0.552 training accuracy:  73.2%  test loss:  0.529 test accuracy:  77.2%
# epoch: 47 training loss:  0.559 training accuracy:  72.4%  test loss:  0.501 test accuracy:  77.2%
# epoch: 48 training loss:  0.588 training accuracy:  73.2%  test loss:  0.484 test accuracy:  79.5%
# epoch: 49 training loss:  0.548 training accuracy:  73.8%  test loss:  0.511 test accuracy:  80.3%
# epoch: 50 training loss:  0.594 training accuracy:  73.4%  test loss:  0.541 test accuracy:  76.4%
# epoch: 51 training loss:  0.574 training accuracy:  71.7%  test loss:  0.548 test accuracy:  74.0%
# epoch: 52 training loss:  0.585 training accuracy:  70.3%  test loss:  0.513 test accuracy:  75.6%
# epoch: 53 training loss:  0.590 training accuracy:  71.5%  test loss:  0.535 test accuracy:  74.0%
# epoch: 54 training loss:  0.547 training accuracy:  72.2%  test loss:  0.572 test accuracy:  74.8%
# epoch: 55 training loss:  0.566 training accuracy:  75.0%  test loss:  0.497 test accuracy:  78.7%
# epoch: 56 training loss:  0.577 training accuracy:  71.3%  test loss:  0.528 test accuracy:  78.0%
# epoch: 57 training loss:  0.545 training accuracy:  72.2%  test loss:  0.512 test accuracy:  76.4%
# epoch: 58 training loss:  0.596 training accuracy:  73.2%  test loss:  0.499 test accuracy:  78.0%
# epoch: 59 training loss:  0.576 training accuracy:  70.7%  test loss:  0.552 test accuracy:  78.0%
# epoch: 60 training loss:  0.568 training accuracy:  73.2%  test loss:  0.515 test accuracy:  78.0%
# epoch: 61 training loss:  0.560 training accuracy:  73.2%  test loss:  0.518 test accuracy:  81.9%
# epoch: 62 training loss:  0.541 training accuracy:  75.2%  test loss:  0.504 test accuracy:  78.0%
# epoch: 63 training loss:  0.599 training accuracy:  71.9%  test loss:  0.518 test accuracy:  75.6%
# epoch: 64 training loss:  0.582 training accuracy:  72.6%  test loss:  0.547 test accuracy:  76.4%
# epoch: 65 training loss:  0.555 training accuracy:  71.3%  test loss:  0.589 test accuracy:  72.4%
# epoch: 66 training loss:  0.575 training accuracy:  75.0%  test loss:  0.565 test accuracy:  75.6%
# epoch: 67 training loss:  0.599 training accuracy:  71.3%  test loss:  0.563 test accuracy:  75.6%
# epoch: 68 training loss:  0.585 training accuracy:  71.9%  test loss:  0.523 test accuracy:  78.0%
# epoch: 69 training loss:  0.579 training accuracy:  71.5%  test loss:  0.572 test accuracy:  76.4%
# epoch: 70 training loss:  0.588 training accuracy:  72.6%  test loss:  0.535 test accuracy:  76.4%
# epoch: 71 training loss:  0.552 training accuracy:  72.8%  test loss:  0.512 test accuracy:  76.4%
# epoch: 72 training loss:  0.566 training accuracy:  73.6%  test loss:  0.521 test accuracy:  81.1%
# epoch: 73 training loss:  0.544 training accuracy:  74.2%  test loss:  0.489 test accuracy:  78.0%
# epoch: 74 training loss:  0.549 training accuracy:  71.5%  test loss:  0.498 test accuracy:  77.2%
# epoch: 75 training loss:  0.566 training accuracy:  73.0%  test loss:  0.514 test accuracy:  77.2%
# epoch: 76 training loss:  0.572 training accuracy:  72.8%  test loss:  0.491 test accuracy:  81.1%
# epoch: 77 training loss:  0.556 training accuracy:  74.6%  test loss:  0.551 test accuracy:  76.4%
# epoch: 78 training loss:  0.546 training accuracy:  73.4%  test loss:  0.536 test accuracy:  75.6%
# epoch: 79 training loss:  0.578 training accuracy:  72.2%  test loss:  0.467 test accuracy:  79.5%
# epoch: 80 training loss:  0.631 training accuracy:  74.8%  test loss:  0.525 test accuracy:  74.0%
# epoch: 81 training loss:  0.590 training accuracy:  73.0%  test loss:  0.591 test accuracy:  72.4%
# epoch: 82 training loss:  0.567 training accuracy:  72.6%  test loss:  0.552 test accuracy:  74.8%
# epoch: 83 training loss:  0.573 training accuracy:  73.6%  test loss:  0.578 test accuracy:  78.7%
# epoch: 84 training loss:  0.568 training accuracy:  72.8%  test loss:  0.521 test accuracy:  77.2%
# epoch: 85 training loss:  0.545 training accuracy:  73.6%  test loss:  0.496 test accuracy:  80.3%
# epoch: 86 training loss:  0.542 training accuracy:  74.0%  test loss:  0.548 test accuracy:  77.2%
# epoch: 87 training loss:  0.568 training accuracy:  74.6%  test loss:  0.536 test accuracy:  78.0%
# epoch: 88 training loss:  0.544 training accuracy:  74.2%  test loss:  0.555 test accuracy:  74.8%
# epoch: 89 training loss:  0.584 training accuracy:  72.6%  test loss:  0.485 test accuracy:  79.5%
# epoch: 90 training loss:  0.567 training accuracy:  74.4%  test loss:  0.518 test accuracy:  77.2%
# epoch: 91 training loss:  0.626 training accuracy:  74.2%  test loss:  0.541 test accuracy:  74.8%
# epoch: 92 training loss:  0.576 training accuracy:  73.2%  test loss:  0.561 test accuracy:  78.0%
# epoch: 93 training loss:  0.572 training accuracy:  74.6%  test loss:  0.570 test accuracy:  77.2%
# epoch: 94 training loss:  0.572 training accuracy:  73.4%  test loss:  0.573 test accuracy:  76.4%
# epoch: 95 training loss:  0.576 training accuracy:  73.4%  test loss:  0.510 test accuracy:  72.4%
# epoch: 96 training loss:  0.593 training accuracy:  72.8%  test loss:  0.496 test accuracy:  78.0%
# epoch: 97 training loss:  0.571 training accuracy:  73.0%  test loss:  0.513 test accuracy:  82.7%
# epoch: 98 training loss:  0.553 training accuracy:  73.6%  test loss:  0.497 test accuracy:  77.2%
# epoch: 99 training loss:  0.581 training accuracy:  74.4%  test loss:  0.493 test accuracy:  79.5%

# %%
from pointnetfunct.evaluation import show_graph
show_graph(path ="./result/2multimodel_uniform_1000pt_test.pt",device = "cuda",name = "1000pt_2branch_trainingtrend")

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import functions as fun
from pointnetfunct.PointNet_trainingfunct import load_model

pointnet_copy = PointNet_2Multimodal_withDNN(classes=2)
model_path = "./pointnet_2multimodal_uniform_1000pt_test.pth"
load_model(pointnet_copy,model_path)
y_true = []
y_pred = []
y_probs = []
y_pred_result = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,inputs_v2,inputs_v3,labels in test_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        inputs_v3 = inputs_v3.to(torch.float32)

        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v,inputs_v3)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) 
        y_probs.extend(outputs)
        
from pointnetfunct.evaluation import show_cm_dl,show_graph,print_values,draw_rocgraph

draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_2branch_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_2branch_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.51
# F1 score: 0.2686567164179105
# Rupture Recall: 0.20454545454545456
# Rupture Precision: 0.391304347826087
# UnRupture Recall: 0.75
# UnRupture Precision: 0.5454545454545454

# %%
pointnet_copy = PointNet_2Multimodal_withDNN(classes=2)
model_path = "./pointnet_2multimodal_uniform_1000pt_test.pth"
load_model(pointnet_copy,model_path)
y_true = []
y_pred = []
y_probs = []
y_pred_result = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,inputs_v2,inputs_v3,labels in valid_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        inputs_v3 = inputs_v3.to(torch.float32)

        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v,inputs_v3)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) 
        y_probs.extend(outputs)
        
from pointnetfunct.evaluation import show_cm_dl,show_graph,print_values,draw_rocgraph

draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_2branch_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_2branch_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.7795275590551181
# F1 score: 0.6666666666666666
# Rupture Recall: 0.7
# Rupture Precision: 0.6363636363636364
# UnRupture Recall: 0.8160919540229885
# UnRupture Precision: 0.8554216867469879

# %% [markdown]
# 3multihead

# %%
import functions
from pointnetfunct.PointNet_struct import PointNet_3Multihead_withDNN
from pointnetfunct.PointNet_trainingfunct import run_model_3multi_head_dnn
pointnet_mh = PointNet_3Multihead_withDNN(classes=2)
run_model_3multi_head_dnn(train_loader_input = train_loader,
                        vaild_loader_input = valid_loader,
                        nepochs = 100, 
                        modelnet = pointnet_mh,
                        results_path = "./result", 
                        filename = "/3multimodal_unform_1000pt_test.pt",
                        model_name= "pointnet_3multimodal_unform_1000pt_test.pth")
pointnet_mh.to("cpu")
print("done")
# Out:
# epoch: 0 training loss:  0.711 training accuracy:  55.9%  test loss:  0.657 test accuracy:  70.1%
# epoch: 1 training loss:  0.707 training accuracy:  65.9%  test loss:  0.704 test accuracy:  66.9%
# epoch: 2 training loss:  0.684 training accuracy:  67.1%  test loss:  0.673 test accuracy:  67.7%
# epoch: 3 training loss:  0.660 training accuracy:  67.7%  test loss:  0.676 test accuracy:  69.3%
# epoch: 4 training loss:  0.646 training accuracy:  70.9%  test loss:  0.624 test accuracy:  76.4%
# epoch: 5 training loss:  0.639 training accuracy:  71.7%  test loss:  0.630 test accuracy:  73.2%
# epoch: 6 training loss:  0.623 training accuracy:  74.0%  test loss:  0.576 test accuracy:  74.0%
# epoch: 7 training loss:  0.620 training accuracy:  72.6%  test loss:  0.566 test accuracy:  73.2%
# epoch: 8 training loss:  0.597 training accuracy:  71.9%  test loss:  0.636 test accuracy:  70.1%
# epoch: 9 training loss:  0.605 training accuracy:  73.6%  test loss:  0.603 test accuracy:  73.2%
# epoch: 10 training loss:  0.609 training accuracy:  73.6%  test loss:  0.545 test accuracy:  76.4%
# epoch: 11 training loss:  0.585 training accuracy:  72.0%  test loss:  0.564 test accuracy:  74.0%
# epoch: 12 training loss:  0.603 training accuracy:  75.6%  test loss:  0.560 test accuracy:  75.6%
# epoch: 13 training loss:  0.595 training accuracy:  73.6%  test loss:  0.583 test accuracy:  75.6%
# epoch: 14 training loss:  0.609 training accuracy:  72.6%  test loss:  0.579 test accuracy:  74.0%
# epoch: 15 training loss:  0.601 training accuracy:  72.8%  test loss:  0.574 test accuracy:  73.2%
# epoch: 16 training loss:  0.593 training accuracy:  71.5%  test loss:  0.578 test accuracy:  74.0%
# epoch: 17 training loss:  0.583 training accuracy:  73.4%  test loss:  0.606 test accuracy:  70.9%
# epoch: 18 training loss:  0.593 training accuracy:  72.2%  test loss:  0.597 test accuracy:  70.1%
# epoch: 19 training loss:  0.587 training accuracy:  73.6%  test loss:  0.575 test accuracy:  74.0%
# epoch: 20 training loss:  0.583 training accuracy:  73.2%  test loss:  0.576 test accuracy:  71.7%
# epoch: 21 training loss:  0.556 training accuracy:  73.0%  test loss:  0.587 test accuracy:  75.6%
# epoch: 22 training loss:  0.648 training accuracy:  71.7%  test loss:  0.657 test accuracy:  73.2%
# epoch: 23 training loss:  0.631 training accuracy:  72.8%  test loss:  0.544 test accuracy:  72.4%
# epoch: 24 training loss:  0.573 training accuracy:  73.0%  test loss:  0.548 test accuracy:  74.0%
# epoch: 25 training loss:  0.572 training accuracy:  72.2%  test loss:  0.555 test accuracy:  72.4%
# epoch: 26 training loss:  0.581 training accuracy:  73.2%  test loss:  0.572 test accuracy:  70.1%
# epoch: 27 training loss:  0.607 training accuracy:  73.8%  test loss:  0.591 test accuracy:  71.7%
# epoch: 28 training loss:  0.571 training accuracy:  75.0%  test loss:  0.531 test accuracy:  73.2%
# epoch: 29 training loss:  0.608 training accuracy:  71.5%  test loss:  0.530 test accuracy:  75.6%
# epoch: 30 training loss:  0.613 training accuracy:  73.2%  test loss:  0.579 test accuracy:  72.4%
# epoch: 31 training loss:  0.575 training accuracy:  74.8%  test loss:  0.545 test accuracy:  78.7%
# epoch: 32 training loss:  0.563 training accuracy:  74.6%  test loss:  0.553 test accuracy:  78.0%
# epoch: 33 training loss:  0.583 training accuracy:  71.7%  test loss:  0.560 test accuracy:  79.5%
# epoch: 34 training loss:  0.561 training accuracy:  73.4%  test loss:  0.597 test accuracy:  78.0%
# epoch: 35 training loss:  0.602 training accuracy:  74.6%  test loss:  0.535 test accuracy:  73.2%
# epoch: 36 training loss:  0.578 training accuracy:  74.0%  test loss:  0.575 test accuracy:  72.4%
# epoch: 37 training loss:  0.629 training accuracy:  73.6%  test loss:  0.586 test accuracy:  74.0%
# epoch: 38 training loss:  0.557 training accuracy:  73.0%  test loss:  0.515 test accuracy:  76.4%
# epoch: 39 training loss:  0.585 training accuracy:  73.6%  test loss:  0.586 test accuracy:  74.8%
# epoch: 40 training loss:  0.570 training accuracy:  75.8%  test loss:  0.538 test accuracy:  78.0%
# epoch: 41 training loss:  0.588 training accuracy:  74.4%  test loss:  0.584 test accuracy:  76.4%
# epoch: 42 training loss:  0.579 training accuracy:  74.4%  test loss:  0.548 test accuracy:  75.6%
# epoch: 43 training loss:  0.548 training accuracy:  75.6%  test loss:  0.509 test accuracy:  76.4%
# epoch: 44 training loss:  0.556 training accuracy:  74.0%  test loss:  0.486 test accuracy:  81.9%
# epoch: 45 training loss:  0.549 training accuracy:  76.6%  test loss:  0.523 test accuracy:  75.6%
# epoch: 46 training loss:  0.554 training accuracy:  73.4%  test loss:  0.508 test accuracy:  75.6%
# epoch: 47 training loss:  0.569 training accuracy:  75.6%  test loss:  0.508 test accuracy:  75.6%
# epoch: 48 training loss:  0.579 training accuracy:  75.6%  test loss:  0.546 test accuracy:  74.8%
# epoch: 49 training loss:  0.548 training accuracy:  72.8%  test loss:  0.522 test accuracy:  76.4%
# epoch: 50 training loss:  0.583 training accuracy:  74.2%  test loss:  0.535 test accuracy:  77.2%
# epoch: 51 training loss:  0.560 training accuracy:  73.2%  test loss:  0.560 test accuracy:  74.8%
# epoch: 52 training loss:  0.539 training accuracy:  75.0%  test loss:  0.542 test accuracy:  74.8%
# epoch: 53 training loss:  0.561 training accuracy:  75.2%  test loss:  0.549 test accuracy:  74.0%
# epoch: 54 training loss:  0.593 training accuracy:  75.0%  test loss:  0.495 test accuracy:  78.0%
# epoch: 55 training loss:  0.575 training accuracy:  74.8%  test loss:  0.530 test accuracy:  74.8%
# epoch: 56 training loss:  0.551 training accuracy:  75.8%  test loss:  0.523 test accuracy:  78.0%
# epoch: 57 training loss:  0.571 training accuracy:  72.8%  test loss:  0.492 test accuracy:  74.8%
# epoch: 58 training loss:  0.529 training accuracy:  76.2%  test loss:  0.502 test accuracy:  74.8%
# epoch: 59 training loss:  0.551 training accuracy:  74.4%  test loss:  0.545 test accuracy:  71.7%
# epoch: 60 training loss:  0.514 training accuracy:  76.2%  test loss:  0.499 test accuracy:  77.2%
# epoch: 61 training loss:  0.580 training accuracy:  76.0%  test loss:  0.466 test accuracy:  79.5%
# epoch: 62 training loss:  0.580 training accuracy:  74.4%  test loss:  0.590 test accuracy:  78.7%
# epoch: 63 training loss:  0.594 training accuracy:  74.4%  test loss:  0.569 test accuracy:  77.2%
# epoch: 64 training loss:  0.587 training accuracy:  75.4%  test loss:  0.496 test accuracy:  78.0%
# epoch: 65 training loss:  0.547 training accuracy:  74.0%  test loss:  0.505 test accuracy:  77.2%
# epoch: 66 training loss:  0.569 training accuracy:  74.4%  test loss:  0.560 test accuracy:  76.4%
# epoch: 67 training loss:  0.606 training accuracy:  75.0%  test loss:  0.541 test accuracy:  77.2%
# epoch: 68 training loss:  0.553 training accuracy:  75.2%  test loss:  0.562 test accuracy:  76.4%
# epoch: 69 training loss:  0.564 training accuracy:  73.6%  test loss:  0.581 test accuracy:  78.7%
# epoch: 70 training loss:  0.582 training accuracy:  74.0%  test loss:  0.508 test accuracy:  75.6%
# epoch: 71 training loss:  0.558 training accuracy:  74.6%  test loss:  0.492 test accuracy:  78.7%
# epoch: 72 training loss:  0.556 training accuracy:  76.4%  test loss:  0.528 test accuracy:  76.4%
# epoch: 73 training loss:  0.599 training accuracy:  74.6%  test loss:  0.518 test accuracy:  78.0%
# epoch: 74 training loss:  0.552 training accuracy:  73.2%  test loss:  0.548 test accuracy:  79.5%
# epoch: 75 training loss:  0.530 training accuracy:  74.6%  test loss:  0.525 test accuracy:  77.2%
# epoch: 76 training loss:  0.512 training accuracy:  74.4%  test loss:  0.537 test accuracy:  77.2%
# epoch: 77 training loss:  0.564 training accuracy:  74.0%  test loss:  0.540 test accuracy:  78.0%
# epoch: 78 training loss:  0.570 training accuracy:  75.2%  test loss:  0.544 test accuracy:  74.0%
# epoch: 79 training loss:  0.536 training accuracy:  76.4%  test loss:  0.506 test accuracy:  77.2%
# epoch: 80 training loss:  0.576 training accuracy:  75.0%  test loss:  0.511 test accuracy:  75.6%
# epoch: 81 training loss:  0.520 training accuracy:  76.0%  test loss:  0.499 test accuracy:  78.0%
# epoch: 82 training loss:  0.552 training accuracy:  75.6%  test loss:  0.503 test accuracy:  73.2%
# epoch: 83 training loss:  0.560 training accuracy:  76.0%  test loss:  0.501 test accuracy:  74.0%
# epoch: 84 training loss:  0.580 training accuracy:  75.0%  test loss:  0.504 test accuracy:  74.8%
# epoch: 85 training loss:  0.561 training accuracy:  73.8%  test loss:  0.537 test accuracy:  72.4%
# epoch: 86 training loss:  0.547 training accuracy:  76.6%  test loss:  0.532 test accuracy:  76.4%
# epoch: 87 training loss:  0.575 training accuracy:  71.5%  test loss:  0.556 test accuracy:  74.8%
# epoch: 88 training loss:  0.553 training accuracy:  74.2%  test loss:  0.515 test accuracy:  76.4%
# epoch: 89 training loss:  0.525 training accuracy:  75.8%  test loss:  0.531 test accuracy:  76.4%
# epoch: 90 training loss:  0.544 training accuracy:  77.0%  test loss:  0.516 test accuracy:  77.2%
# epoch: 91 training loss:  0.532 training accuracy:  73.6%  test loss:  0.496 test accuracy:  80.3%
# epoch: 92 training loss:  0.561 training accuracy:  74.8%  test loss:  0.527 test accuracy:  78.0%
# epoch: 93 training loss:  0.548 training accuracy:  74.4%  test loss:  0.550 test accuracy:  73.2%
# epoch: 94 training loss:  0.549 training accuracy:  75.8%  test loss:  0.517 test accuracy:  75.6%
# epoch: 95 training loss:  0.571 training accuracy:  75.6%  test loss:  0.494 test accuracy:  76.4%
# epoch: 96 training loss:  0.588 training accuracy:  75.4%  test loss:  0.489 test accuracy:  78.7%
# epoch: 97 training loss:  0.563 training accuracy:  73.0%  test loss:  0.533 test accuracy:  78.7%
# epoch: 98 training loss:  0.557 training accuracy:  75.0%  test loss:  0.519 test accuracy:  74.0%
# epoch: 99 training loss:  0.587 training accuracy:  74.2%  test loss:  0.542 test accuracy:  81.1%
# done

# %%
device = torch.device('cuda:0')
show_graph(path ="./result/3multimodal_unform_1000pt_test.pt",device = "cuda",name ="1000pt_3branch_trainingtrend")

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import functions as fun
from pointnetfunct.PointNet_trainingfunct import load_model

pointnet_copy = PointNet_3Multihead_withDNN(classes=2)
model_path = "./pointnet_3multimodal_unform_1000pt_test.pth"
load_model(pointnet_copy,model_path)
y_true = []
y_pred = []
y_probs = []
y_pred_result = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,inputs_v2,inputs_v3,labels in test_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        inputs_v2 = inputs_v2.to(torch.float32)
        inputs_v2 = inputs_v2.squeeze(1).permute(0, 2, 1)
        inputs_v3 = inputs_v3.to(torch.float32)

        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v,inputs_v2,inputs_v3)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) 
        y_probs.extend(outputs)

# %%
from pointnetfunct.evaluation import show_cm_dl,show_graph,print_values,draw_rocgraph

draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_3branch_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_3branch_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.53
# F1 score: 0.2985074626865672
# Rupture Recall: 0.22727272727272727
# Rupture Precision: 0.43478260869565216
# UnRupture Recall: 0.7678571428571429
# UnRupture Precision: 0.5584415584415584

# %%
y_true = []
y_pred = []
y_probs = []
y_pred_result = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,inputs_v2,inputs_v3,labels in valid_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        inputs_v2 = inputs_v2.to(torch.float32)
        inputs_v2 = inputs_v2.squeeze(1).permute(0, 2, 1)
        inputs_v3 = inputs_v3.to(torch.float32)

        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v,inputs_v2,inputs_v3)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) 
        y_probs.extend(outputs)

# %%
draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_3branch_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_3branch_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.7480314960629921
# F1 score: 0.6097560975609756
# Rupture Recall: 0.625
# Rupture Precision: 0.5952380952380952
# UnRupture Recall: 0.8045977011494253
# UnRupture Precision: 0.8235294117647058
