# %%
import test_application as ta
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# ...

# %% [markdown]
# PointNet vanilla

# %%
ta.output_result(points = 2000, sample = "uniform", model_type = "pointnet", model_file = "./final_models/2000points/pointnet_uniform_2000pt.pth")
# Out:
#  Internal test result
# Accuracy: 0.7559055118110236
# F1 score: 0.6172839506172839
# Rupture Recall: 0.625
# Rupture Precision: 0.6097560975609756
# UnRupture Recall: 0.8160919540229885
# UnRupture Precision: 0.8255813953488372
#
#  External test result
# Accuracy: 0.59
# F1 score: 0.4057971014492754
# Rupture Recall: 0.3181818181818182
# Rupture Precision: 0.56
# UnRupture Recall: 0.8035714285714286
# UnRupture Precision: 0.6

# %%
ta.output_result(points = 2000, 
                 sample = "uniform", 
                 model_type = "pointnet_2branch", 
                 model_file = "./final_models/2000points/pointnet_2branch_modal_uniform_2000pt.pth")
# Out:
#  Internal test result
# Accuracy: 0.7795275590551181
# F1 score: 0.6585365853658537
# Rupture Recall: 0.675
# Rupture Precision: 0.6428571428571429
# UnRupture Recall: 0.8275862068965517
# UnRupture Precision: 0.8470588235294118
#
#  External test result
# Accuracy: 0.53
# F1 score: 0.3380281690140845
# Rupture Recall: 0.2727272727272727
# Rupture Precision: 0.4444444444444444
# UnRupture Recall: 0.7321428571428571
# UnRupture Precision: 0.5616438356164384

# %%
ta.output_result(points = 2000, 
                 sample = "uniform", 
                 model_type = "pointnet_3branch", 
                 model_file = "./final_models/2000points/pointnet_3branch_modal_uniform_2000pt.pth")
# Out:
#  Internal test result
# Accuracy: 0.7322834645669292
# F1 score: 0.6304347826086957
# Rupture Recall: 0.725
# Rupture Precision: 0.5576923076923077
# UnRupture Recall: 0.735632183908046
# UnRupture Precision: 0.8533333333333334
#
#  External test result
# Accuracy: 0.61
# F1 score: 0.49350649350649356
# Rupture Recall: 0.4318181818181818
# Rupture Precision: 0.5757575757575758
# UnRupture Recall: 0.75
# UnRupture Precision: 0.6268656716417911
