# %%
import test_application as ta
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# d:\Universityofleeds\MSC_PROG\Msc_project\results\pointnetfunct\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\results\pointnetfunct\data_process_ml.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# ...

# %% [markdown]
# PointNet vanilla

# %%
ta.output_result(points = 2000, 
                 sample = "uniform", 
                 model_type = "pointnet", 
                 cuttype = "dome",
                 model_file = "./final_models/2000points/dome/pointnet_dome_uniform_2000pt.pth")
# Out:
#  Internal test result
# Accuracy: 0.7086614173228346
# F1 score: 0.463768115942029
# Rupture Recall: 0.4
# Rupture Precision: 0.5517241379310345
# UnRupture Recall: 0.8505747126436781
# UnRupture Precision: 0.7551020408163265
#
#  External test result
# Accuracy: 0.57
# F1 score: 0.29508196721311475
# Rupture Recall: 0.20454545454545456
# Rupture Precision: 0.5294117647058824
# UnRupture Recall: 0.8571428571428571
# UnRupture Precision: 0.5783132530120482

# %% [markdown]
# 2branch pointNet

# %%
ta.output_result(points = 1000, 
                 sample = "uniform", 
                 model_type = "pointnet_2branch", 
                 cuttype = "cut1",
                 model_file = "./final_models/1000points/cut1/pointnet_cut1_2branch_uniform_1000pt.pth")
# Out:
#  Internal test result
# Accuracy: 0.7716535433070866
# F1 score: 0.6329113924050633
# Rupture Recall: 0.625
# Rupture Precision: 0.6410256410256411
# UnRupture Recall: 0.8390804597701149
# UnRupture Precision: 0.8295454545454546
#
#  External test result
# Accuracy: 0.49
# F1 score: 0.2608695652173913
# Rupture Recall: 0.20454545454545456
# Rupture Precision: 0.36
# UnRupture Recall: 0.7142857142857143
# UnRupture Precision: 0.5333333333333333

# %%
ta.output_result(points = 2000, 
                 sample = "uniform", 
                 model_type = "pointnet_2branch", 
                 cuttype = "cut1",
                 model_file = "./final_models/2000points/cut1/pointnet_cut1_2branch_uniform_2000pt.pth")
# Out:
#  Internal test result
# Accuracy: 0.7952755905511811
# F1 score: 0.7045454545454546
# Rupture Recall: 0.775
# Rupture Precision: 0.6458333333333334
# UnRupture Recall: 0.8045977011494253
# UnRupture Precision: 0.8860759493670886
#
#  External test result
# Accuracy: 0.52
# F1 score: 0.3142857142857143
# Rupture Recall: 0.25
# Rupture Precision: 0.4230769230769231
# UnRupture Recall: 0.7321428571428571
# UnRupture Precision: 0.5540540540540541

# %%
ta.output_result(points = 2000, 
                 sample = "ppd", 
                 model_type = "pointnet_2branch", 
                 cuttype = "cut1",
                 model_file = "./final_models/2000points/cut1/pointnet_cut1_2branch_ppd_2000pt.pth")
# Out:
#  Internal test result
# Accuracy: 0.7952755905511811
# F1 score: 0.6976744186046512
# Rupture Recall: 0.75
# Rupture Precision: 0.6521739130434783
# UnRupture Recall: 0.8160919540229885
# UnRupture Precision: 0.8765432098765432
#
#  External test result
# Accuracy: 0.55
# F1 score: 0.34782608695652173
# Rupture Recall: 0.2727272727272727
# Rupture Precision: 0.48
# UnRupture Recall: 0.7678571428571429
# UnRupture Precision: 0.5733333333333334

# %% [markdown]
# 3 branch pointnet

# %%
ta.output_result(points = 1000, 
                 sample = "ppd", 
                 model_type = "pointnet_3branch", 
                 cuttype = "dome",
                 model_file = "./final_models/1000points/dome_vessel/pointnet_dome_3branch_ppd_1000pt.pth")
# Out:
#  Internal test result
# Accuracy: 0.7795275590551181
# F1 score: 0.6410256410256411
# Rupture Recall: 0.625
# Rupture Precision: 0.6578947368421053
# UnRupture Recall: 0.8505747126436781
# UnRupture Precision: 0.8314606741573034
#
#  External test result
# Accuracy: 0.58
# F1 score: 0.3
# Rupture Recall: 0.20454545454545456
# Rupture Precision: 0.5625
# UnRupture Recall: 0.875
# UnRupture Precision: 0.5833333333333334

# %%
ta.output_result(points = 2000, 
                 sample = "ppd", 
                 model_type = "pointnet_3branch", 
                 cuttype = "cut1",
                 model_file = "./final_models/2000points/cut1_vessel/pointnet_cut1_3branch_ppd_2000pt.pth")
# Out:
#  Internal test result
# Accuracy: 0.8503937007874016
# F1 score: 0.7816091954022989
# Rupture Recall: 0.85
# Rupture Precision: 0.723404255319149
# UnRupture Recall: 0.8505747126436781
# UnRupture Precision: 0.925
#
#  External test result
# Accuracy: 0.61
# F1 score: 0.4800000000000001
# Rupture Recall: 0.4090909090909091
# Rupture Precision: 0.5806451612903226
# UnRupture Recall: 0.7678571428571429
# UnRupture Precision: 0.6231884057971014
