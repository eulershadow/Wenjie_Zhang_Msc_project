# %%
import vtk
import os
import numpy as np
import itertools
import math, random
import data_process_ml
random.seed = 42
import copy

import torch
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
from torchvision import transforms, utils

import scipy.spatial.distance
# import plotly.graph_objects as go
# import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
import open3d as o3d
def reduce_mesh(target_mesh, reference_mesh):
    # Find common vertices between the two meshes
    output_mesh = copy.deepcopy(target_mesh)
    target_vertices = set(tuple(vertex) for vertex in np.asarray(target_mesh.vertices))
    target_vertices_list = [tuple(vertex) for vertex in np.asarray(target_mesh.vertices)]
    index_dict = {item: index for index, item in enumerate(target_vertices_list)}
    reference_vertices = set(tuple(vertex) for vertex in np.asarray(reference_mesh.vertices))

    common_vertices = target_vertices.intersection(reference_vertices)
    #print(len(list(common_vertices)))
    list_mine = [index_dict[element_to_find] for element_to_find in list(common_vertices)]

    #print(list_mine)

    # Filter out vertices and triangles based on common vertices
    output_mesh.remove_vertices_by_index(list_mine)

    return output_mesh

def mesh_to_point_cloud(file_path,points = 10000):
    """
    Convert a mesh object to a point cloud object.
    """
    mesh = o3d.io.read_triangle_mesh(file_path)
    point_cloud = mesh.sample_points_uniformly(number_of_points=points) # Adjust number_of_points as needed
    return point_cloud

# %%
import vtk
import numpy as np

def vtp_to_mesh(file_path):
    reader = vtk.vtkXMLPolyDataReader()
    reader.SetFileName(file_path)
    reader.Update()
    polydata = reader.GetOutput()

    vertices = np.array(polydata.GetPoints().GetData())
    polygons = np.array(polydata.GetPolys().GetData())

    # Extract vertices
    vertices = vertices.reshape(-1, 3)

    # Extract faces
    faces = polygons.reshape(-1, 4)[:, 1:]  

    mesh = o3d.geometry.TriangleMesh()
    mesh.vertices = o3d.utility.Vector3dVector(vertices)
    mesh.triangles = o3d.utility.Vector3iVector(faces)
    return mesh

def vtp_to_point_cloud(file_path,points = 10000):
    mesh = o3d.geometry.TriangleMesh()
    if ".vtp" not in file_path:
        mesh = o3d.io.read_triangle_mesh(file_path)
    else:
        mesh = vtp_to_mesh(file_path)

    point_cloud = mesh.sample_points_uniformly(number_of_points=points)

    return point_cloud

def vtp_to_point_cloud_cutvessel(vessel_file_path,cut_file_path, points = 10000):
    """
    Convert a mesh object to a point cloud object.
    """
    if ".vtp" not in vessel_file_path:
        vessel_mesh = o3d.io.read_triangle_mesh(vessel_file_path)
    else:
        vessel_mesh = vtp_to_mesh(vessel_file_path)
    if ".vtp" not in cut_file_path:
        cut_mesh = o3d.io.read_triangle_mesh(cut_file_path)
    else:
        cut_mesh = vtp_to_mesh(cut_file_path)
    
    box_mesh = cut_mesh.get_axis_aligned_bounding_box()
    reduced_mesh =  vessel_mesh.crop(box_mesh) 
    result_mesh = reduce_mesh(vessel_mesh,reduced_mesh)
    #print(cut1_mesh,result_mesh)
    if vessel_mesh.vertices == result_mesh.vertices:
        return False
                  
    #o3d.visualization.draw_geometries([result_mesh])
    
    point_cloud = result_mesh.sample_points_uniformly(number_of_points=points) # Adjust number_of_points as needed
    return point_cloud

# %% [markdown]
# test case

# %%
modelcov_vtp = vtp_to_point_cloud("./test_model/SNF00000036_02.vtp")
# o3d.visualization.draw_geometries([modelcov_vtp])

# %%
print(np.asarray(modelcov_vtp.points))
# Out:
# [[38.39359112 25.73729217 11.00451665]
#  [40.55299039 24.10619762 13.48027918]
#  [36.71958714 28.03707383 14.44223189]
#  ...
#  [22.93412879 25.76327997 33.00578464]
#  [23.1041807  26.44252294 31.81658701]
#  [37.61510272 34.44956764 20.37695921]]

# %%
# modelcov_vtp = vtp_to_point_cloud_cutvessel("./test_model/ANSYS_UNIGE_09.vtp","./test_model/ANSYS_UNIGE_09_dome.vtp")
# o3d.visualization.draw_geometries([modelcov_vtp])

# %%
# modelcov_vtp = vtp_to_point_cloud_cutvessel("./test_model/C0040.vtp","./test_model/C0040_dome.vtp")
# o3d.visualization.draw_geometries([modelcov_vtp])

# %%
class Aneuxmodel_Dataset(Dataset):

    def __init__(self, df, root = "", transform = None,mesh = "area-001",cuttype = "dome",crop = False):

        self.root = root
        self.transform = transform
        self.mesh = mesh
        self.cuttype = cuttype
        self.crop = crop
        if self.cuttype!= "dome" and self.cuttype!= "cut1":
            return "type error"
        
        self.df = df
        self.label = []
        self.vessel_model_file = []
        self.cut1_model_file = []
        self.dome_model_file = []
        self.model_table = []
        
        self.cropdome_vessel_file = []
        self.cropcut1_vessel_file = []
        
        self.training_data_load()
        self.label_loader()
        self.my_device = "cuda:0"
            
    def label_loader(self):
        self.label = []
        for model in self.model_table:
            if  model in list(self.df["dataset"]):
                label_num = self.df[self.df["dataset"] == model]["status"]
                label_num = list(label_num)[0]
                if label_num == "rupture":
                    label_num = 1
                else:
                    label_num = 0
                self.label.append(label_num)
        self.label = torch.from_numpy(np.array(self.label))
        return True
    
    def find_dome_cut1(self,all_IA_model,model_name):
        IA_name_cut1 = ""
        IA_name_dome = ""
        for IA_model in all_IA_model:
                
            if model_name in IA_model and "cut1" in IA_model and model_name not in IA_name_cut1:
                #print("find:" + IA_model)
                IA_name_cut1 = IA_model
            elif model_name.split("_")[0] in IA_model and "cut1" in IA_model and IA_name_cut1 == "":
                IA_name_cut1 = IA_model
                
            if model_name in IA_model and "dome" in IA_model and model_name not in IA_name_dome:
                IA_name_dome = IA_model
            elif model_name.split("_")[0] in IA_model and "dome" in IA_model and IA_name_dome == "":
                IA_name_dome = IA_model
                
            if IA_name_cut1 != "" and IA_name_dome != "" and model_name in IA_name_cut1 and model_name in IA_name_dome:
                break
        return IA_name_cut1,IA_name_dome
                
    def training_data_load(self):
        self.label = []
        self.vessel_model_file = []
        self.cut1_model_file = []
        self.dome_model_file = []
        self.model_table = []
        self.cropdome_vessel_file = []
        self.cropcut1_vessel_file = []
        
        #path of the files
        IA = "aneurysms\\remeshed\\area-001"
        Vessel = "vessels\\remeshed\\area-001"
        if self.mesh == "area-001":
            IA = "aneurysms\\remeshed\\area-001"
            Vessel = "vessels\\remeshed\\area-001"
        elif self.mesh == "area-005":
            IA = "aneurysms\r\emeshed\\area-005"
            Vessel = "vessels\\remeshed\\area-005"
        elif self.mesh == "orginal":
            IA = "aneurysms\\orginal"
            Vessel = "vessels\\orginal"
            
        IA_root = os.path.join(self.root,IA)
        Vessel_root = os.path.join(self.root,Vessel)
        #list of the model files
        all_vessel_model = os.listdir(Vessel_root)
        all_IA_model = os.listdir(IA_root)

        for model in all_vessel_model[:50]:
            #file name for IA cut1 and dome
            model_name = model[:-4]
            # get cut1 file name and dome file name from ALL_IA_model list
            IA_name_cut1 = ""
            IA_name_dome = ""
            IA_name_cut1,IA_name_dome = self.find_dome_cut1(all_IA_model,model_name)

            #read the file path and add the model to the list
            if IA_name_cut1 in all_IA_model:
                IA_root_cut1 = os.path.join(IA_root,IA_name_cut1)
                cut1 = vtp_to_point_cloud(IA_root_cut1,points = 10000)
                self.cut1_model_file.append(cut1)
            else:
                print("missing a cut1 model: " + model_name)
                
            if IA_name_dome in all_IA_model:
                IA_root_dome = os.path.join(IA_root,IA_name_dome)
                dome = vtp_to_point_cloud(IA_root_dome,points = 10000)
                self.dome_model_file.append(dome)
            else:
                print("missing a dome model: " + model_name)
            
            
            # append vessel list             
            if model in all_vessel_model:
                Vessel_model_root = os.path.join(Vessel_root,model)
                vessel = vtp_to_point_cloud(Vessel_model_root,points = 10000)
                self.vessel_model_file.append(vessel)
            else:
                print("missing a vessel model: " + model_name)
            if self.crop:
                IA_root_cut1 = os.path.join(IA_root,IA_name_cut1)
                IA_root_dome = os.path.join(IA_root,IA_name_dome)
                Vessel_model_root = os.path.join(Vessel_root,model)
                Vessel_crop_cut1 = vtp_to_point_cloud_cutvessel(Vessel_model_root,IA_root_cut1,points = 10000)
                Vessel_crop_dome = vtp_to_point_cloud_cutvessel(Vessel_model_root,IA_root_dome,points = 10000)
                self.cropcut1_vessel_file.append(Vessel_crop_cut1)
                self.cropdome_vessel_file.append(Vessel_crop_dome)
                        
            self.model_table.append(IA_name_cut1.split("_")[0])
        
        return True
        # self.org_imgs = np.array(self.org_imgs)
        # self.total_imgs = torch.from_numpy(np.array(self.total_imgs)) 
        # self.label = torch.from_numpy(np.array(self.label))  
        # return True

    
    def __getitem__(self, index):
        
        """ Returns one data pair (image and target caption). """
        cut_model = self.cut1_model_file[index]
        vessel_model = self.vessel_model_file[index]
        if self.cuttype == "dome":
            cut_model = self.dome_model_file[index]
        if self.crop and self.cuttype == "cut1":
            vessel_model = self.cropcut1_vessel_file[index]
        if self.crop and self.cuttype == "dome":
            vessel_model = self.cropdome_vessel_file[index]
            
        vessel_model = np.asarray(vessel_model.points)
        cut_model = np.asarray(cut_model.points)
        
        if self.transform is not None:      
            cut_model= self.transform(cut_model)
            vessel_model = self.transform(vessel_model)
            
        label_return = self.label[index]
            
         
        return vessel_model,cut_model,label_return

    def __len__(self):
                                
        return len(self.model_table)

# %% [markdown]
# load the dataset

# %%
root = "..\..\msc_data\models-v1.0\models"
IA = "aneurysms\\remeshed\\area-001"
Vessel = "vessels\\remeshed\\area-001"
IA_root = os.path.join(root,IA)
Vessel_root = os.path.join(root,Vessel)
list1 = os.listdir(Vessel_root)
list2 = os.listdir(IA_root)

# %%
morpho_path = ".\AneuX\data-v1.0\data\morpho-per-cut.csv"
patient_path = ".\AneuX\data-v1.0\data\clinical.csv"
morpho_data_patient = data_process_ml.read_and_combine_data(morpho_path,patient_path)
merged_dataset = data_process_ml.encode_column(morpho_data_patient)
merged_dataset = data_process_ml.drop_columns(merged_dataset)
morpho_data_cut1,morpho_data_dome = data_process_ml.output_cut1anddome(merged_dataset)
# Out:
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_dome.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)

# %%
morpho_data_patient
# Out:
#       source_x                        dataset cuttype curvature-gauss--L2N  \
# 0      hug2016  p043_HAARCREcDAAQDQcbHgANDRQM    cut1                  NaN
# 1      hug2016  p043_HAARCREcDAAQDQcbHgANDRQM    cut2                  NaN
# 2      hug2016  p043_HAARCREcDAAQDQcbHgANDRQM    dome             0.725242
# 3      hug2016  p043_HAARCREcDAAQDQcbHgANDRQM   ninja              2.10899
# 4      hug2016  p044_BBMdFxESDBMcEwcVBhMBExQC    cut1                  NaN
# ...        ...                            ...     ...                  ...
# 2771  aneurisk                          C0098   ninja              4.02451
# 2772  aneurisk                          C0099    cut1                  NaN
# 2773  aneurisk                          C0099    cut2                  NaN
# 2774  aneurisk                          C0099    dome             0.606894
# 2775  aneurisk                          C0099   ninja              1.12167
#
#      curvature.1-gauss-H curvature.2-gauss-L2N curvature.3-gauss-L2NCH  \
# 0                    NaN                   NaN                     NaN
# 1                    NaN                   NaN                     NaN
# 2             -0.0894094               2.60987                 1.18701
# 3               0.214448               3.36637                 1.46921
# 4                    NaN                   NaN                     NaN
# ...                  ...                   ...                     ...
# 2771             -1.3277               6.76148                 1.58789
# 2772                 NaN                   NaN                     NaN
# 2773                 NaN                   NaN                     NaN
# 2774           0.0592102               1.77604                 1.05955
# 2775             0.33062               2.66307                 1.07932
#
#      curvature.4-mean--L2N curvature.5-mean-H curvature.6-mean-L2N  ...  \
# 0                      NaN                NaN                  NaN  ...
# 1                      NaN                NaN                  NaN  ...
# 2                 0.198244           0.086614              1.86744  ...
# 3                 0.613297           0.297034               1.9215  ...
# 4                      NaN                NaN                  NaN  ...
# ...                    ...                ...                  ...  ...
# 2771              0.700816          -0.445498              2.39925  ...
# 2772                   NaN                NaN                  NaN  ...
# 2773                   NaN                NaN                  NaN  ...
# 2774             0.0435289         -0.0156052               1.5576  ...
# 2775             0.0552181          0.0808308              1.75805  ...
#
#      zmi_surf.136-energy-n16 zmi_surf.137-energy-n17 zmi_surf.138-energy-n18  \
# 0                    45.5701                 47.4192                 49.5589
# 1                    60.8748                 64.7821                 68.2609
# 2                    30.1846                 32.0237                 33.6042
# 3                     32.396                 34.5638                 36.0719
# 4                    42.1663                 44.2741                 46.3791
# ...                      ...                     ...                     ...
# 2771                  32.908                 35.3017                 36.9199
# 2772                 39.4508                 42.9421                      45
# 2773                 48.4827                 51.0062                 53.8531
# 2774                 29.1724                  30.676                 32.1221
# 2775                 69.4443                 72.5563                 75.4661
#
#      zmi_surf.139-energy-n19 zmi_surf.140-energy-n20      status location  \
# 0                    52.4916                 54.9455  unruptured  ICA oph
# 1                    71.7461                 74.6314  unruptured  ICA oph
# 2                    35.1063                 37.0662  unruptured  ICA oph
# 3                    37.9747                  39.807  unruptured  ICA oph
# 4                    47.4028                 49.1238  unruptured    VA V4
# ...                      ...                     ...         ...      ...
# 2771                 38.3504                  40.132    ruptured  MCA bif
# 2772                 47.9252                 50.0939  unruptured  MCA bif
# 2773                 56.8737                 60.1946  unruptured  MCA bif
# 2774                 33.7636                 35.7248  unruptured  MCA bif
# 2775                 81.0222                 84.8019  unruptured  MCA bif
#
#        side     sex   age
# 0      left  female  64.2
# 1      left  female  64.2
# 2      left  female  64.2
# 3      left  female  64.2
# 4      left  female  72.7
# ...     ...     ...   ...
# 2771  right  female  59.0
# 2772  right  female  42.0
# 2773  right  female  42.0
# 2774  right  female  42.0
# 2775  right  female  42.0
#
# [2776 rows x 178 columns]

# %%
import pandas as pd
df = pd.DataFrame()
Aneux_Dataset = Aneuxmodel_Dataset(root = root,
                                   df=morpho_data_patient,
                                   transform = transforms.ToTensor(),
                                   mesh = "area-001",
                                   cuttype = "dome",
                                   crop = False)

# %%
Aneux_Dataset
label_aneux = []
for model in Aneux_Dataset.model_table:
    if  model in list(Aneux_Dataset.df["dataset"]):
        label_num = Aneux_Dataset.df[Aneux_Dataset.df["dataset"] == model]["status"]
        label_num = list(label_num)[0]
        if label_num == "rupture":
            label_num = 1
        else:
            label_num = 0
        label_aneux.append(label_num)
    else:
        print(model)
# Out:
# C0007
# C0025
# C0039

# %%
# load dataset, transfer the open3d pointnet to the tensotflow object
train_size = int(len(Aneux_Dataset) * 0.8) # 80% training data
valid_size = len(Aneux_Dataset) - train_size
train_data, valid_data = random_split(Aneux_Dataset, [train_size, valid_size])

train_loader = torch.utils.data.DataLoader(
    train_data,
    batch_size=16,
    shuffle=True,
    #num_workers=2, 
    pin_memory=True
)

valid_loader = torch.utils.data.DataLoader(
    valid_data,
    batch_size=100, # Forward pass only so batch size can be larger
    shuffle=False,
    #num_workers=2, 
    pin_memory=True
)

# %%
for i in train_loader:
    a,b,c = i
    print(a,b,c)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 for i in train_loader:
#       2     a,b,c = i
#       3     print(a,b,c)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\utils\data\dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\utils\data\_utils\fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      47 if self.auto_collation:
#      48     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
#      51         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\utils\data\dataset.py:399, in Subset.__getitems__(self, indices)
#     397     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     398 else:
# --> 399     return [self.dataset[self.indices[idx]] for idx in indices]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\utils\data\dataset.py:399, in <listcomp>(.0)
#     397     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     398 else:
# --> 399     return [self.dataset[self.indices[idx]] for idx in indices]
#
# Cell In [32], line 156, in Aneuxmodel_Dataset.__getitem__(self, index)
#     153     cut_model= self.transform(cut_model)
#     154     vessel_model = self.transform(vessel_model)
# --> 156 label_return = self.label[index]
#     159 return vessel_model,cut_model,label_return
#
# IndexError: index 532 is out of bounds for dimension 0 with size 0

# %%
file = "\\C0006"
model_list = []
for model_name in list1[:]:
    file = model_name[:-4]
    Vessel_root_file = Vessel_root + "\\" + file + ".vtp"
    
    IA_name_cut1 = ""
    IA_name_dome = ""
    for IA_model in list2:
        
        if file in IA_model and "cut1" in IA_model and file not in IA_name_cut1:
            print("find:" + IA_model)
            IA_name_cut1 = IA_model
        elif file.split("_")[0] in IA_model and "cut1" in IA_model and IA_name_cut1 == "":
            IA_name_cut1 = IA_model
            
        if file in IA_model and "dome" in IA_model and file not in IA_name_dome:
            IA_name_dome = IA_model
        elif file.split("_")[0] in IA_model and "dome" in IA_model and IA_name_dome == "":
            IA_name_dome = IA_model
            
        if IA_name_cut1 != "" and IA_name_dome != "" and file in IA_name_cut1 and file in IA_name_dome:
            break
            
    print(IA_name_cut1)
    IA_root_file = os.path.join(IA_root,IA_name_cut1)
    modelcov_vtp = True
    if IA_name_cut1 != "" and IA_name_dome!= "":
        modelcov_vtp = vtp_to_point_cloud_cutvessel(Vessel_root_file,IA_root_file)
    if modelcov_vtp == False:
        print("Can not crop: " + file)
        print("Vessel root name: " + Vessel_root_file)
        print("IA root name: " + IA_root_file)
        break
         #o3d.visualization.draw_geometries([modelcov_vtp])
    else:
        model_list.append(modelcov_vtp)
# Out:
# find:ANSYS_UNIGE_09_cut1.vtp
# ANSYS_UNIGE_09_cut1.vtp
# find:ANSYS_UNIGE_16_cut1.vtp
# ANSYS_UNIGE_16_cut1.vtp
# find:ANSYS_UNIGE_17_10_cut1.vtp
# ANSYS_UNIGE_17_10_cut1.vtp
# find:ANSYS_UNIGE_27_cut1.vtp
# ANSYS_UNIGE_27_cut1.vtp
# find:ANSYS_UNIGE_28_269_cut1.vtp
# ANSYS_UNIGE_28_269_cut1.vtp
# find:ANSYS_UNIGE_30_612_cut1.vtp
# ANSYS_UNIGE_30_612_cut1.vtp
# find:ANSYS_UNIGE_30_614_cut1.vtp
# ANSYS_UNIGE_30_614_cut1.vtp
# find:ANSYS_UNIGE_33_628_cut1.vtp
# ANSYS_UNIGE_33_628_cut1.vtp
# find:ANSYS_UNIGE_33_631_cut1.vtp
# ANSYS_UNIGE_33_631_cut1.vtp
# find:ANSYS_UNIGE_34_cut1.vtp
# ANSYS_UNIGE_34_cut1.vtp
# find:ANSYS_UNIGE_35_cut1.vtp
# ANSYS_UNIGE_35_cut1.vtp
# find:C0001_cut1.vtp
# C0001_cut1.vtp
# find:C0002_cut1.vtp
# C0002_cut1.vtp
# find:C0003_cut1.vtp
# C0003_cut1.vtp
# find:C0005_cut1.vtp
# C0005_cut1.vtp
# find:C0006_cut1.vtp
# C0006_cut1.vtp
# find:C0007a_cut1.vtp
# C0007a_cut1.vtp
# find:C0008_cut1.vtp
# C0008_cut1.vtp
# find:C0009_cut1.vtp
# C0009_cut1.vtp
# find:C0010_cut1.vtp
# C0010_cut1.vtp
# find:C0011_cut1.vtp
# C0011_cut1.vtp
# find:C0012_cut1.vtp
# C0012_cut1.vtp
# find:C0013_cut1.vtp
# C0013_cut1.vtp
# find:C0014_cut1.vtp
# C0014_cut1.vtp
# find:C0015_cut1.vtp
# C0015_cut1.vtp
# find:C0016_cut1.vtp
# C0016_cut1.vtp
# find:C0017_cut1.vtp
# C0017_cut1.vtp
# find:C0018_cut1.vtp
# C0018_cut1.vtp
# find:C0019_cut1.vtp
# C0019_cut1.vtp
# find:C0020_cut1.vtp
# C0020_cut1.vtp
# find:C0021_cut1.vtp
# C0021_cut1.vtp
# find:C0023_cut1.vtp
# C0023_cut1.vtp
# p314_Fw0TEgMNCx8fBBUcFxgJCRQL_cut1.vtp
# find:p315_FREbDxURDBEaCwMWFxEHCxAB_cut1.vtp
# p315_FREbDxURDBEaCwMWFxEHCxAB_cut1.vtp
# find:p316_Ag4WExkPBwQJGwkLAAgJEBAC_cut1.vtp
# p316_Ag4WExkPBwQJGwkLAAgJEBAC_cut1.vtp
# find:p317_HRQeDRUaDBQfCQMdHxQCCRAK_cut1.vtp
# p317_HRQeDRUaDBQfCQMdHxQCCRAK_cut1.vtp
# find:p319_EQ8WGxEFEx8dARwOHwAPCxEC_cut1.vtp
# p319_EQ8WGxEFEx8dARwOHwAPCxEC_cut1.vtp
# find:p320_FAQRAAIMFxcSBhgKEQAcARAO_cut1.vtp
# p320_FAQRAAIMFxcSBhgKEQAcARAO_cut1.vtp
# find:p321_BA4ACBEGGx8cFw8OHAgaCgcR_BA_cut1.vtp
# p321_BA4ACBEGGx8cFw8OHAgaCgcR_BA_cut1.vtp
# find:p322_BA4ACBEGGz4jLCUuDA4cDBQW_cut1.vtp
# p322_BA4ACBEGGz4jLCUuDA4cDBQW_cut1.vtp
# find:p323_HggVBhUEGx8aAgEKHggADBIf_cut1.vtp
# p323_HggVBhUEGx8aAgEKHggADBIf_cut1.vtp
# find:p324_GgARAhEaFh8SBgUOAAUEBBYb_cut1.vtp
# p324_GgARAhEaFh8SBgUOAAUEBBYb_cut1.vtp
# find:p325_GwAcBA4JHAQYBAgKGQAAAB4Z_cut1.vtp
# p325_GwAcBA4JHAQYBAgKGQAAAB4Z_cut1.vtp
# find:p326_HA4HDR8dDA4GCQkaHg4bCRoN_1_cut1.vtp
# p326_HA4HDR8dDA4GCQkaHg4bCRoN_1_cut1.vtp
# find:p327_BggeDREGBwQFBBgGHg0PCwAd_cut1.vtp
# p327_BggeDREGBwQFBBgGHg0PCwAd_cut1.vtp
# find:p329_HQ4ADBkEHgQNChQCGw0CABgX_cut1.vtp
# p329_HQ4ADBkEHgQNChQCGw0CABgX_cut1.vtp
# find:p330_FAQDFBkMBh8WFBMGFhUKAAQN_cut1.vtp
# p330_FAQDFBkMBh8WFBMGFhUKAAQN_cut1.vtp
# find:p331_Ag4BBAINHBINChUKAAQAFgcX_cut1.vtp
# p331_Ag4BBAINHBINChUKAAQAFgcX_cut1.vtp
# find:p333_AhQdDQMWBw4fFhQaHQ0dFwAX_cut1.vtp
# p333_AhQdDQMWBw4fFhQaHQ0dFwAX_cut1.vtp
# find:p334_FwAHBRkGDAAGAQ8BFQAbARwW_cut1.vtp
# p334_FwAHBRkGDAAGAQ8BFQAbARwW_cut1.vtp
# find:p336_EwkTDxUSDAkSCwMVEQkPCxAC_cut1.vtp
# p336_EwkTDxUSDAkSCwMVEQkPCxAC_cut1.vtp
# find:p337_FwQdExcNAR8WChQIFxIJABoK_LICA_cut1.vtp
# p337_FwQdExcNAR8WChQIFxIJABoK_LICA_cut1.vtp
# find:p338_FwQdExcNAR8WChQIFxIJABoK_RICA_cut1.vtp
# p338_FwQdExcNAR8WChQIFxIJABoK_RICA_cut1.vtp
# find:p339_Ag4fAB4WHQwSCxQAHwAAFxoV_cut1.vtp
# p339_Ag4fAB4WHQwSCxQAHwAAFxoV_cut1.vtp
# find:p340_HRQUFRkLDBQVEQ8MHxQIERwb_cut1.vtp
# p340_HRQUFRkLDBQVEQ8MHxQIERwb_cut1.vtp
# find:p341_HRQcEhMADBQdFgUHHxQAFhYQ_cut1.vtp
# p341_HRQcEhMADBQdFgUHHxQAFhYQ_cut1.vtp
# find:p342_AAgcCR83HgQaEQMRGw8GCioU_cut1.vtp
# p342_AAgcCR83HgQaEQMRGw8GCioU_cut1.vtp
# find:p343_AgARBB4NBh8SBgMBFxUcBBYd_cut1.vtp
# p343_AgARBB4NBh8SBgMBFxUcBBYd_cut1.vtp
# find:p344_AA4UBxUcDA4VAwMbAg4IAxAM_cut1.vtp
# p344_AA4UBxUcDA4VAwMbAg4IAxAM_cut1.vtp
# find:p345_HRQeDRUaDBQfCQMdHxQCCRAK_cut1.vtp
# p345_HRQeDRUaDBQfCQMdHxQCCRAK_cut1.vtp
# find:p346_EwkTAhgJHg4NDQcMGgACChYQ_cut1.vtp
# p346_EwkTAhgJHg4NDQcMGgACChYQ_cut1.vtp
# find:p347_FAQEBBwJCx8WEwMDExgKAAMd_cut1.vtp
# p347_FAQEBBwJCx8WEwMDExgKAAMd_cut1.vtp
# find:p348_Eg4VDwUMEx8cAggaFgAMChIW_cut1.vtp
# p348_Eg4VDwUMEx8cAggaFgAMChIW_cut1.vtp
# find:p349_GwgeCBMWGw0aBg0GHggNDhwU_1_cut1.vtp
# p349_GwgeCBMWGw0aBg0GHggNDhwU_1_cut1.vtp
# find:p351_HQQaCA4NGggeAA4GHwQGDBgd_cut1.vtp
# p351_HQQaCA4NGggeAA4GHwQGDBgd_cut1.vtp
# find:p352_FggEAAoWGxcSHwAGBAAUAxwO_cut1.vtp
# p352_FggEAAoWGxcSHwAGBAAUAxwO_cut1.vtp
# find:p353_EggcChUaBh8aCw0KABUMDBsT_RICA_cut1.vtp
# p353_EggcChUaBh8aCw0KABUMDBsT_RICA_cut1.vtp
# find:p354_ERMIAA4aCAASFxwOExMUBBQK_cut1.vtp
# p354_ERMIAA4aCAASFxwOExMUBBQK_cut1.vtp
# find:p355_EhMXFQ4aFxURFwMbEBMLERcK_cut1.vtp
# p355_EhMXFQ4aFxURFwMbEBMLERcK_cut1.vtp
# find:p356_EwAcCAYNCB8SCw8ZFxsNBBsR_cut1.vtp
# p356_EwAcCAYNCB8SCw8ZFxsNBBsR_cut1.vtp
# find:p357_EhMTDxQHHB8BBAgLHQ8MFxQW_cut1.vtp
# p357_EhMTDxQHHB8BBAgLHQ8MFxQW_cut1.vtp
# find:p358_HAQaDxgNABMNAA4BGgQcFxkd_cut1.vtp
# p358_HAQaDxgNABMNAA4BGgQcFxkd_cut1.vtp
# find:p359_ExMXGA4aFxgQFwMWERMLHBYK_cut1.vtp
# p359_ExMXGA4aFxgQFwMWERMLHBYK_cut1.vtp
# find:p360_AA4RCR8GDA4QDQkBAg4NDRoW_1_cut1.vtp
# find:p482_AwAaCAQBDAAbDBIGAQAGDAER_cut1.vtp
# p482_AwAaCAQBDAAbDBIGAQAGDAER_cut1.vtp
# find:p483_CQABEhkGDAAAFg8BCwAdFhwW_1_cut1.vtp
# p483_CQABEhkGDAAAFg8BCwAdFhwW_1_cut1.vtp
# find:p484_FwgADhQWGxMcAQEGAA4KAhwK_cut1.vtp
# p484_FwgADhQWGxMcAQEGAA4KAhwK_cut1.vtp
# find:p485_FwkXAwINHAQUEBURGgQMFxAW_cut1.vtp
# p485_FwkXAwINHAQUEBURGgQMFxAW_cut1.vtp
# find:p486_AwQAFxEBAR8WFxAOGxIdAAcO_cut1.vtp
# p486_AwQAFxEBAR8WFxAOGxIdAAcO_cut1.vtp
# find:p487_BwAVBB4WEwYWCxEOFQQAEhQf_cut1.vtp
# p487_BwAVBB4WEwYWCxEOFQQAEhQf_cut1.vtp
# find:p488_BAkbBAIRDAkaABQWBgkHAAcB_LV_cut1.vtp
# p488_BAkbBAIRDAkaABQWBgkHAAcB_LV_cut1.vtp
# find:p489_BAkbBAIRDAkaABQWBgkHAAcB_LICA_cut1.vtp
# p489_BAkbBAIRDAkaABQWBgkHAAcB_LICA_cut1.vtp
# find:p490_EhMHDx4NAB8BEAgBFxMMFwAW_1_cut1.vtp
# p490_EhMHDx4NAB8BEAgBFxMMFwAW_1_cut1.vtp
# find:p491_EgQcFxUGBxUaGwMBBAQAEAER_RICA_1_cut1.vtp
# p491_EgQcFxUGBxUaGwMBBAQAEAER_RICA_1_cut1.vtp
# find:p492_EgQcFxUGBxUaGwMBBAQAEAER_LICA_cut1.vtp
# p492_EgQcFxUGBxUaGwMBBAQAEAER_LICA_cut1.vtp
# find:p493_AgQbEi8aGwMWDBQADAQHFioK_a_cut1.vtp
# p493_AgQbEi8aGwMWDBQADAQHFioK_a_cut1.vtp
# find:p494_FwARCR8dFh8SBg4ABwUJBBYQ_b_cut1.vtp
# p494_FwARCR8dFh8SBg4ABwUJBBYQ_b_cut1.vtp
# find:p495_AAQAExkGDAQBFw8BAgQcFxwW_1_cut1.vtp
# p495_AAQAExkGDAQBFw8BAgQcFxwW_1_cut1.vtp
# find:p496_HQgeCRkcDAgfDQ8bHwgCDRwM_cut1.vtp
# p496_HQgeCRkcDAgfDQ8bHwgCDRwM_cut1.vtp
# find:p497_AwIaCBUbAR8QDQ8KARIdBh0R_cut1.vtp
# p497_AwIaCBUbAR8QDQ8KARIdBh0R_cut1.vtp
# find:p498_Fw4fBAoWHQwWHwEAHwQUAhoV_LICA_cut1.vtp
# p498_Fw4fBAoWHQwWHwEAHwQUAhoV_LICA_cut1.vtp
# find:p499_Fw4fBAoWHQwWHwEAHwQUAhoV_RICA_1_cut1.vtp
# p499_Fw4fBAoWHQwWHwEAHwQUAhoV_RICA_1_cut1.vtp
# find:p500_FAAtEhkEBAANBDkcGw0YBBEZ_cut1.vtp
# p500_FAAtEhkEBAANBDkcGw0YBBEZ_cut1.vtp
# find:p501_GAQWCBcNAB8WAQ8IFxMGABER_cut1.vtp
# p501_GAQWCBcNAB8WAQ8IFxMGABER_cut1.vtp
# p548_FAAtDQUSDAAsCRMVFgAxCQAC_LICA_cut1.vtp
# find:p549_AwAeAA4JHgAABAoOAQACBAYZ_TB_cut1.vtp
# p549_AwAeAA4JHgAABAoOAQACBAYZ_TB_cut1.vtp
# find:p550_Gw4aDwQHAhENCg4BBg4eFR4X_LICA_cut1.vtp
# p550_Gw4aDwQHAhENCg4BBg4eFR4X_LICA_cut1.vtp
# find:p551_EwkdAxESDAkcBwcVEQkBBxQC_RMCA_1_cut1.vtp
# p551_EwkdAxESDAkcBwcVEQkBBxQC_RMCA_1_cut1.vtp
# find:p552_AwkTAxEGGx8bBAQOHAgdDRQa_RICA_1_cut1.vtp
# p552_AwkTAxEGGx8bBAQOHAgdDRQa_RICA_1_cut1.vtp
# find:p553_FxMTDxQCFwAdGxQOHAUEABQW_RICA_1_cut1.vtp
# p553_FxMTDxQCFwAdGxQOHAUEABQW_RICA_1_cut1.vtp
# find:p554_AwQAFxEBAR8WFxAOGxIdAAcO_RICA_cut1.vtp
# p554_AwQAFxEBAR8WFxAOGxIdAAcO_RICA_cut1.vtp
# find:p555_AAQAExkGDAQBFw8BAgQcFxwW_TB_cut1.vtp
# p555_AAQAExkGDAQBFw8BAgQcFxwW_TB_cut1.vtp
# find:SNF00000024_cut1.vtp
# SNF00000024_cut1.vtp
# find:SNF00000026_cut1.vtp
# SNF00000026_cut1.vtp
# find:SNF00000027_cut1.vtp
# SNF00000027_cut1.vtp
# find:SNF00000036_01_1_cut1.vtp
# SNF00000036_01_1_cut1.vtp
# find:SNF00000036_02_2_cut1.vtp
# SNF00000036_02_2_cut1.vtp
# find:SNF00000048_cut1.vtp
# SNF00000048_cut1.vtp
# find:SNF00000049_01_1_cut1.vtp
# SNF00000049_01_1_cut1.vtp
# SNF00000049_01_1_cut1.vtp
# SNF00000049_01_1_cut1.vtp
# find:SNF00000054_01_1_cut1.vtp
# SNF00000054_01_1_cut1.vtp
# find:SNF00000055_cut1.vtp
# SNF00000055_cut1.vtp
# find:SNF00000059_cut1.vtp
# SNF00000059_cut1.vtp
# find:SNF00000063_cut1.vtp
# SNF00000063_cut1.vtp
# find:SNF00000070_cut1.vtp
# SNF00000070_cut1.vtp
# find:SNF00000071_cut1.vtp
# SNF00000071_cut1.vtp
# find:SNF00000074_cut1.vtp
# SNF00000074_cut1.vtp
# find:SNF00000077_01_1_cut1.vtp
# SNF00000077_01_1_cut1.vtp
# find:SNF00000082_cut1.vtp
# SNF00000082_cut1.vtp
# find:SNF00000090_cut1.vtp
# SNF00000090_cut1.vtp
# find:SNF00000094_01_1_cut1.vtp
# SNF00000094_01_1_cut1.vtp
# find:SNF00000095_cut1.vtp
# SNF00000095_cut1.vtp
# find:SNF00000100_cut1.vtp
# SNF00000100_cut1.vtp
# find:SNF00000114_cut1.vtp
# SNF00000114_cut1.vtp
# find:SNF00000125_cut1.vtp
# SNF00000125_cut1.vtp
# find:SNF00000126_cut1.vtp
# SNF00000126_cut1.vtp
# find:SNF00000127_cut1.vtp
# SNF00000127_cut1.vtp
# find:SNF00000128_cut1.vtp
# SNF00000128_cut1.vtp
# find:SNF00000130_01_1sib_cut1.vtp
# SNF00000130_01_1sib_cut1.vtp
# find:SNF00000134_cut1.vtp
# SNF00000134_cut1.vtp
# find:SNF00000135_cut1.vtp
# SNF00000135_cut1.vtp
# find:SNF00000137_01_1_cut1.vtp
# SNF00000137_01_1_cut1.vtp
# find:SNF00000141_cut1.vtp
# SNF00000141_cut1.vtp
# find:SNF00000142_01_1sib_cut1.vtp
# SNF00000142_01_1sib_cut1.vtp
# find:SNF00000143_01_1_cut1.vtp
# SNF00000143_01_1_cut1.vtp
# find:SNF00000144_cut1.vtp
# SNF00000144_cut1.vtp
# find:SNF00000146_cut1.vtp
# SNF00000146_cut1.vtp
# find:SNF00000148_cut1.vtp
# SNF00000148_cut1.vtp
# find:SNF00000152_cut1.vtp
# SNF00000152_cut1.vtp
# find:SNF00000154_cut1.vtp
# SNF00000154_cut1.vtp
# find:SNF00000155_cut1.vtp
# SNF00000155_cut1.vtp
# find:SNF00000173_cut1.vtp
# SNF00000173_cut1.vtp
# find:SNF00000175_cut1.vtp
# SNF00000175_cut1.vtp
# find:SNF00000185_cut1.vtp
# SNF00000185_cut1.vtp
# find:SNF00000186_cut1.vtp
# SNF00000186_cut1.vtp
# find:SNF00000189_1sib_cut1.vtp
# SNF00000189_1sib_cut1.vtp
# find:SNF00000208_01_1_cut1.vtp
# SNF00000208_01_1_cut1.vtp
# find:SNF00000215_cut1.vtp
# SNF00000215_cut1.vtp
# find:SNF00000227_cut1.vtp
# SNF00000227_cut1.vtp
# find:SNF00000228_01_1_cut1.vtp
# SNF00000228_01_1_cut1.vtp
# find:SNF00000244_cut1.vtp
# SNF00000244_cut1.vtp
# find:SNF00000252_cut1.vtp
# SNF00000252_cut1.vtp
# find:SNF00000259_01_1_cut1.vtp
# SNF00000259_01_1_cut1.vtp
# find:SNF00000261_cut1.vtp
# SNF00000261_cut1.vtp
# find:SNF00000267_cut1.vtp
# SNF00000267_cut1.vtp
# find:SNF00000270_cut1.vtp
# SNF00000270_cut1.vtp
# find:SNF00000273_cut1.vtp
# SNF00000273_cut1.vtp
# find:SNF00000284_cut1.vtp
# SNF00000284_cut1.vtp
# find:SNF00000285_cut1.vtp
# SNF00000285_cut1.vtp
# find:SNF00000286_cut1.vtp
# SNF00000286_cut1.vtp
# find:SNF00000294_01_1_cut1.vtp
# SNF00000294_01_1_cut1.vtp
# find:SNF00000303_cut1.vtp
# SNF00000303_cut1.vtp
# find:SNF00000309_cut1.vtp
# SNF00000309_cut1.vtp
# find:SNF00000316_cut1.vtp
# SNF00000316_cut1.vtp
# find:SNF00000332_cut1.vtp
# SNF00000332_cut1.vtp
# find:SNF00000335_cut1.vtp
# SNF00000335_cut1.vtp
# find:SNF00000338_cut1.vtp
# SNF00000338_cut1.vtp
# find:SNF00000344_cut1.vtp
# SNF00000344_cut1.vtp
# find:SNF00000350_cut1.vtp
# SNF00000350_cut1.vtp
# find:SNF00000357_cut1.vtp
# SNF00000357_cut1.vtp
# find:SNF00000360_01_1_cut1.vtp
# SNF00000581_cut1.vtp
# find:SNF00000591_cut1.vtp
# SNF00000591_cut1.vtp
# find:SNF00000592_01_1_cut1.vtp
# SNF00000592_01_1_cut1.vtp
# find:SNF00000592_03_3_cut1.vtp
# SNF00000592_03_3_cut1.vtp
# find:SNF00000596_cut1.vtp
# SNF00000596_cut1.vtp
# find:SNF00000605_cut1.vtp
# SNF00000605_cut1.vtp
# find:SNF00000606_cut1.vtp
# SNF00000606_cut1.vtp
# find:SNF00000607_01_1_cut1.vtp
# SNF00000607_01_1_cut1.vtp
# find:SNF00000614_cut1.vtp
# SNF00000614_cut1.vtp
# find:SNF00000617_cut1.vtp
# SNF00000617_cut1.vtp
# find:UPF_P0001.00_ID1_cut1.vtp
# UPF_P0001.00_ID1_cut1.vtp
# find:UPF_P0003.00_ID1_cut1.vtp
# UPF_P0003.00_ID1_cut1.vtp
# find:UPF_P0012.00_ID1_cut1.vtp
# UPF_P0012.00_ID1_cut1.vtp
# find:UPF_P0013.00_ID1_cut1.vtp
# UPF_P0013.00_ID1_cut1.vtp
# find:UPF_P0016.00_ID1_cut1.vtp
# UPF_P0016.00_ID1_cut1.vtp
# find:UPF_P0019.00_ID1_cut1.vtp
# UPF_P0019.00_ID1_cut1.vtp
# find:UPF_P0024.00_ID1_cut1.vtp
# UPF_P0024.00_ID1_cut1.vtp
# find:UPF_P0029.00_ID1_cut1.vtp
# UPF_P0029.00_ID1_cut1.vtp
# find:UPF_P0031.00_ID1_cut1.vtp
# UPF_P0031.00_ID1_cut1.vtp
# find:UPF_P0034.00_ID1_cut1.vtp
# UPF_P0034.00_ID1_cut1.vtp
# find:UPF_P0035.00_ID1_cut1.vtp
# UPF_P0035.00_ID1_cut1.vtp
# find:UPF_P0038.00_ID2_cut1.vtp
# UPF_P0038.00_ID2_cut1.vtp
# find:UPF_P0042.00_ID1_cut1.vtp
# UPF_P0042.00_ID1_cut1.vtp
# find:UPF_P0042.00_ID2_cut1.vtp
# UPF_P0042.00_ID2_cut1.vtp
# find:UPF_P0043.00_ID1_cut1.vtp
# UPF_P0043.00_ID1_cut1.vtp
# find:UPF_P0044.00_ID1_cut1.vtp
# UPF_P0044.00_ID1_cut1.vtp
# find:UPF_P0046.00_ID1_cut1.vtp
# UPF_P0046.00_ID1_cut1.vtp
# find:UPF_P0048.00_ID1_cut1.vtp
# UPF_P0048.00_ID1_cut1.vtp
# find:UPF_P0053.00_ID1_cut1.vtp
# UPF_P0053.00_ID1_cut1.vtp
# find:UPF_P0056.00_ID1_cut1.vtp
# UPF_P0056.00_ID1_cut1.vtp
# find:UPF_P0057.00_ID1_cut1.vtp
# UPF_P0057.00_ID1_cut1.vtp
# find:UPF_P0058.00_ID1_cut1.vtp
# UPF_P0058.00_ID1_cut1.vtp
# find:UPF_P0060.00_ID1_cut1.vtp
# UPF_P0060.00_ID1_cut1.vtp
# find:UPF_P0061.00_ID1_cut1.vtp
# UPF_P0061.00_ID1_cut1.vtp
# find:UPF_P0065.00_ID1_cut1.vtp
# UPF_P0065.00_ID1_cut1.vtp
# find:UPF_P0067.00_ID1_cut1.vtp
# UPF_P0067.00_ID1_cut1.vtp
# find:UPF_P0070.00_ID1_cut1.vtp
# UPF_P0070.00_ID1_cut1.vtp
# find:UPF_P0076.00_ID1_cut1.vtp
# UPF_P0076.00_ID1_cut1.vtp
# find:UPF_P0078.00_ID1_cut1.vtp
# UPF_P0078.00_ID1_cut1.vtp
# find:UPF_P0082.00_ID1_cut1.vtp
# UPF_P0082.00_ID1_cut1.vtp
# find:UPF_P0084.00_ID1_cut1.vtp
# UPF_P0084.00_ID1_cut1.vtp
# find:UPF_P0089.00_ID2_cut1.vtp
# UPF_P0089.00_ID2_cut1.vtp
# find:UPF_P0090.00_ID1_cut1.vtp
# UPF_P0090.00_ID1_cut1.vtp
# find:UPF_P0092.00_ID1_cut1.vtp
# UPF_P0092.00_ID1_cut1.vtp
# find:UPF_P0098.00_ID2_cut1.vtp
# UPF_P0098.00_ID2_cut1.vtp
# find:UPF_P0099.00_ID1_cut1.vtp
# UPF_P0099.00_ID1_cut1.vtp
# find:UPF_P0103.00_ID1_cut1.vtp
# UPF_P0103.00_ID1_cut1.vtp
# find:UPF_P0106.00_ID1_cut1.vtp
# UPF_P0106.00_ID1_cut1.vtp
# find:UPF_P0108.00_ID1_cut1.vtp
# UPF_P0108.00_ID1_cut1.vtp
# find:UPF_P0117.00_ID1_cut1.vtp
# UPF_P0117.00_ID1_cut1.vtp
# find:UPF_P0120.00_ID2_cut1.vtp
# UPF_P0120.00_ID2_cut1.vtp
# find:UPF_P0123.00_ID1_cut1.vtp
# UPF_P0123.00_ID1_cut1.vtp
# find:UPF_P0129.00_ID1_cut1.vtp
# UPF_P0129.00_ID1_cut1.vtp
# find:UPF_P0134.00_ID1_cut1.vtp
# UPF_P0134.00_ID1_cut1.vtp
# find:UPF_P0135.00_ID1_cut1.vtp
# UPF_P0135.00_ID1_cut1.vtp
# find:UPF_P0140.00_ID1_cut1.vtp
# UPF_P0140.00_ID1_cut1.vtp
# find:UPF_P0142.00_ID1_cut1.vtp
# UPF_P0142.00_ID1_cut1.vtp
# find:UPF_P0143.00_ID1_cut1.vtp
# UPF_P0143.00_ID1_cut1.vtp
# find:UPF_P0148.00_ID1_cut1.vtp
# UPF_P0148.00_ID1_cut1.vtp
# find:UPF_P0153.00_ID1_cut1.vtp
# UPF_P0153.00_ID1_cut1.vtp
# find:UPF_P0156.00_ID1_cut1.vtp
# UPF_P0156.00_ID1_cut1.vtp
# find:UPF_P0157.00_ID1_cut1.vtp
# UPF_P0157.00_ID1_cut1.vtp
# find:UPF_P0161.00_ID1_cut1.vtp
# UPF_P0161.00_ID1_cut1.vtp
# find:UPF_P0164.00_ID1_cut1.vtp
# UPF_P0164.00_ID1_cut1.vtp
# find:UPF_P0165.00_ID1_cut1.vtp
# UPF_P0165.00_ID1_cut1.vtp
# find:UPF_P0167.00_ID1_cut1.vtp
# UPF_P0167.00_ID1_cut1.vtp
# find:UPF_P0169.00_ID1_cut1.vtp
# UPF_P0169.00_ID1_cut1.vtp
# find:UPF_P0171.00_ID1_cut1.vtp
# UPF_P0171.00_ID1_cut1.vtp
# find:UPF_P0171.00_ID2_cut1.vtp
# UPF_P0171.00_ID2_cut1.vtp
# find:UPF_P0172.00_ID1_cut1.vtp
# UPF_P0172.00_ID1_cut1.vtp
# find:UPF_P0175.00_ID2_cut1.vtp
# UPF_P0175.00_ID2_cut1.vtp
# find:UPF_P0176.00_ID1_cut1.vtp
# UPF_P0176.00_ID1_cut1.vtp
# find:UPF_P0177.00_ID1_cut1.vtp
# UPF_P0177.00_ID1_cut1.vtp
# find:UPF_P0178.00_ID1_cut1.vtp
# UPF_P0178.00_ID1_cut1.vtp
# find:UPF_P0178.00_ID2_cut1.vtp
# UPF_P0178.00_ID2_cut1.vtp
# find:UPF_P0179.00_ID1_cut1.vtp
# UPF_P0179.00_ID1_cut1.vtp
# find:UPF_P0181.00_ID1_cut1.vtp
# UPF_P0181.00_ID1_cut1.vtp
# find:UPF_P0181.00_ID2_cut1.vtp
# UPF_P0181.00_ID2_cut1.vtp
# find:UPF_P0188.00_ID1_cut1.vtp
# UPF_P0188.00_ID1_cut1.vtp
# find:UPF_P0194.00_ID1_cut1.vtp
# UPF_P0194.00_ID1_cut1.vtp
# find:UPF_P0195.00_ID1_cut1.vtp
# UPF_P0195.00_ID1_cut1.vtp
# find:UPF_P0196.00_ID1_cut1.vtp
# UPF_P0196.00_ID1_cut1.vtp
# find:UPF_P0204.01_ID3_cut1.vtp
# UPF_P0204.01_ID3_cut1.vtp
# find:UPF_P0206.00_ID1_cut1.vtp
# UPF_P0206.00_ID1_cut1.vtp
# find:UPF_P0207.01_ID1_cut1.vtp
# UPF_P0207.01_ID1_cut1.vtp
# find:UPF_P0208.00_ID1_cut1.vtp
# UPF_P0208.00_ID1_cut1.vtp
# find:UPF_P0211.00_ID1_cut1.vtp
# UPF_P0211.00_ID1_cut1.vtp
# find:UPF_P0221.00_ID1_cut1.vtp
# UPF_P0221.00_ID1_cut1.vtp
# find:UPF_P0222.00_ID3_cut1.vtp
# UPF_P0222.00_ID3_cut1.vtp
# find:UPF_P0224.00_ID1_cut1.vtp
# UPF_P0224.00_ID1_cut1.vtp
# find:UPF_P0229.00_ID1_cut1.vtp
# UPF_P0229.00_ID1_cut1.vtp
# find:UPF_P0230.00_ID1_cut1.vtp
# UPF_P0230.00_ID1_cut1.vtp
# find:UPF_P0232.01_ID1_cut1.vtp
# UPF_P0232.01_ID1_cut1.vtp
# find:UPF_P0239.00_ID1_cut1.vtp
# UPF_P0239.00_ID1_cut1.vtp
# find:UPF_P0258.00_ID1_cut1.vtp
# UPF_P0258.00_ID1_cut1.vtp
# find:UPF_P0261.00_ID1_cut1.vtp
# UPF_P0261.00_ID1_cut1.vtp
# find:UPF_P0266.00_ID1_cut1.vtp
# UPF_P0266.00_ID1_cut1.vtp
# find:UPF_P0272.00_ID1_cut1.vtp
# UPF_P0272.00_ID1_cut1.vtp
# find:UPF_P0277.00_ID1_cut1.vtp
# UPF_P0277.00_ID1_cut1.vtp
# find:UPF_P0280.00_ID2_cut1.vtp
# UPF_P0280.00_ID2_cut1.vtp
# find:USFD_0054_cut1.vtp
# USFD_0054_cut1.vtp
# find:USFD_0055_cut1.vtp
# USFD_0055_cut1.vtp
# find:USFD_0056_cut1.vtp
# USFD_0056_cut1.vtp
# find:USFD_0057_cut1.vtp
# USFD_0057_cut1.vtp
# find:USFD_0058_cut1.vtp
# USFD_0058_cut1.vtp
# find:USFD_0059_cut1.vtp
# USFD_0059_cut1.vtp
# find:USFD_0060_cut1.vtp
# USFD_0060_cut1.vtp
# find:USFD_UNIGE_0001_cut1.vtp
# USFD_UNIGE_0001_cut1.vtp
# find:USFD_UNIGE_0007_cut1.vtp
# USFD_UNIGE_0007_cut1.vtp
# find:USFD_UNIGE_0017_cut1.vtp
# USFD_UNIGE_0017_cut1.vtp
# find:USFD_UNIGE_0023_cut1.vtp
# USFD_UNIGE_0023_cut1.vtp
# find:USFD_UNIGE_0027_cut1.vtp
# USFD_UNIGE_0027_cut1.vtp
# find:USFD_UNIGE_0029_cut1.vtp
# USFD_UNIGE_0029_cut1.vtp
# find:USFD_UNIGE_0033_cut1.vtp
# USFD_UNIGE_0033_cut1.vtp
# find:USFD_UNIGE_0034_cut1.vtp
# USFD_UNIGE_0034_cut1.vtp
# find:USFD_UNIGE_0037_cut1.vtp
# USFD_UNIGE_0037_cut1.vtp
# find:USFD_UNIGE_0038_cut1.vtp
# USFD_UNIGE_0038_cut1.vtp
# find:USFD_UNIGE_0042_cut1.vtp
# USFD_UNIGE_0042_cut1.vtp

# %%
print(len(list1),len(model_list))
print(model_list)
# Out:
# 682 682
# [PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points., PointCloud with 10000 points.,  ...

# %% [markdown]
# # PointNet model

# %%
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
#https://www.kaggle.com/code/balraj98/pointnet-for-3d-object-classification-pytorch/notebook
class Tnet(nn.Module):
    def __init__(self, k=3):
        super().__init__()
        self.k=k
        self.conv1 = nn.Conv1d(k,64,1)
        self.conv2 = nn.Conv1d(64,128,1)
        self.conv3 = nn.Conv1d(128,1024,1)
        self.fc1 = nn.Linear(1024,512)
        self.fc2 = nn.Linear(512,256)
        self.fc3 = nn.Linear(256,k*k)

        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(128)
        self.bn3 = nn.BatchNorm1d(1024)
        self.bn4 = nn.BatchNorm1d(512)
        self.bn5 = nn.BatchNorm1d(256)


    def forward(self, input):
        # input.shape == (bs,n,3)
        bs = input.size(0)
        xb = F.relu(self.bn1(self.conv1(input)))
        xb = F.relu(self.bn2(self.conv2(xb)))
        xb = F.relu(self.bn3(self.conv3(xb)))
        pool = nn.MaxPool1d(xb.size(-1))(xb)
        flat = nn.Flatten(1)(pool)
        xb = F.relu(self.bn4(self.fc1(flat)))
        xb = F.relu(self.bn5(self.fc2(xb)))

        #initialize as identity
        init = torch.eye(self.k, requires_grad=True).repeat(bs,1,1)
        if xb.is_cuda:
            init=init.cuda()
        matrix = self.fc3(xb).view(-1,self.k,self.k) + init
        return matrix


class Transform(nn.Module):
    def __init__(self):
        super().__init__()
        self.input_transform = Tnet(k=3)
        self.feature_transform = Tnet(k=64)
        self.conv1 = nn.Conv1d(3,64,1)

        self.conv2 = nn.Conv1d(64,128,1)
        self.conv3 = nn.Conv1d(128,1024,1)


        self.bn1 = nn.BatchNorm1d(64)
        self.bn2 = nn.BatchNorm1d(128)
        self.bn3 = nn.BatchNorm1d(1024)

    def forward(self, input):
        matrix3x3 = self.input_transform(input)
        # batch matrix multiplication
        xb = torch.bmm(torch.transpose(input,1,2), matrix3x3).transpose(1,2)

        xb = F.relu(self.bn1(self.conv1(xb)))

        matrix64x64 = self.feature_transform(xb)
        xb = torch.bmm(torch.transpose(xb,1,2), matrix64x64).transpose(1,2)

        xb = F.relu(self.bn2(self.conv2(xb)))
        xb = self.bn3(self.conv3(xb))
        xb = nn.MaxPool1d(xb.size(-1))(xb)
        output = nn.Flatten(1)(xb)
        return output, matrix3x3, matrix64x64

class PointNet(nn.Module):
    def __init__(self, classes = 10):
        super().__init__()
        self.transform = Transform()
        self.fc1 = nn.Linear(1024, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, classes)
        

        self.bn1 = nn.BatchNorm1d(512)
        self.bn2 = nn.BatchNorm1d(256)
        self.dropout = nn.Dropout(p=0.3)
        self.logsoftmax = nn.LogSoftmax(dim=1)

    def forward(self, input):
        xb, matrix3x3, matrix64x64 = self.transform(input)
        xb = F.relu(self.bn1(self.fc1(xb)))
        xb = F.relu(self.bn2(self.dropout(self.fc2(xb))))
        output = self.fc3(xb)
        return self.logsoftmax(output)

# %%
pointnet = PointNet()

# %%
#Train use 3d model use Pointnet

# %% [markdown]
# # PointNet ++

# %%
#https://github.com/charlesq34/pointnet2

# %%
import torch
class PointNetplus(nn.Module):
    def __init__(self, classes = 10):
        super().__init__()
        self.transform = Transform()
        
        self.fc1 = nn.Linear(2048, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, classes)
        

        self.bn1 = nn.BatchNorm1d(512)
        self.bn2 = nn.BatchNorm1d(256)
        self.dropout = nn.Dropout(p=0.3)
        self.logsoftmax = nn.LogSoftmax(dim=1)

    def forward(self, input1, input2):
        xb, matrix3x3, matrix64x64 = self.transform(input)
        xa, matrix3x3, matrix64x64 = self.transform(input1)
        xb, matrix3x3, matrix64x64 = self.transform(input2)
        xc = xa + xb
        xc = F.relu(self.bn1(self.fc1(xc)))
        xc = F.relu(self.bn2(self.dropout(self.fc2(xc))))
        output = self.fc3(xb)
        return self.logsoftmax(output)

# %%
#Train use 3d model use Pointnet
