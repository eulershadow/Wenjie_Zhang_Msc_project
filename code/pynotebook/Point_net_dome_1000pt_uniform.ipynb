# %%
import vtk
import os
import numpy as np
import itertools
import math, random
import data_process_ml
random.seed = 42
import copy

import torch
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
from torchvision import transforms, utils

import scipy.spatial.distance
# import plotly.graph_objects as go
# import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
device = "cuda"

# %% [markdown]
# load the dataset

# %%
root = "..\..\msc_data\models-v1.0\models"
IA = "aneurysms\\remeshed\\area-001"
Vessel = "vessels\\remeshed\\area-001"
IA_root = os.path.join(root,IA)
Vessel_root = os.path.join(root,Vessel)
list1 = os.listdir(Vessel_root)
list2 = os.listdir(IA_root)

# %%
morpho_path = ".\AneuX\data-v1.0\data\morpho-per-cut.csv"
patient_path = ".\AneuX\data-v1.0\data\clinical.csv"
morpho_data_patient = data_process_ml.read_and_combine_data(morpho_path,patient_path)
merged_dataset = data_process_ml.encode_column(morpho_data_patient)
merged_dataset = data_process_ml.drop_columns(merged_dataset)
morpho_data_cut1,morpho_data_dome = data_process_ml.output_cut1anddome(merged_dataset)
# Out:
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_dome.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)

# %%
import pandas as pd
from pointnetfunct.PointNet_dataset import Aneux_Dataset_load
df = pd.DataFrame()
# Aneux_Dataset = Aneuxmodel_Dataset(root = root,
#                                    df=morpho_data_patient[morpho_data_patient["cuttype"] == "dome"],
#                                    transform = transforms.ToTensor(),
#                                    mesh = "area-001",
#                                    cuttype = "dome",
#                                    crop = False)

Aneux_Dataset = Aneux_Dataset_load('./Aneux_Dataset_1000pt_sample_600train.pt')
Aneux_Dataset_test = Aneux_Dataset_load('./Aneux_Dataset_1000pt_sample_100test.pt')
Aneux_Dataset.paraout = True
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_dome.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_dome.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)

# %%
from torch.utils.data import Subset

seed = torch.seed()
print(seed)
torch.manual_seed(32381912834800)
#12984260249700
#16912914325100

train_size = int(len(Aneux_Dataset) * 0.8) # 80% training data
valid_size = len(Aneux_Dataset) - train_size
train_data, valid_data = random_split(Aneux_Dataset, [train_size, valid_size])

train_loader = torch.utils.data.DataLoader(
    train_data,
    batch_size=50,
    shuffle=True,
    #num_workers=2, 
    pin_memory=True
)

valid_loader = torch.utils.data.DataLoader(
    valid_data,
    batch_size=50, # Forward pass only so batch size can be larger
    shuffle=False,
    #num_workers=2, 
    pin_memory=True
)

test_loader = torch.utils.data.DataLoader(
    Aneux_Dataset_test,
    batch_size=50, # Forward pass only so batch size can be larger
    shuffle=False,
    #num_workers=2, 
    pin_memory=True
)
# Out:
# 737125997400

# %% [markdown]
# Test vaildation

# %% [markdown]
# # PointNet model

# %%
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from
# epoch: 91 training loss:  0.681 training accuracy:  65.6%  test loss:  0.668 test accuracy:  65.4%
# epoch: 92 training loss:  0.694 training accuracy:  63.4%  test loss:  0.683 test accuracy:  63.8%
# epoch: 93 training loss:  0.686 training accuracy:  66.3%  test loss:  0.677 test accuracy:  66.9%
# epoch: 94 training loss:  0.670 training accuracy:  65.0%  test loss:  0.692 test accuracy:  65.4%
# epoch: 95 training loss:  0.679 training accuracy:  63.2%  test loss:  0.658 test accuracy:  71.7%
# epoch: 96 training loss:  0.686 training accuracy:  66.9%  test loss:  0.690 test accuracy:  65.4%
# epoch: 97 training loss:  0.681 training accuracy:  65.2%  test loss:  0.687 test accuracy:  66.1%
# epoch: 98 training loss:  0.690 training accuracy:  66.3%  test loss:  0.693 test accuracy:  67.7%
# epoch: 99 training loss:  0.684 training accuracy:  64.6%  test loss:  0.677 test accuracy:  69.3%
# PointNet(
#   (transform): Transform(
#     (input_transform): Tnet(
#       (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=9, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (feature_transform): Tnet(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=4096, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=3, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=64, bias=True)
#     (fc4): Linear(in_features=64, out_features=128, bias=True)
#     (fc5): Linear(in_features=128, out_features=1024, bias=True)
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=2, bias=True)
#   (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (logsoftmax): LogSoftmax(dim=1)
#   (loss_fn): CrossEntropyLoss()
# )

# %%
def show_graph(path,device):
    data = torch.load(path, map_location=device) # by doing map_location=device, you can use trained model on GPU --> to test on CPU
    statsrec = data["stats"]
    fig, ax1 = plt.subplots()
    plt.plot(statsrec[0], 'r', label = 'training loss', )
    plt.plot(statsrec[2], 'g', label = 'test loss' )
    plt.legend(loc='lower right')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training and test loss, and test accuracy')
    ax2=ax1.twinx()
    ax2.plot(statsrec[1], 'm', label = 'training accuracy')
    ax2.plot(statsrec[3], 'b', label = 'test accuracy')
    ax2.set_ylabel('accuracy')
    plt.legend(loc='upper right')
    fig.savefig("roc.svg")
    plt.show()

# %%
device = torch.device('cuda:0')
show_graph(path ="./result/dome_1000pt_unform_test.pt",device = "cuda")

# %%
model_path = "pointnet_dome_test.pth"
torch.save(pointnet.state_dict(), model_path)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import functions as fun
pointnet_copy = PointNet(classes=2)
model_path = "./pointnet_dome_unform_1000pt_test.pth"
load_model(pointnet_copy,model_path)
y_true = []
y_pred = []
y_pred_result = []
y_probs = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,_,_,labels in test_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels)
        y_probs.extend(outputs)

# %%
from pointnetfunct.evaluation import show_cm_dl,show_graph,print_values,draw_rocgraph

draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_pointnet_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_pointnet_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.57
# F1 score: 0.4266666666666667
# Rupture Recall: 0.36363636363636365
# Rupture Precision: 0.5161290322580645
# UnRupture Recall: 0.7321428571428571
# UnRupture Precision: 0.5942028985507246

# %%
y_true = []
y_pred = []
y_pred_result = []
y_probs = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,_,_,labels in valid_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels)
        y_probs.extend(outputs)

# %%
draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_pointnet_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_pointnet_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.6614173228346457
# F1 score: 0.42666666666666664
# Rupture Recall: 0.4
# Rupture Precision: 0.45714285714285713
# UnRupture Recall: 0.7816091954022989
# UnRupture Precision: 0.7391304347826086

# %% [markdown]
# Multi head

# %% [markdown]
# 2 multihead

# %%
import functions
from pointnetfunct.PointNet_struct import PointNet_2Multimodal_withDNN
from pointnetfunct.PointNet_trainingfunct import run_model_2multi_head_dnn
# epoch: 58 training loss:  0.700 training accuracy:  59.6%  test loss:  0.651 test accuracy:  64.6%
# epoch: 59 training loss:  0.664 training accuracy:  57.5%  test loss:  0.659 test accuracy:  66.1%
# epoch: 60 training loss:  0.694 training accuracy:  59.3%  test loss:  0.647 test accuracy:  65.4%
# epoch: 61 training loss:  0.684 training accuracy:  60.6%  test loss:  0.693 test accuracy:  60.6%
# epoch: 62 training loss:  0.675 training accuracy:  59.8%  test loss:  0.676 test accuracy:  65.4%
# epoch: 63 training loss:  0.677 training accuracy:  63.2%  test loss:  0.648 test accuracy:  66.1%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [15], line 5
#       3 from pointnetfunct.PointNet_trainingfunct import run_model_2multi_head_dnn
#       4 pointnet_mh = PointNet_2Multimodal_withDNN(classes=2)
# ----> 5 run_model_2multi_head_dnn(train_loader_input = train_loader,
#       6                         vaild_loader_input = valid_loader,
#       7                         nepochs = 100,
#       8                         modelnet = pointnet_mh,
#       9                         results_path = "./result",
#      10                         filename = "/2multimodel_uniform_1000pt_test.pt",
#      11                         model_name= "pointnet_2multimodal_uniform_1000pt_test.pth")
#
# File d:\Universityofleeds\MSC_PROG\Msc_project\code\pointnetfunct\PointNet_trainingfunct.py:549, in run_model_2multi_head_dnn(train_loader_input, vaild_loader_input, nepochs, modelnet, results_path, filename, transform, dataset, model_name)
#     547 inputs = inputs.squeeze(1).permute(0, 2, 1)
#     548 inputs2 = inputs2.squeeze(1).permute(0, 2, 1)
# --> 549 outputs = modelnet.forward(inputs,inputs3)
#     550 # accumulate data for accuracy
#     551 _, predicted = torch.max(outputs.data, 1)
#
# File d:\Universityofleeds\MSC_PROG\Msc_project\code\pointnetfunct\PointNet_struct.py:444, in PointNet_2Multimodal_withDNN.forward(self, input1, input2)
#     442 def forward(self, input1, input2):
#     443     #xb, matrix3x3, matrix64x64 = self.transform(input)
# --> 444     xa, matrix3x3, matrix64x64 = self.transform2(input1)
#     445     xb = self.transform3(input2)
#     448     xd = torch.cat((xa, xb), dim=1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File d:\Universityofleeds\MSC_PROG\Msc_project\code\pointnetfunct\PointNet_struct.py:241, in Transform_2Multi.forward(self, input)
#     237 xb = F.relu(self.bn1(self.conv1(xb)))
#     238 # xb = F.relu(self.bn4(self.fc1(xb)))
#     239 # xb = F.relu(self.bn5(self.fc2(xb)))
# --> 241 matrix64x64 = self.feature_transform(xb)
#     242 xb = torch.bmm(torch.transpose(xb,1,2), matrix64x64).transpose(1,2)
#     243 # print(xb.size())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File d:\Universityofleeds\MSC_PROG\Msc_project\code\pointnetfunct\PointNet_struct.py:39, in Tnet.forward(self, input)
#      37 init = torch.eye(self.k, requires_grad=True).repeat(bs,1,1)
#      38 if xb.is_cuda:
# ---> 39     init=init.cuda()
#      40 matrix = self.fc3(xb).view(-1,self.k,self.k) + init
#      41 return matrix
#
# KeyboardInterrupt:

# %%
from pointnetfunct.evaluation import show_graph
show_graph(path ="./result/2multimodel_uniform_1000pt_test.pt",device = "cuda",name = "1000pt_2branch_trainingtrend")

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import functions as fun
from pointnetfunct.PointNet_trainingfunct import load_model

pointnet_copy = PointNet_2Multimodal_withDNN(classes=2)
model_path = "./pointnet_2multimodal_uniform_1000pt_test.pth"
load_model(pointnet_copy,model_path)
y_true = []
y_pred = []
y_probs = []
y_pred_result = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,inputs_v2,inputs_v3,labels in test_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        inputs_v3 = inputs_v3.to(torch.float32)

        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v,inputs_v3)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) 
        y_probs.extend(outputs)
        
from pointnetfunct.evaluation import show_cm_dl,show_graph,print_values,draw_rocgraph

draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_2branch_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_2branch_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.54
# F1 score: 0.2580645161290322
# Rupture Recall: 0.18181818181818182
# Rupture Precision: 0.4444444444444444
# UnRupture Recall: 0.8214285714285714
# UnRupture Precision: 0.5609756097560976

# %%
pointnet_copy = PointNet_2Multimodal_withDNN(classes=2)
model_path = "./pointnet_2multimodal_uniform_1000pt_test.pth"
load_model(pointnet_copy,model_path)
y_true = []
y_pred = []
y_probs = []
y_pred_result = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,inputs_v2,inputs_v3,labels in valid_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        inputs_v3 = inputs_v3.to(torch.float32)

        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v,inputs_v3)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) 
        y_probs.extend(outputs)
        
from pointnetfunct.evaluation import show_cm_dl,show_graph,print_values,draw_rocgraph

draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_2branch_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_2branch_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.7165354330708661
# F1 score: 0.5135135135135136
# Rupture Recall: 0.475
# Rupture Precision: 0.5588235294117647
# UnRupture Recall: 0.8275862068965517
# UnRupture Precision: 0.7741935483870968

# %% [markdown]
# 3multihead

# %%
import functions
from pointnetfunct.PointNet_struct import PointNet_3Multihead_withDNN
from pointnetfunct.PointNet_trainingfunct import run_model_3multi_head_dnn
pointnet_mh = PointNet_3Multihead_withDNN(classes=2)
run_model_3multi_head_dnn(train_loader_input = train_loader,
                        vaild_loader_input = valid_loader,
                        nepochs = 100, 
                        modelnet = pointnet_mh,
                        results_path = "./result", 
                        filename = "/3multimodal_unform_1000pt_test.pt",
                        model_name= "pointnet_3multimodal_unform_1000pt_test.pth")
pointnet_mh.to("cpu")
print("done")
# Out:
# epoch: 0 training loss:  0.725 training accuracy:  62.4%  test loss:  0.674 test accuracy:  63.8%
# epoch: 1 training loss:  0.685 training accuracy:  66.5%  test loss:  0.625 test accuracy:  73.2%
# epoch: 2 training loss:  0.668 training accuracy:  68.1%  test loss:  0.621 test accuracy:  70.1%
# epoch: 3 training loss:  0.643 training accuracy:  69.9%  test loss:  0.606 test accuracy:  71.7%
# epoch: 4 training loss:  0.635 training accuracy:  73.2%  test loss:  0.637 test accuracy:  70.1%
# epoch: 5 training loss:  0.654 training accuracy:  69.5%  test loss:  0.613 test accuracy:  72.4%
# epoch: 6 training loss:  0.626 training accuracy:  70.9%  test loss:  0.660 test accuracy:  70.9%
# epoch: 7 training loss:  0.613 training accuracy:  71.7%  test loss:  0.621 test accuracy:  66.1%
# epoch: 8 training loss:  0.645 training accuracy:  70.7%  test loss:  0.585 test accuracy:  71.7%
# epoch: 9 training loss:  0.612 training accuracy:  73.2%  test loss:  0.613 test accuracy:  67.7%
# epoch: 10 training loss:  0.596 training accuracy:  74.2%  test loss:  0.611 test accuracy:  70.9%
# epoch: 11 training loss:  0.625 training accuracy:  74.2%  test loss:  0.591 test accuracy:  73.2%
# epoch: 12 training loss:  0.586 training accuracy:  72.6%  test loss:  0.565 test accuracy:  74.8%
# epoch: 13 training loss:  0.607 training accuracy:  74.6%  test loss:  0.550 test accuracy:  76.4%
# epoch: 14 training loss:  0.619 training accuracy:  72.4%  test loss:  0.553 test accuracy:  78.0%
# epoch: 77 training loss:  0.551 training accuracy:  77.2%  test loss:  0.506 test accuracy:  71.7%
# epoch: 78 training loss:  0.551 training accuracy:  76.8%  test loss:  0.488 test accuracy:  79.5%
# epoch: 79 training loss:  0.535 training accuracy:  76.4%  test loss:  0.524 test accuracy:  75.6%
# epoch: 80 training loss:  0.520 training accuracy:  76.2%  test loss:  0.520 test accuracy:  77.2%
# epoch: 81 training loss:  0.571 training accuracy:  74.6%  test loss:  0.513 test accuracy:  70.9%
# epoch: 82 training loss:  0.551 training accuracy:  75.2%  test loss:  0.466 test accuracy:  78.7%
# epoch: 83 training loss:  0.539 training accuracy:  75.4%  test loss:  0.518 test accuracy:  78.7%
# epoch: 84 training loss:  0.543 training accuracy:  74.8%  test loss:  0.494 test accuracy:  74.8%
# epoch: 85 training loss:  0.565 training accuracy:  73.8%  test loss:  0.499 test accuracy:  76.4%
# epoch: 86 training loss:  0.566 training accuracy:  78.0%  test loss:  0.557 test accuracy:  70.9%
# epoch: 87 training loss:  0.595 training accuracy:  73.8%  test loss:  0.536 test accuracy:  72.4%
# epoch: 88 training loss:  0.558 training accuracy:  74.6%  test loss:  0.523 test accuracy:  75.6%
# epoch: 89 training loss:  0.571 training accuracy:  75.4%  test loss:  0.520 test accuracy:  75.6%
# epoch: 90 training loss:  0.566 training accuracy:  74.8%  test loss:  0.536 test accuracy:  74.0%
# epoch: 91 training loss:  0.547 training accuracy:  75.6%  test loss:  0.504 test accuracy:  73.2%
# epoch: 92 training loss:  0.555 training accuracy:  78.1%  test loss:  0.507 test accuracy:  71.7%
# epoch: 93 training loss:  0.612 training accuracy:  75.0%  test loss:  0.536 test accuracy:  70.1%
# epoch: 94 training loss:  0.584 training accuracy:  74.4%  test loss:  0.536 test accuracy:  73.2%
# epoch: 95 training loss:  0.552 training accuracy:  76.2%  test loss:  0.515 test accuracy:  74.0%
# epoch: 96 training loss:  0.563 training accuracy:  74.8%  test loss:  0.515 test accuracy:  74.0%
# epoch: 97 training loss:  0.576 training accuracy:  74.0%  test loss:  0.529 test accuracy:  73.2%
# epoch: 98 training loss:  0.548 training accuracy:  73.4%  test loss:  0.534 test accuracy:  78.0%
# epoch: 99 training loss:  0.559 training accuracy:  76.0%  test loss:  0.521 test accuracy:  76.4%
# PointNet_3Multihead_withDNN(
#   (transform): Transform(
#     (input_transform): Tnet(
#       (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=9, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (feature_transform): Tnet(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=4096, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=3, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=64, bias=True)
#     (fc4): Linear(in_features=64, out_features=128, bias=True)
#     (fc5): Linear(in_features=128, out_features=1024, bias=True)
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (transform2): Transform(
#     (input_transform): Tnet(
#       (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=9, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (feature_transform): Tnet(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=4096, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=3, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=64, bias=True)
#     (fc4): Linear(in_features=64, out_features=128, bias=True)
#     (fc5): Linear(in_features=128, out_features=1024, bias=True)
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (transform4): Transform_2Multi(
#     (input_transform): Tnet(
#       (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=9, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (feature_transform): Tnet(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=4096, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=3, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=64, bias=True)
#     (fc4): Linear(in_features=64, out_features=128, bias=True)
#     (fc5): Linear(in_features=128, out_features=1024, bias=True)
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (transform5): Transform_2Multi(
#     (input_transform): Tnet(
#       (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=9, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (feature_transform): Tnet(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=4096, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=3, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=64, bias=True)
#     (fc4): Linear(in_features=64, out_features=128, bias=True)
#     (fc5): Linear(in_features=128, out_features=1024, bias=True)
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (transform3): DNNModel(
#     (Flatten): Flatten(start_dim=1, end_dim=-1)
#     (fc1): Linear(in_features=172, out_features=512, bias=True)
#     (relu): ReLU()
#     (fc2): Linear(in_features=512, out_features=256, bias=True)
#     (fc3): Linear(in_features=256, out_features=128, bias=True)
#     (loss_fn): CrossEntropyLoss()
#     (logsoftmax): LogSoftmax(dim=1)
#     (dropout): Dropout(p=0.3, inplace=False)
#     (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc1): Linear(in_features=1152, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=2, bias=True)
#   (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (logsoftmax): LogSoftmax(dim=1)
#   (loss_fn): CrossEntropyLoss()
# )

# %%
device = torch.device('cuda:0')
show_graph(path ="./result/3multimodal_unform_1000pt_test.pt",device = "cuda",name ="1000pt_3branch_trainingtrend")

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import functions as fun
from pointnetfunct.PointNet_trainingfunct import load_model

pointnet_copy = PointNet_3Multihead_withDNN(classes=2)
model_path = "./pointnet_3multimodal_unform_1000pt_test.pth"
load_model(pointnet_copy,model_path)
y_true = []
y_pred = []
y_probs = []
y_pred_result = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,inputs_v2,inputs_v3,labels in test_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        inputs_v2 = inputs_v2.to(torch.float32)
        inputs_v2 = inputs_v2.squeeze(1).permute(0, 2, 1)
        inputs_v3 = inputs_v3.to(torch.float32)

        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v,inputs_v2,inputs_v3)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) 
        y_probs.extend(outputs)

# %%
from pointnetfunct.evaluation import show_cm_dl,show_graph,print_values,draw_rocgraph

draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_3branch_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_3branch_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.55
# F1 score: 0.3835616438356164
# Rupture Recall: 0.3181818181818182
# Rupture Precision: 0.4827586206896552
# UnRupture Recall: 0.7321428571428571
# UnRupture Precision: 0.5774647887323944

# %%
y_true = []
y_pred = []
y_probs = []
y_pred_result = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,inputs_v2,inputs_v3,labels in valid_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        inputs_v2 = inputs_v2.to(torch.float32)
        inputs_v2 = inputs_v2.squeeze(1).permute(0, 2, 1)
        inputs_v3 = inputs_v3.to(torch.float32)

        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v,inputs_v2,inputs_v3)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) 
        y_probs.extend(outputs)

# %%
draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_3branch_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_3branch_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.7559055118110236
# F1 score: 0.6436781609195402
# Rupture Recall: 0.7
# Rupture Precision: 0.5957446808510638
# UnRupture Recall: 0.7816091954022989
# UnRupture Precision: 0.85
