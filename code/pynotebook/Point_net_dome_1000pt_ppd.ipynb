# %%
import vtk
import os
import numpy as np
import itertools
import math, random
import data_process_ml
random.seed = 42
import copy

import torch
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
from torchvision import transforms, utils

import scipy.spatial.distance
# import plotly.graph_objects as go
# import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
device = "cuda"

# %% [markdown]
# load the dataset

# %%
root = "..\..\msc_data\models-v1.0\models"
IA = "aneurysms\\remeshed\\area-001"
Vessel = "vessels\\remeshed\\area-001"
IA_root = os.path.join(root,IA)
Vessel_root = os.path.join(root,Vessel)
list1 = os.listdir(Vessel_root)
list2 = os.listdir(IA_root)

# %%
morpho_path = ".\AneuX\data-v1.0\data\morpho-per-cut.csv"
patient_path = ".\AneuX\data-v1.0\data\clinical.csv"
morpho_data_patient = data_process_ml.read_and_combine_data(morpho_path,patient_path)
merged_dataset = data_process_ml.encode_column(morpho_data_patient)
merged_dataset = data_process_ml.drop_columns(merged_dataset)
morpho_data_cut1,morpho_data_dome = data_process_ml.output_cut1anddome(merged_dataset)
# Out:
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_dome.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)

# %%
import pandas as pd
from pointnetfunct.PointNet_dataset import Aneux_Dataset_load
df = pd.DataFrame()
# Aneux_Dataset = Aneuxmodel_Dataset(root = root,
#                                    df=morpho_data_patient[morpho_data_patient["cuttype"] == "dome"],
#                                    transform = transforms.ToTensor(),
#                                    mesh = "area-001",
#                                    cuttype = "dome",
#                                    crop = False)

Aneux_Dataset = Aneux_Dataset_load('./Aneux_Dataset_1000pt_ppd_600train.pt')
Aneux_Dataset_test = Aneux_Dataset_load('./Aneux_Dataset_1000pt_ppd_100test.pt')
Aneux_Dataset.paraout = True
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_dome.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_dome.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)

# %%
from torch.utils.data import Subset

seed = torch.seed()
print(seed)
torch.manual_seed(32381912834800)
#12984260249700
#16912914325100

train_size = int(len(Aneux_Dataset) * 0.8) # 80% training data
valid_size = len(Aneux_Dataset) - train_size
train_data, valid_data = random_split(Aneux_Dataset, [train_size, valid_size])

train_loader = torch.utils.data.DataLoader(
    train_data,
    batch_size=50,
    shuffle=True,
    #num_workers=2, 
    pin_memory=True
)

valid_loader = torch.utils.data.DataLoader(
    valid_data,
    batch_size=50, # Forward pass only so batch size can be larger
    shuffle=False,
    #num_workers=2, 
    pin_memory=True
)

test_loader = torch.utils.data.DataLoader(
    Aneux_Dataset_test,
    batch_size=50, # Forward pass only so batch size can be larger
    shuffle=False,
    #num_workers=2, 
    pin_memory=True
)
# Out:
# 168315532000

# %% [markdown]
# Test vaildation

# %% [markdown]
# # PointNet model

# %%
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torch import optim
from pointnetfunct.PointNet_struct import Tnet,Transform,PointNet,PointNet_2Multihead,PointNet_3Multihead

# %% [markdown]
# Run model

# %%
import functions
from pointnetfunct.PointNet_trainingfunct import run_model_get, load_model

pointnet = PointNet(classes=2)
run_model_get(train_loader_input = train_loader,
                        vaild_loader_input = valid_loader,
                        nepochs = 100, 
                        modelnet = pointnet,
                        results_path = "./result", 
                        filename = "/dome_test_ppd.pt",
                        model_name= "pointnet_dome_ppd_1000pt_test.pth")
pointnet.to("cpu")
# Out:
# epoch: 0 training loss:  0.699 training accuracy:  55.7%  test loss:  0.675 test accuracy:  70.9%
# epoch: 1 training loss:  0.700 training accuracy:  59.3%  test loss:  0.711 test accuracy:  58.3%
# epoch: 2 training loss:  0.699 training accuracy:  60.4%  test loss:  0.745 test accuracy:  60.6%
# epoch: 3 training loss:  0.705 training accuracy:  59.3%  test loss:  0.725 test accuracy:  64.6%
# epoch: 4 training loss:  0.688 training accuracy:  67.3%  test loss:  0.720 test accuracy:  65.4%
# epoch: 5 training loss:  0.675 training accuracy:  66.3%  test loss:  0.699 test accuracy:  64.6%
# epoch: 6 training loss:  0.674 training accuracy:  64.0%  test loss:  0.687 test accuracy:  64.6%
# epoch: 7 training loss:  0.694 training accuracy:  60.2%  test loss:  0.738 test accuracy:  63.8%
# epoch: 8 training loss:  0.674 training accuracy:  65.4%  test loss:  0.699 test accuracy:  65.4%
# epoch: 9 training loss:  0.700 training accuracy:  65.0%  test loss:  0.677 test accuracy:  67.7%
# epoch: 10 training loss:  0.688 training accuracy:  65.2%  test loss:  0.688 test accuracy:  66.9%
# epoch: 11 training loss:  0.686 training accuracy:  67.5%  test loss:  0.717 test accuracy:  65.4%
# epoch: 12 training loss:  0.676 training accuracy:  63.6%  test loss:  0.704 test accuracy:  62.2%
# epoch: 13 training loss:  0.670 training accuracy:  68.7%  test loss:  0.738 test accuracy:  59.1%
# epoch: 14 training loss:  0.665 training accuracy:  63.8%  test loss:  0.704 test accuracy:  63.8%
# epoch: 15 training loss:  0.699 training accuracy:  65.7%  test loss:  0.701 test accuracy:  65.4%
# epoch: 16 training loss:  0.658 training accuracy:  65.2%  test loss:  0.706 test accuracy:  64.6%
# epoch: 17 training loss:  0.659 training accuracy:  67.1%  test loss:  0.720 test accuracy:  66.1%
# epoch: 18 training loss:  0.683 training accuracy:  64.4%  test loss:  0.706 test accuracy:  63.0%
# epoch: 19 training loss:  0.673 training accuracy:  64.8%  test loss:  0.715 test accuracy:  66.1%
# epoch: 20 training loss:  0.678 training accuracy:  68.9%  test loss:  0.724 test accuracy:  63.8%
# epoch: 21 training loss:  0.697 training accuracy:  64.2%  test loss:  0.699 test accuracy:  66.9%
# epoch: 22 training loss:  0.687 training accuracy:  65.7%  test loss:  0.725 test accuracy:  66.1%
# epoch: 23 training loss:  0.682 training accuracy:  65.2%  test loss:  0.726 test accuracy:  63.8%
# epoch: 24 training loss:  0.675 training accuracy:  63.6%  test loss:  0.680 test accuracy:  63.8%
# epoch: 25 training loss:  0.669 training accuracy:  67.1%  test loss:  0.720 test accuracy:  61.4%
# epoch: 26 training loss:  0.694 training accuracy:  63.4%  test loss:  0.708 test accuracy:  62.2%
# epoch: 27 training loss:  0.714 training accuracy:  63.2%  test loss:  0.696 test accuracy:  61.4%
# epoch: 28 training loss:  0.682 training accuracy:  64.2%  test loss:  0.704 test accuracy:  66.1%
# epoch: 29 training loss:  0.668 training accuracy:  67.1%  test loss:  0.718 test accuracy:  63.8%
# epoch: 30 training loss:  0.674 training accuracy:  65.6%  test loss:  0.680 test accuracy:  64.6%
# epoch: 31 training loss:  0.671 training accuracy:  67.7%  test loss:  0.694 test accuracy:  66.1%
# epoch: 32 training loss:  0.663 training accuracy:  66.9%  test loss:  0.716 test accuracy:  60.6%
# epoch: 33 training loss:  0.661 training accuracy:  66.5%  test loss:  0.701 test accuracy:  63.0%
# epoch: 34 training loss:  0.686 training accuracy:  66.3%  test loss:  0.728 test accuracy:  63.0%
# epoch: 35 training loss:  0.676 training accuracy:  66.9%  test loss:  0.691 test accuracy:  68.5%
# epoch: 36 training loss:  0.666 training accuracy:  67.7%  test loss:  0.714 test accuracy:  63.0%
# epoch: 37 training loss:  0.665 training accuracy:  67.3%  test loss:  0.691 test accuracy:  66.9%
# epoch: 38 training loss:  0.689 training accuracy:  66.9%  test loss:  0.719 test accuracy:  63.0%
# epoch: 39 training loss:  0.667 training accuracy:  67.1%  test loss:  0.685 test accuracy:  64.6%
# epoch: 40 training loss:  0.672 training accuracy:  68.3%  test loss:  0.667 test accuracy:  65.4%
# epoch: 41 training loss:  0.644 training accuracy:  68.9%  test loss:  0.722 test accuracy:  66.1%
# epoch: 42 training loss:  0.658 training accuracy:  68.7%  test loss:  0.679 test accuracy:  66.1%
# epoch: 43 training loss:  0.670 training accuracy:  65.7%  test loss:  0.697 test accuracy:  68.5%
# epoch: 44 training loss:  0.685 training accuracy:  65.6%  test loss:  0.704 test accuracy:  66.9%
# epoch: 45 training loss:  0.701 training accuracy:  65.2%  test loss:  0.728 test accuracy:  61.4%
# epoch: 46 training loss:  0.661 training accuracy:  66.3%  test loss:  0.705 test accuracy:  63.0%
# epoch: 47 training loss:  0.677 training accuracy:  65.7%  test loss:  0.695 test accuracy:  66.9%
# epoch: 48 training loss:  0.669 training accuracy:  66.7%  test loss:  0.684 test accuracy:  64.6%
# epoch: 49 training loss:  0.667 training accuracy:  67.3%  test loss:  0.745 test accuracy:  61.4%
# epoch: 50 training loss:  0.670 training accuracy:  66.1%  test loss:  0.739 test accuracy:  61.4%
# epoch: 51 training loss:  0.668 training accuracy:  66.9%  test loss:  0.701 test accuracy:  59.1%
# epoch: 52 training loss:  0.709 training accuracy:  66.9%  test loss:  0.709 test accuracy:  60.6%
# epoch: 53 training loss:  0.682 training accuracy:  65.0%  test loss:  0.707 test accuracy:  62.2%
# epoch: 54 training loss:  0.650 training accuracy:  66.3%  test loss:  0.685 test accuracy:  66.1%
# epoch: 55 training loss:  0.656 training accuracy:  67.5%  test loss:  0.708 test accuracy:  65.4%
# epoch: 56 training loss:  0.662 training accuracy:  67.1%  test loss:  0.724 test accuracy:  63.0%
# epoch: 57 training loss:  0.680 training accuracy:  66.3%  test loss:  0.730 test accuracy:  62.2%
# epoch: 58 training loss:  0.641 training accuracy:  66.3%  test loss:  0.717 test accuracy:  60.6%
# epoch: 59 training loss:  0.686 training accuracy:  66.9%  test loss:  0.682 test accuracy:  66.9%
# epoch: 60 training loss:  0.651 training accuracy:  67.9%  test loss:  0.699 test accuracy:  65.4%
# epoch: 61 training loss:  0.680 training accuracy:  66.7%  test loss:  0.699 test accuracy:  63.8%
# epoch: 62 training loss:  0.666 training accuracy:  68.5%  test loss:  0.701 test accuracy:  65.4%
# epoch: 63 training loss:  0.670 training accuracy:  69.9%  test loss:  0.708 test accuracy:  58.3%
# epoch: 64 training loss:  0.697 training accuracy:  65.6%  test loss:  0.683 test accuracy:  61.4%
# epoch: 65 training loss:  0.680 training accuracy:  64.2%  test loss:  0.701 test accuracy:  65.4%
# epoch: 66 training loss:  0.660 training accuracy:  67.7%  test loss:  0.728 test accuracy:  62.2%
# epoch: 67 training loss:  0.652 training accuracy:  65.7%  test loss:  0.698 test accuracy:  66.1%
# epoch: 68 training loss:  0.695 training accuracy:  65.2%  test loss:  0.704 test accuracy:  64.6%
# epoch: 69 training loss:  0.659 training accuracy:  67.7%  test loss:  0.683 test accuracy:  70.9%
# epoch: 70 training loss:  0.660 training accuracy:  65.9%  test loss:  0.680 test accuracy:  66.1%
# epoch: 71 training loss:  0.671 training accuracy:  67.7%  test loss:  0.676 test accuracy:  63.0%
# epoch: 72 training loss:  0.674 training accuracy:  65.7%  test loss:  0.714 test accuracy:  61.4%
# epoch: 73 training loss:  0.656 training accuracy:  68.9%  test loss:  0.706 test accuracy:  66.9%
# epoch: 74 training loss:  0.664 training accuracy:  66.9%  test loss:  0.706 test accuracy:  63.8%
# epoch: 75 training loss:  0.661 training accuracy:  67.7%  test loss:  0.676 test accuracy:  64.6%
# epoch: 76 training loss:  0.682 training accuracy:  67.7%  test loss:  0.689 test accuracy:  63.0%
# epoch: 77 training loss:  0.664 training accuracy:  68.7%  test loss:  0.708 test accuracy:  65.4%
# epoch: 78 training loss:  0.653 training accuracy:  68.1%  test loss:  0.692 test accuracy:  66.1%
# epoch: 79 training loss:  0.676 training accuracy:  66.9%  test loss:  0.682 test accuracy:  66.9%
# epoch: 80 training loss:  0.685 training accuracy:  65.7%  test loss:  0.711 test accuracy:  60.6%
# epoch: 81 training loss:  0.650 training accuracy:  67.1%  test loss:  0.698 test accuracy:  62.2%
# epoch: 82 training loss:  0.639 training accuracy:  66.5%  test loss:  0.683 test accuracy:  64.6%
# epoch: 83 training loss:  0.652 training accuracy:  68.5%  test loss:  0.680 test accuracy:  66.9%
# epoch: 84 training loss:  0.672 training accuracy:  66.3%  test loss:  0.669 test accuracy:  69.3%
# epoch: 85 training loss:  0.665 training accuracy:  68.9%  test loss:  0.661 test accuracy:  67.7%
# epoch: 86 training loss:  0.679 training accuracy:  66.3%  test loss:  0.690 test accuracy:  68.5%
# epoch: 87 training loss:  0.659 training accuracy:  67.1%  test loss:  0.667 test accuracy:  68.5%
# epoch: 88 training loss:  0.660 training accuracy:  67.1%  test loss:  0.682 test accuracy:  66.1%
# epoch: 89 training loss:  0.668 training accuracy:  68.3%  test loss:  0.684 test accuracy:  63.8%
# epoch: 90 training loss:  0.674 training accuracy:  65.4%  test loss:  0.675 test accuracy:  63.8%
# epoch: 91 training loss:  0.671 training accuracy:  66.3%  test loss:  0.685 test accuracy:  62.2%
# epoch: 92 training loss:  0.673 training accuracy:  67.5%  test loss:  0.701 test accuracy:  63.8%
# epoch: 93 training loss:  0.646 training accuracy:  69.7%  test loss:  0.685 test accuracy:  66.9%
# epoch: 94 training loss:  0.675 training accuracy:  67.9%  test loss:  0.665 test accuracy:  63.8%
# epoch: 95 training loss:  0.679 training accuracy:  65.4%  test loss:  0.680 test accuracy:  67.7%
# epoch: 96 training loss:  0.689 training accuracy:  66.1%  test loss:  0.714 test accuracy:  61.4%
# epoch: 97 training loss:  0.661 training accuracy:  68.3%  test loss:  0.716 test accuracy:  62.2%
# epoch: 98 training loss:  0.669 training accuracy:  68.1%  test loss:  0.704 test accuracy:  63.0%
# epoch: 99 training loss:  0.660 training accuracy:  68.3%  test loss:  0.694 test accuracy:  62.2%
# PointNet(
#   (transform): Transform(
#     (input_transform): Tnet(
#       (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=9, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (feature_transform): Tnet(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=4096, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=3, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=64, bias=True)
#     (fc4): Linear(in_features=64, out_features=128, bias=True)
#     (fc5): Linear(in_features=128, out_features=1024, bias=True)
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=2, bias=True)
#   (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (logsoftmax): LogSoftmax(dim=1)
#   (loss_fn): CrossEntropyLoss()
# )

# %%
def show_graph(path,device):
    data = torch.load(path, map_location=device) # by doing map_location=device, you can use trained model on GPU --> to test on CPU
    statsrec = data["stats"]
    fig, ax1 = plt.subplots()
    plt.plot(statsrec[0], 'r', label = 'training loss', )
    plt.plot(statsrec[2], 'g', label = 'test loss' )
    plt.legend(loc='lower right')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training and test loss, and test accuracy')
    ax2=ax1.twinx()
    ax2.plot(statsrec[1], 'm', label = 'training accuracy')
    ax2.plot(statsrec[3], 'b', label = 'test accuracy')
    ax2.set_ylabel('accuracy')
    plt.legend(loc='upper right')
    fig.savefig("roc.svg")
    plt.show()

# %%
device = torch.device('cuda:0')
show_graph(path ="./result/dome_test_ppd.pt",device = "cuda")

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import functions as fun
pointnet_copy = PointNet(classes=2)
model_path = "./pointnet_dome_ppd_1000pt_test.pth"
load_model(pointnet_copy,model_path)
y_true = []
y_pred = []
y_pred_result = []
y_probs = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,_,_,labels in test_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels)
        y_probs.extend(outputs)

# %%
from pointnetfunct.evaluation import show_cm_dl,show_graph,print_values,draw_rocgraph

draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_pointnet_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_pointnet_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.55
# F1 score: 0.3661971830985915
# Rupture Recall: 0.29545454545454547
# Rupture Precision: 0.48148148148148145
# UnRupture Recall: 0.75
# UnRupture Precision: 0.5753424657534246

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import functions as fun
pointnet_copy = PointNet(classes=2)
model_path = "./pointnet_dome_ppd_1000pt_test.pth"
load_model(pointnet_copy,model_path)
y_true = []
y_pred = []
y_pred_result = []
y_probs = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,_,_,labels in valid_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels)
        y_probs.extend(outputs)

# %%
draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_pointnet_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_pointnet_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.5748031496062992
# F1 score: 0.2894736842105263
# Rupture Recall: 0.275
# Rupture Precision: 0.3055555555555556
# UnRupture Recall: 0.7126436781609196
# UnRupture Precision: 0.6813186813186813

# %%
#61.9%~70.5%

# %% [markdown]
# Multi head

# %% [markdown]
# 2 multi head

# %%
import functions
from pointnetfunct.PointNet_struct import PointNet_2Multimodal_withDNN
from pointnetfunct.PointNet_trainingfunct import run_model_2multi_head_dnn
pointnet_mh = PointNet_2Multimodal_withDNN(classes=2)
run_model_2multi_head_dnn(train_loader_input = train_loader,
                        vaild_loader_input = valid_loader,
                        nepochs = 100, 
                        modelnet = pointnet_mh,
                        results_path = "./result", 
                        filename = "/2multimodel_ppd_test.pt",
                        model_name= "pointnet_2multimodal_ppd_1000pt_test.pth")
# Out:
# epoch: 0 training loss:  0.739 training accuracy:  62.2%  test loss:  0.696 test accuracy:  62.2%
# epoch: 1 training loss:  0.701 training accuracy:  61.0%  test loss:  0.677 test accuracy:  67.7%
# epoch: 2 training loss:  0.681 training accuracy:  63.8%  test loss:  0.655 test accuracy:  66.1%
# epoch: 3 training loss:  0.678 training accuracy:  64.4%  test loss:  0.635 test accuracy:  69.3%
# epoch: 4 training loss:  0.668 training accuracy:  63.8%  test loss:  0.660 test accuracy:  63.0%
# epoch: 5 training loss:  0.683 training accuracy:  63.0%  test loss:  0.655 test accuracy:  66.1%
# epoch: 6 training loss:  0.653 training accuracy:  63.8%  test loss:  0.697 test accuracy:  63.8%
# epoch: 7 training loss:  0.674 training accuracy:  68.1%  test loss:  0.673 test accuracy:  66.1%
# epoch: 8 training loss:  0.647 training accuracy:  66.9%  test loss:  0.656 test accuracy:  68.5%
# epoch: 9 training loss:  0.635 training accuracy:  66.1%  test loss:  0.680 test accuracy:  65.4%
# epoch: 10 training loss:  0.668 training accuracy:  66.7%  test loss:  0.677 test accuracy:  65.4%
# epoch: 11 training loss:  0.644 training accuracy:  67.3%  test loss:  0.638 test accuracy:  66.1%
# epoch: 12 training loss:  0.652 training accuracy:  65.6%  test loss:  0.664 test accuracy:  64.6%
# epoch: 13 training loss:  0.643 training accuracy:  65.4%  test loss:  0.669 test accuracy:  65.4%
# epoch: 14 training loss:  0.665 training accuracy:  67.9%  test loss:  0.640 test accuracy:  66.9%
# epoch: 15 training loss:  0.653 training accuracy:  68.3%  test loss:  0.601 test accuracy:  74.0%
# epoch: 16 training loss:  0.639 training accuracy:  66.9%  test loss:  0.600 test accuracy:  72.4%
# epoch: 17 training loss:  0.623 training accuracy:  65.9%  test loss:  0.608 test accuracy:  69.3%
# epoch: 18 training loss:  0.649 training accuracy:  66.9%  test loss:  0.608 test accuracy:  72.4%
# epoch: 19 training loss:  0.623 training accuracy:  69.1%  test loss:  0.625 test accuracy:  68.5%
# epoch: 20 training loss:  0.620 training accuracy:  68.9%  test loss:  0.630 test accuracy:  70.9%
# epoch: 21 training loss:  0.589 training accuracy:  66.5%  test loss:  0.622 test accuracy:  76.4%
# epoch: 22 training loss:  0.629 training accuracy:  71.7%  test loss:  0.595 test accuracy:  78.7%
# epoch: 23 training loss:  0.589 training accuracy:  68.3%  test loss:  0.602 test accuracy:  71.7%
# epoch: 24 training loss:  0.624 training accuracy:  72.4%  test loss:  0.573 test accuracy:  74.8%
# epoch: 25 training loss:  0.604 training accuracy:  72.8%  test loss:  0.599 test accuracy:  77.2%
# epoch: 26 training loss:  0.603 training accuracy:  70.3%  test loss:  0.614 test accuracy:  72.4%
# epoch: 27 training loss:  0.589 training accuracy:  69.1%  test loss:  0.581 test accuracy:  77.2%
# epoch: 28 training loss:  0.599 training accuracy:  69.5%  test loss:  0.601 test accuracy:  74.0%
# epoch: 29 training loss:  0.598 training accuracy:  70.9%  test loss:  0.596 test accuracy:  72.4%
# epoch: 30 training loss:  0.599 training accuracy:  69.9%  test loss:  0.598 test accuracy:  70.1%
# epoch: 31 training loss:  0.591 training accuracy:  68.9%  test loss:  0.576 test accuracy:  73.2%
# epoch: 32 training loss:  0.608 training accuracy:  71.1%  test loss:  0.582 test accuracy:  72.4%
# epoch: 33 training loss:  0.567 training accuracy:  72.8%  test loss:  0.612 test accuracy:  68.5%
# epoch: 34 training loss:  0.587 training accuracy:  73.0%  test loss:  0.598 test accuracy:  71.7%
# epoch: 35 training loss:  0.595 training accuracy:  70.1%  test loss:  0.587 test accuracy:  72.4%
# epoch: 36 training loss:  0.601 training accuracy:  71.7%  test loss:  0.588 test accuracy:  74.8%
# epoch: 37 training loss:  0.585 training accuracy:  70.7%  test loss:  0.575 test accuracy:  77.2%
# epoch: 38 training loss:  0.598 training accuracy:  71.7%  test loss:  0.574 test accuracy:  70.1%
# epoch: 39 training loss:  0.585 training accuracy:  71.5%  test loss:  0.562 test accuracy:  74.8%
# epoch: 40 training loss:  0.611 training accuracy:  69.5%  test loss:  0.572 test accuracy:  72.4%
# epoch: 41 training loss:  0.587 training accuracy:  73.6%  test loss:  0.586 test accuracy:  73.2%
# epoch: 42 training loss:  0.558 training accuracy:  73.0%  test loss:  0.570 test accuracy:  74.0%
# epoch: 43 training loss:  0.580 training accuracy:  70.1%  test loss:  0.550 test accuracy:  74.0%
# epoch: 44 training loss:  0.574 training accuracy:  72.2%  test loss:  0.578 test accuracy:  74.8%
# epoch: 45 training loss:  0.593 training accuracy:  73.0%  test loss:  0.553 test accuracy:  78.7%
# epoch: 46 training loss:  0.592 training accuracy:  73.2%  test loss:  0.548 test accuracy:  77.2%
# epoch: 47 training loss:  0.550 training accuracy:  73.6%  test loss:  0.556 test accuracy:  77.2%
# epoch: 48 training loss:  0.575 training accuracy:  71.3%  test loss:  0.542 test accuracy:  75.6%
# epoch: 49 training loss:  0.555 training accuracy:  72.0%  test loss:  0.554 test accuracy:  73.2%
# epoch: 50 training loss:  0.552 training accuracy:  71.9%  test loss:  0.554 test accuracy:  78.0%
# epoch: 51 training loss:  0.567 training accuracy:  73.8%  test loss:  0.506 test accuracy:  80.3%
# epoch: 52 training loss:  0.572 training accuracy:  71.9%  test loss:  0.543 test accuracy:  74.0%
# epoch: 53 training loss:  0.552 training accuracy:  70.5%  test loss:  0.551 test accuracy:  75.6%
# epoch: 54 training loss:  0.586 training accuracy:  70.5%  test loss:  0.516 test accuracy:  82.7%
# epoch: 55 training loss:  0.553 training accuracy:  72.4%  test loss:  0.545 test accuracy:  76.4%
# epoch: 56 training loss:  0.561 training accuracy:  73.4%  test loss:  0.530 test accuracy:  78.0%
# epoch: 57 training loss:  0.560 training accuracy:  70.3%  test loss:  0.522 test accuracy:  74.8%
# epoch: 58 training loss:  0.555 training accuracy:  72.6%  test loss:  0.532 test accuracy:  80.3%
# epoch: 59 training loss:  0.563 training accuracy:  73.0%  test loss:  0.542 test accuracy:  77.2%
# epoch: 60 training loss:  0.562 training accuracy:  72.2%  test loss:  0.525 test accuracy:  78.7%
# epoch: 61 training loss:  0.581 training accuracy:  73.8%  test loss:  0.524 test accuracy:  74.0%
# epoch: 62 training loss:  0.565 training accuracy:  74.6%  test loss:  0.530 test accuracy:  78.0%
# epoch: 63 training loss:  0.574 training accuracy:  72.6%  test loss:  0.490 test accuracy:  81.1%
# epoch: 64 training loss:  0.569 training accuracy:  70.9%  test loss:  0.520 test accuracy:  76.4%
# epoch: 65 training loss:  0.552 training accuracy:  71.1%  test loss:  0.545 test accuracy:  79.5%
# epoch: 66 training loss:  0.581 training accuracy:  72.6%  test loss:  0.493 test accuracy:  81.9%
# epoch: 67 training loss:  0.559 training accuracy:  75.6%  test loss:  0.517 test accuracy:  79.5%
# epoch: 68 training loss:  0.530 training accuracy:  73.2%  test loss:  0.530 test accuracy:  76.4%
# epoch: 69 training loss:  0.548 training accuracy:  73.2%  test loss:  0.518 test accuracy:  78.0%
# epoch: 70 training loss:  0.552 training accuracy:  72.6%  test loss:  0.546 test accuracy:  75.6%
# epoch: 71 training loss:  0.540 training accuracy:  72.2%  test loss:  0.531 test accuracy:  78.0%
# epoch: 72 training loss:  0.531 training accuracy:  73.6%  test loss:  0.533 test accuracy:  74.8%
# epoch: 73 training loss:  0.560 training accuracy:  73.8%  test loss:  0.530 test accuracy:  77.2%
# epoch: 74 training loss:  0.557 training accuracy:  73.8%  test loss:  0.543 test accuracy:  71.7%
# epoch: 75 training loss:  0.561 training accuracy:  71.9%  test loss:  0.537 test accuracy:  76.4%
# epoch: 76 training loss:  0.541 training accuracy:  73.6%  test loss:  0.550 test accuracy:  70.9%
# epoch: 77 training loss:  0.553 training accuracy:  75.0%  test loss:  0.528 test accuracy:  71.7%
# epoch: 78 training loss:  0.584 training accuracy:  74.8%  test loss:  0.551 test accuracy:  74.8%
# epoch: 79 training loss:  0.553 training accuracy:  72.0%  test loss:  0.531 test accuracy:  77.2%
# epoch: 80 training loss:  0.540 training accuracy:  73.8%  test loss:  0.515 test accuracy:  76.4%
# epoch: 81 training loss:  0.550 training accuracy:  73.0%  test loss:  0.552 test accuracy:  70.9%
# epoch: 82 training loss:  0.551 training accuracy:  72.6%  test loss:  0.535 test accuracy:  74.0%
# epoch: 83 training loss:  0.543 training accuracy:  70.5%  test loss:  0.541 test accuracy:  76.4%
# epoch: 84 training loss:  0.554 training accuracy:  73.2%  test loss:  0.556 test accuracy:  76.4%
# epoch: 85 training loss:  0.550 training accuracy:  71.5%  test loss:  0.513 test accuracy:  74.8%
# epoch: 86 training loss:  0.532 training accuracy:  73.8%  test loss:  0.514 test accuracy:  77.2%
# epoch: 87 training loss:  0.530 training accuracy:  72.6%  test loss:  0.522 test accuracy:  72.4%
# epoch: 88 training loss:  0.547 training accuracy:  73.6%  test loss:  0.556 test accuracy:  72.4%
# epoch: 89 training loss:  0.575 training accuracy:  74.0%  test loss:  0.527 test accuracy:  75.6%
# epoch: 90 training loss:  0.582 training accuracy:  71.7%  test loss:  0.563 test accuracy:  72.4%
# epoch: 91 training loss:  0.544 training accuracy:  74.2%  test loss:  0.551 test accuracy:  74.0%
# epoch: 92 training loss:  0.556 training accuracy:  75.0%  test loss:  0.538 test accuracy:  71.7%
# epoch: 93 training loss:  0.557 training accuracy:  71.5%  test loss:  0.534 test accuracy:  69.3%
# epoch: 94 training loss:  0.534 training accuracy:  73.0%  test loss:  0.539 test accuracy:  72.4%
# epoch: 95 training loss:  0.527 training accuracy:  73.4%  test loss:  0.523 test accuracy:  76.4%
# epoch: 96 training loss:  0.547 training accuracy:  73.2%  test loss:  0.531 test accuracy:  75.6%
# epoch: 97 training loss:  0.544 training accuracy:  72.2%  test loss:  0.514 test accuracy:  75.6%
# epoch: 98 training loss:  0.539 training accuracy:  74.8%  test loss:  0.507 test accuracy:  75.6%
# epoch: 99 training loss:  0.536 training accuracy:  75.2%  test loss:  0.511 test accuracy:  78.7%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import functions as fun
from pointnetfunct.PointNet_trainingfunct import load_model

pointnet_copy = PointNet_2Multimodal_withDNN(classes=2)
model_path = "./pointnet_2multimodal_ppd_1000pt_test.pth"
load_model(pointnet_copy,model_path)
y_true = []
y_pred = []
y_probs = []
y_pred_result = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,inputs_v2,inputs_v3,labels in test_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        inputs_v3 = inputs_v3.to(torch.float32)

        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v,inputs_v3)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) 
        y_probs.extend(outputs)

# %%
from pointnetfunct.evaluation import show_graph
show_graph(path ="./result/2multimodel_ppd_test.pt",device = "cuda",name = "1000pt_2branch_trainingtrend")

# %%
from pointnetfunct.evaluation import show_cm_dl,show_graph,print_values,draw_rocgraph

draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_2branch_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_2branch_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.57
# F1 score: 0.3384615384615385
# Rupture Recall: 0.25
# Rupture Precision: 0.5238095238095238
# UnRupture Recall: 0.8214285714285714
# UnRupture Precision: 0.5822784810126582

# %%
pointnet_copy = PointNet_2Multimodal_withDNN(classes=2)
model_path = "./pointnet_2multimodal_ppd_1000pt_test.pth"
load_model(pointnet_copy,model_path)
y_true = []
y_pred = []
y_probs = []
y_pred_result = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,inputs_v2,inputs_v3,labels in valid_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        inputs_v3 = inputs_v3.to(torch.float32)

        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v,inputs_v3)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) 
        y_probs.extend(outputs)

# %%
from pointnetfunct.evaluation import show_cm_dl,show_graph,print_values,draw_rocgraph

draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_2branch_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_2branch_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.7637795275590551
# F1 score: 0.625
# Rupture Recall: 0.625
# Rupture Precision: 0.625
# UnRupture Recall: 0.8275862068965517
# UnRupture Precision: 0.8275862068965517

# %% [markdown]
# 3multihead

# %%
import functions
from pointnetfunct.PointNet_struct import PointNet_3Multihead_withDNN
from pointnetfunct.PointNet_trainingfunct import run_model_3multi_head_dnn
pointnet_mh = PointNet_3Multihead_withDNN(classes=2)
run_model_3multi_head_dnn(train_loader_input = train_loader,
                        vaild_loader_input = valid_loader,
                        nepochs = 100, 
                        modelnet = pointnet_mh,
                        results_path = "./result", 
                        filename = "/3multimodal_ppd_test.pt",
                        model_name= "pointnet_3multimodal_ppd_1000pt_test.pth")
pointnet_mh.to("cpu")
# Out:
# epoch: 0 training loss:  0.736 training accuracy:  49.6%  test loss:  0.679 test accuracy:  55.1%
# epoch: 1 training loss:  0.691 training accuracy:  62.0%  test loss:  0.717 test accuracy:  51.2%
# epoch: 2 training loss:  0.709 training accuracy:  62.2%  test loss:  0.701 test accuracy:  58.3%
# epoch: 3 training loss:  0.688 training accuracy:  64.2%  test loss:  0.678 test accuracy:  57.5%
# epoch: 4 training loss:  0.680 training accuracy:  63.2%  test loss:  0.702 test accuracy:  52.8%
# epoch: 5 training loss:  0.655 training accuracy:  66.1%  test loss:  0.680 test accuracy:  63.8%
# epoch: 6 training loss:  0.668 training accuracy:  67.1%  test loss:  0.671 test accuracy:  63.8%
# epoch: 7 training loss:  0.665 training accuracy:  64.0%  test loss:  0.671 test accuracy:  62.2%
# epoch: 8 training loss:  0.679 training accuracy:  68.9%  test loss:  0.666 test accuracy:  70.9%
# epoch: 9 training loss:  0.675 training accuracy:  71.3%  test loss:  0.649 test accuracy:  63.8%
# epoch: 10 training loss:  0.649 training accuracy:  69.7%  test loss:  0.661 test accuracy:  69.3%
# epoch: 11 training loss:  0.641 training accuracy:  67.1%  test loss:  0.680 test accuracy:  60.6%
# epoch: 12 training loss:  0.659 training accuracy:  66.3%  test loss:  0.684 test accuracy:  70.1%
# epoch: 13 training loss:  0.655 training accuracy:  70.3%  test loss:  0.690 test accuracy:  63.8%
# epoch: 14 training loss:  0.640 training accuracy:  70.1%  test loss:  0.661 test accuracy:  66.1%
# epoch: 15 training loss:  0.649 training accuracy:  67.5%  test loss:  0.670 test accuracy:  63.8%
# epoch: 16 training loss:  0.634 training accuracy:  68.9%  test loss:  0.679 test accuracy:  63.8%
# epoch: 17 training loss:  0.629 training accuracy:  70.3%  test loss:  0.658 test accuracy:  65.4%
# epoch: 18 training loss:  0.640 training accuracy:  71.5%  test loss:  0.663 test accuracy:  66.1%
# epoch: 19 training loss:  0.626 training accuracy:  70.1%  test loss:  0.640 test accuracy:  66.1%
# epoch: 20 training loss:  0.620 training accuracy:  70.7%  test loss:  0.617 test accuracy:  69.3%
# epoch: 21 training loss:  0.623 training accuracy:  71.3%  test loss:  0.640 test accuracy:  69.3%
# epoch: 22 training loss:  0.635 training accuracy:  69.9%  test loss:  0.632 test accuracy:  71.7%
# epoch: 23 training loss:  0.619 training accuracy:  72.8%  test loss:  0.681 test accuracy:  70.1%
# epoch: 24 training loss:  0.607 training accuracy:  71.9%  test loss:  0.646 test accuracy:  71.7%
# epoch: 25 training loss:  0.599 training accuracy:  72.6%  test loss:  0.629 test accuracy:  70.9%
# epoch: 26 training loss:  0.585 training accuracy:  70.3%  test loss:  0.656 test accuracy:  71.7%
# epoch: 27 training loss:  0.606 training accuracy:  73.0%  test loss:  0.611 test accuracy:  74.0%
# epoch: 28 training loss:  0.602 training accuracy:  71.7%  test loss:  0.632 test accuracy:  70.9%
# epoch: 29 training loss:  0.620 training accuracy:  73.0%  test loss:  0.640 test accuracy:  71.7%
# epoch: 30 training loss:  0.606 training accuracy:  72.2%  test loss:  0.598 test accuracy:  71.7%
# epoch: 31 training loss:  0.613 training accuracy:  73.4%  test loss:  0.603 test accuracy:  72.4%
# epoch: 32 training loss:  0.597 training accuracy:  75.4%  test loss:  0.601 test accuracy:  70.9%
# epoch: 33 training loss:  0.616 training accuracy:  73.8%  test loss:  0.619 test accuracy:  73.2%
# epoch: 34 training loss:  0.584 training accuracy:  76.0%  test loss:  0.620 test accuracy:  71.7%
# epoch: 35 training loss:  0.587 training accuracy:  72.8%  test loss:  0.612 test accuracy:  76.4%
# epoch: 36 training loss:  0.579 training accuracy:  75.2%  test loss:  0.604 test accuracy:  73.2%
# epoch: 37 training loss:  0.601 training accuracy:  73.0%  test loss:  0.623 test accuracy:  71.7%
# epoch: 38 training loss:  0.597 training accuracy:  76.0%  test loss:  0.573 test accuracy:  74.8%
# epoch: 39 training loss:  0.566 training accuracy:  74.8%  test loss:  0.604 test accuracy:  72.4%
# epoch: 40 training loss:  0.575 training accuracy:  73.2%  test loss:  0.546 test accuracy:  77.2%
# epoch: 41 training loss:  0.590 training accuracy:  70.3%  test loss:  0.561 test accuracy:  78.0%
# epoch: 42 training loss:  0.566 training accuracy:  75.0%  test loss:  0.539 test accuracy:  78.7%
# epoch: 43 training loss:  0.574 training accuracy:  73.8%  test loss:  0.566 test accuracy:  78.0%
# epoch: 44 training loss:  0.580 training accuracy:  74.0%  test loss:  0.570 test accuracy:  76.4%
# epoch: 45 training loss:  0.569 training accuracy:  76.4%  test loss:  0.551 test accuracy:  74.0%
# epoch: 46 training loss:  0.570 training accuracy:  75.6%  test loss:  0.541 test accuracy:  78.0%
# epoch: 47 training loss:  0.590 training accuracy:  72.0%  test loss:  0.550 test accuracy:  74.0%
# epoch: 48 training loss:  0.579 training accuracy:  74.2%  test loss:  0.550 test accuracy:  76.4%
# epoch: 49 training loss:  0.553 training accuracy:  75.2%  test loss:  0.543 test accuracy:  76.4%
# epoch: 50 training loss:  0.589 training accuracy:  72.2%  test loss:  0.533 test accuracy:  74.0%
# epoch: 51 training loss:  0.547 training accuracy:  76.0%  test loss:  0.531 test accuracy:  78.0%
# epoch: 52 training loss:  0.584 training accuracy:  72.0%  test loss:  0.539 test accuracy:  75.6%
# epoch: 53 training loss:  0.602 training accuracy:  74.0%  test loss:  0.533 test accuracy:  75.6%
# epoch: 54 training loss:  0.549 training accuracy:  77.0%  test loss:  0.533 test accuracy:  76.4%
# epoch: 55 training loss:  0.557 training accuracy:  75.0%  test loss:  0.544 test accuracy:  76.4%
# epoch: 56 training loss:  0.550 training accuracy:  75.8%  test loss:  0.528 test accuracy:  76.4%
# epoch: 57 training loss:  0.591 training accuracy:  74.8%  test loss:  0.493 test accuracy:  79.5%
# epoch: 58 training loss:  0.545 training accuracy:  74.8%  test loss:  0.530 test accuracy:  78.0%
# epoch: 59 training loss:  0.556 training accuracy:  75.6%  test loss:  0.527 test accuracy:  74.8%
# epoch: 60 training loss:  0.567 training accuracy:  73.6%  test loss:  0.538 test accuracy:  75.6%
# epoch: 61 training loss:  0.563 training accuracy:  73.8%  test loss:  0.514 test accuracy:  81.9%
# epoch: 62 training loss:  0.529 training accuracy:  76.8%  test loss:  0.500 test accuracy:  80.3%
# epoch: 63 training loss:  0.549 training accuracy:  75.4%  test loss:  0.507 test accuracy:  81.9%
# epoch: 64 training loss:  0.553 training accuracy:  74.8%  test loss:  0.512 test accuracy:  78.7%
# epoch: 65 training loss:  0.563 training accuracy:  75.8%  test loss:  0.528 test accuracy:  78.0%
# epoch: 66 training loss:  0.532 training accuracy:  75.2%  test loss:  0.526 test accuracy:  77.2%
# epoch: 67 training loss:  0.524 training accuracy:  75.4%  test loss:  0.510 test accuracy:  75.6%
# epoch: 68 training loss:  0.538 training accuracy:  77.6%  test loss:  0.526 test accuracy:  78.0%
# epoch: 69 training loss:  0.541 training accuracy:  76.8%  test loss:  0.509 test accuracy:  78.7%
# epoch: 70 training loss:  0.548 training accuracy:  76.2%  test loss:  0.526 test accuracy:  78.7%
# epoch: 71 training loss:  0.550 training accuracy:  74.8%  test loss:  0.524 test accuracy:  78.7%
# epoch: 72 training loss:  0.535 training accuracy:  76.2%  test loss:  0.485 test accuracy:  78.7%
# epoch: 73 training loss:  0.527 training accuracy:  76.8%  test loss:  0.508 test accuracy:  76.4%
# epoch: 74 training loss:  0.535 training accuracy:  75.4%  test loss:  0.508 test accuracy:  78.7%
# epoch: 75 training loss:  0.522 training accuracy:  76.4%  test loss:  0.516 test accuracy:  77.2%
# epoch: 76 training loss:  0.519 training accuracy:  75.8%  test loss:  0.507 test accuracy:  78.0%
# epoch: 77 training loss:  0.541 training accuracy:  76.4%  test loss:  0.513 test accuracy:  78.0%
# epoch: 78 training loss:  0.543 training accuracy:  76.0%  test loss:  0.502 test accuracy:  75.6%
# epoch: 79 training loss:  0.525 training accuracy:  77.2%  test loss:  0.515 test accuracy:  74.0%
# epoch: 80 training loss:  0.521 training accuracy:  76.2%  test loss:  0.516 test accuracy:  77.2%
# epoch: 81 training loss:  0.503 training accuracy:  76.2%  test loss:  0.489 test accuracy:  78.7%
# epoch: 82 training loss:  0.549 training accuracy:  74.6%  test loss:  0.495 test accuracy:  79.5%
# epoch: 83 training loss:  0.536 training accuracy:  75.4%  test loss:  0.497 test accuracy:  79.5%
# epoch: 84 training loss:  0.525 training accuracy:  75.8%  test loss:  0.499 test accuracy:  76.4%
# epoch: 85 training loss:  0.527 training accuracy:  77.4%  test loss:  0.481 test accuracy:  77.2%
# epoch: 86 training loss:  0.513 training accuracy:  78.1%  test loss:  0.501 test accuracy:  77.2%
# epoch: 87 training loss:  0.522 training accuracy:  76.0%  test loss:  0.483 test accuracy:  79.5%
# epoch: 88 training loss:  0.541 training accuracy:  75.4%  test loss:  0.515 test accuracy:  76.4%
# epoch: 89 training loss:  0.524 training accuracy:  74.2%  test loss:  0.484 test accuracy:  76.4%
# epoch: 90 training loss:  0.500 training accuracy:  77.8%  test loss:  0.493 test accuracy:  75.6%
# epoch: 91 training loss:  0.534 training accuracy:  75.4%  test loss:  0.489 test accuracy:  78.7%
# epoch: 92 training loss:  0.556 training accuracy:  76.0%  test loss:  0.506 test accuracy:  77.2%
# epoch: 93 training loss:  0.512 training accuracy:  78.5%  test loss:  0.499 test accuracy:  76.4%
# epoch: 94 training loss:  0.566 training accuracy:  75.8%  test loss:  0.473 test accuracy:  78.7%
# epoch: 95 training loss:  0.509 training accuracy:  76.0%  test loss:  0.504 test accuracy:  77.2%
# epoch: 96 training loss:  0.522 training accuracy:  77.0%  test loss:  0.472 test accuracy:  78.0%
# epoch: 97 training loss:  0.522 training accuracy:  75.4%  test loss:  0.480 test accuracy:  81.9%
# epoch: 98 training loss:  0.514 training accuracy:  76.2%  test loss:  0.485 test accuracy:  76.4%
# epoch: 99 training loss:  0.510 training accuracy:  79.7%  test loss:  0.486 test accuracy:  78.0%
# PointNet_3Multihead_withDNN(
#   (transform): Transform(
#     (input_transform): Tnet(
#       (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=9, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (feature_transform): Tnet(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=4096, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=3, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=64, bias=True)
#     (fc4): Linear(in_features=64, out_features=128, bias=True)
#     (fc5): Linear(in_features=128, out_features=1024, bias=True)
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (transform2): Transform(
#     (input_transform): Tnet(
#       (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=9, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (feature_transform): Tnet(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=4096, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=3, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=64, bias=True)
#     (fc4): Linear(in_features=64, out_features=128, bias=True)
#     (fc5): Linear(in_features=128, out_features=1024, bias=True)
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (transform4): Transform_2Multi(
#     (input_transform): Tnet(
#       (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=9, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (feature_transform): Tnet(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=4096, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=3, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=64, bias=True)
#     (fc4): Linear(in_features=64, out_features=128, bias=True)
#     (fc5): Linear(in_features=128, out_features=1024, bias=True)
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (transform5): Transform_2Multi(
#     (input_transform): Tnet(
#       (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=9, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (feature_transform): Tnet(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=4096, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 512, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=3, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=64, bias=True)
#     (fc4): Linear(in_features=64, out_features=128, bias=True)
#     (fc5): Linear(in_features=128, out_features=1024, bias=True)
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (transform3): DNNModel(
#     (Flatten): Flatten(start_dim=1, end_dim=-1)
#     (fc1): Linear(in_features=172, out_features=512, bias=True)
#     (relu): ReLU()
#     (fc2): Linear(in_features=512, out_features=256, bias=True)
#     (fc3): Linear(in_features=256, out_features=128, bias=True)
#     (loss_fn): CrossEntropyLoss()
#     (logsoftmax): LogSoftmax(dim=1)
#     (dropout): Dropout(p=0.3, inplace=False)
#     (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc1): Linear(in_features=1152, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=2, bias=True)
#   (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (logsoftmax): LogSoftmax(dim=1)
#   (loss_fn): CrossEntropyLoss()
# )

# %%
device = torch.device('cuda:0')
show_graph(path ="./result/3multimodal_ppd_test.pt",device = "cuda",name ="1000pt_3branch_trainingtrend")

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import functions as fun
from pointnetfunct.PointNet_trainingfunct import load_model

pointnet_copy = PointNet_3Multihead_withDNN(classes=2)
model_path = "./pointnet_3multimodal_ppd_1000pt_test.pth"
load_model(pointnet_copy,model_path)
y_true = []
y_pred = []
y_probs = []
y_pred_result = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,inputs_v2,inputs_v3,labels in test_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        inputs_v2 = inputs_v2.to(torch.float32)
        inputs_v2 = inputs_v2.squeeze(1).permute(0, 2, 1)
        inputs_v3 = inputs_v3.to(torch.float32)

        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v,inputs_v2,inputs_v3)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) 
        y_probs.extend(outputs)

# %%
from pointnetfunct.evaluation import show_cm_dl,show_graph,print_values,draw_rocgraph

draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_3branch_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_3branch_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.6
# F1 score: 0.4444444444444444
# Rupture Recall: 0.36363636363636365
# Rupture Precision: 0.5714285714285714
# UnRupture Recall: 0.7857142857142857
# UnRupture Precision: 0.6111111111111112

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import functions as fun
from pointnetfunct.PointNet_trainingfunct import load_model

pointnet_copy = PointNet_3Multihead_withDNN(classes=2)
model_path = "./pointnet_3multimodal_ppd_1000pt_test.pth"
load_model(pointnet_copy,model_path)
y_true = []
y_pred = []
y_probs = []
y_pred_result = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,inputs_v2,inputs_v3,labels in valid_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        inputs_v2 = inputs_v2.to(torch.float32)
        inputs_v2 = inputs_v2.squeeze(1).permute(0, 2, 1)
        inputs_v3 = inputs_v3.to(torch.float32)

        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v,inputs_v2,inputs_v3)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) 
        y_probs.extend(outputs)

# %%
draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_3branch_AOC")
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_3branch_CM")
print_values (y_true, y_pred_result)
# Out:
# Accuracy: 0.7795275590551181
# F1 score: 0.6888888888888889
# Rupture Recall: 0.775
# Rupture Precision: 0.62
# UnRupture Recall: 0.7816091954022989
# UnRupture Precision: 0.8831168831168831

# %% [markdown]
# 68%~78%
