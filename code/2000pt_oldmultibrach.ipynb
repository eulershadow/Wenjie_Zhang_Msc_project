# %%
import vtk
import os
import numpy as np
import itertools
import math, random
import data_process_ml
random.seed = 42
import copy

import torch
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
from torchvision import transforms, utils

import scipy.spatial.distance
# import plotly.graph_objects as go
# import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
import open3d as o3d
def reduce_mesh(target_mesh, reference_mesh):
    # Find common vertices between the two meshes
    output_mesh = copy.deepcopy(target_mesh)
    target_vertices = set(tuple(vertex) for vertex in np.asarray(target_mesh.vertices))
    target_vertices_list = [tuple(vertex) for vertex in np.asarray(target_mesh.vertices)]
    index_dict = {item: index for index, item in enumerate(target_vertices_list)}
    reference_vertices = set(tuple(vertex) for vertex in np.asarray(reference_mesh.vertices))

    common_vertices = target_vertices.intersection(reference_vertices)
    #print(len(list(common_vertices)))
    list_mine = [index_dict[element_to_find] for element_to_find in list(common_vertices)]

    #print(list_mine)

    # Filter out vertices and triangles based on common vertices
    output_mesh.remove_vertices_by_index(list_mine)

    return output_mesh

def mesh_to_point_cloud(file_path,points = 10000):
    """
    Convert a mesh object to a point cloud object.
    """
    mesh = o3d.io.read_triangle_mesh(file_path)
    point_cloud = mesh.sample_points_uniformly(number_of_points=points) # Adjust number_of_points as needed
    return point_cloud
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
import vtk
import numpy as np

def vtp_to_mesh(file_path):
    reader = vtk.vtkXMLPolyDataReader()
    reader.SetFileName(file_path)
    reader.Update()
    polydata = reader.GetOutput()

    vertices = np.array(polydata.GetPoints().GetData())
    polygons = np.array(polydata.GetPolys().GetData())

    # Extract vertices
    vertices = vertices.reshape(-1, 3)

    # Extract faces
    faces = polygons.reshape(-1, 4)[:, 1:]  

    mesh = o3d.geometry.TriangleMesh()
    mesh.vertices = o3d.utility.Vector3dVector(vertices)
    mesh.triangles = o3d.utility.Vector3iVector(faces)
    return mesh

def vtp_to_point_cloud(file_path,points = 10000):
    mesh = o3d.geometry.TriangleMesh()
    if ".vtp" not in file_path:
        mesh = o3d.io.read_triangle_mesh(file_path)
    else:
        mesh = vtp_to_mesh(file_path)
        
    #o3d.visualization.draw_geometries([mesh])
    # if (len(mesh.vertices))>10000:
    #     print(len(mesh.vertices))

    point_cloud = mesh.sample_points_uniformly(number_of_points=points)

    return point_cloud

def vtp_to_point_cloud_cutvessel(vessel_file_path,cut_file_path, points = 10000):
    """
    Convert a mesh object to a point cloud object.
    """
    if ".vtp" not in vessel_file_path:
        vessel_mesh = o3d.io.read_triangle_mesh(vessel_file_path)
    else:
        vessel_mesh = vtp_to_mesh(vessel_file_path)
    if ".vtp" not in cut_file_path:
        cut_mesh = o3d.io.read_triangle_mesh(cut_file_path)
    else:
        cut_mesh = vtp_to_mesh(cut_file_path)
    
    box_mesh = cut_mesh.get_axis_aligned_bounding_box()
    reduced_mesh =  vessel_mesh.crop(box_mesh) 
    result_mesh = reduce_mesh(vessel_mesh,reduced_mesh)
    #print(cut1_mesh,result_mesh)
    # if vessel_mesh.vertices == result_mesh.vertices:
    #     return False
                  
    #o3d.visualization.draw_geometries([result_mesh])
    #o3d.visualization.draw_geometries([reduced_mesh])
    # if (len(vessel_mesh.vertices))>10000:
    #     print("larger")
    
    point_cloud = result_mesh.sample_points_uniformly(number_of_points=points) # Adjust number_of_points as needed
    return point_cloud

# %% [markdown]
# load the dataset

# %%
root = "..\..\msc_data\models-v1.0\models"
IA = "aneurysms\\remeshed\\area-001"
Vessel = "vessels\\remeshed\\area-001"
IA_root = os.path.join(root,IA)
Vessel_root = os.path.join(root,Vessel)
list1 = os.listdir(Vessel_root)
list2 = os.listdir(IA_root)

# %%
morpho_path = ".\AneuX\data-v1.0\data\morpho-per-cut.csv"
patient_path = ".\AneuX\data-v1.0\data\clinical.csv"
morpho_data_patient = data_process_ml.read_and_combine_data(morpho_path,patient_path)
merged_dataset = data_process_ml.encode_column(morpho_data_patient)
merged_dataset = data_process_ml.drop_columns(merged_dataset)
morpho_data_cut1,morpho_data_dome = data_process_ml.output_cut1anddome(merged_dataset)
# Out:
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_dome.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)

# %%
import pandas as pd
from pointnetfunct.PointNet_dataset import Aneux_Dataset_load
df = pd.DataFrame()
# Aneux_Dataset = Aneuxmodel_Dataset(root = root,
#                                    df=morpho_data_patient[morpho_data_patient["cuttype"] == "dome"],
#                                    transform = transforms.ToTensor(),
#                                    mesh = "area-001",
#                                    cuttype = "dome",
#                                    crop = False)

Aneux_Dataset = Aneux_Dataset_load('./Aneux_Dataset_2000pt_sample_train.pt')
Aneux_Dataset.paraout = True
Aneux_Dataset_test = Aneux_Dataset_load('./Aneux_Dataset_2000pt_sample_100test.pt')
# Out:
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_dome.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(morpho_data_cut1.columns[3:23], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_cut1.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)
# d:\Universityofleeds\MSC_PROG\Msc_project\code\data_process_ml.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morpho_data_dome.drop(['source_x',"cuttype","dataset"], axis=1, inplace=True)

# %%
print(len(Aneux_Dataset.model_table),len(Aneux_Dataset.label))
print(Aneux_Dataset.points)
# Out:
# 600 600
# 2000

# %%
from torch.utils.data import Subset

#torch.manual_seed(25447239782700)

train_size = int(len(Aneux_Dataset) * 0.85) # 80% training data
valid_size = len(Aneux_Dataset) - train_size
train_data, valid_data = random_split(Aneux_Dataset, [train_size, valid_size])

train_loader = torch.utils.data.DataLoader(
    train_data,
    batch_size=50,
    shuffle=True,
    #num_workers=2, 
    pin_memory=True
)

valid_loader = torch.utils.data.DataLoader(
    valid_data,
    batch_size=50, # Forward pass only so batch size can be larger
    shuffle=False,
    #num_workers=2, 
    pin_memory=True
)

test_loader = torch.utils.data.DataLoader(
    Aneux_Dataset_test,
    batch_size=50, # Forward pass only so batch size can be larger
    shuffle=False,
    #num_workers=2, 
    pin_memory=True
)

# %% [markdown]
# Test vaildation

# %%
file = "\\C0006"
model_list = []
for model_name in list1[:1]:
    file = model_name[:-4]
    Vessel_root_file = Vessel_root + "\\" + file + ".vtp"
    
    IA_name_cut1 = ""
    IA_name_dome = ""
    for IA_model in list2:
        
        if file in IA_model and "cut1" in IA_model and file not in IA_name_cut1:
            print("find:" + IA_model)
            IA_name_cut1 = IA_model
        elif file.split("_")[0] in IA_model and "cut1" in IA_model and IA_name_cut1 == "":
            IA_name_cut1 = IA_model
            
        if file in IA_model and "dome" in IA_model and file not in IA_name_dome:
            IA_name_dome = IA_model
        elif file.split("_")[0] in IA_model and "dome" in IA_model and IA_name_dome == "":
            IA_name_dome = IA_model
            
        if IA_name_cut1 != "" and IA_name_dome != "" and file in IA_name_cut1 and file in IA_name_dome:
            break
            
    print(IA_name_cut1)
    IA_root_file = os.path.join(IA_root,IA_name_cut1)
    modelcov_vtp = True
    if IA_name_cut1 != "" and IA_name_dome!= "":
        modelcov_vtp = vtp_to_point_cloud_cutvessel(Vessel_root_file,IA_root_file)
    if modelcov_vtp == False:
        print("Can not crop: " + file)
        print("Vessel root name: " + Vessel_root_file)
        print("IA root name: " + IA_root_file)
        break
         #o3d.visualization.draw_geometries([modelcov_vtp])
    else:
        model_list.append(modelcov_vtp)
# Out:
# find:ANSYS_UNIGE_09_cut1.vtp
# ANSYS_UNIGE_09_cut1.vtp

# %%
print(len(list1),len(model_list))
print(model_list)
# Out:
# 682 1
# [PointCloud with 10000 points.]

# %% [markdown]
# # PointNet model

# %%
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torch import optim
from pointnetfunct.PointNet_struct import Tnet,Transform,PointNet,PointNet_2Multihead,PointNet_3Multihead

# %% [markdown]
# Run model

# %%
import functions
from pointnetfunct.PointNet_trainingfunct import run_model_get,run_model_3multi_head_dnn,run_model_2multi_head_dnn,load_model
from pointnetfunct.PointNet_struct import PointNet,PointNet_2Multimodal_withDNN,PointNet_3Multihead_withDNN

pointnet = PointNet(classes=2)
run_model_get(train_loader_input = train_loader,
                        vaild_loader_input = valid_loader,
                        nepochs = 100, 
                        modelnet = pointnet,
                        results_path = "./result", 
                        filename = "/dome_200pt_test.pt",
                        model_name="pointnet_2000pt.pth")
pointnet.to("cpu")
# Out:
# epoch: 0 training loss:  0.696 training accuracy:  62.1%  test loss:  0.647 test accuracy:  63.9%
# epoch: 1 training loss:  0.671 training accuracy:  65.5%  test loss:  0.658 test accuracy:  63.3%
# epoch: 2 training loss:  0.669 training accuracy:  65.6%  test loss:  0.654 test accuracy:  65.3%
# epoch: 3 training loss:  0.664 training accuracy:  64.8%  test loss:  0.656 test accuracy:  64.6%
# epoch: 4 training loss:  0.669 training accuracy:  64.3%  test loss:  0.603 test accuracy:  68.0%
# epoch: 5 training loss:  0.671 training accuracy:  64.5%  test loss:  0.671 test accuracy:  65.3%
# epoch: 6 training loss:  0.657 training accuracy:  64.3%  test loss:  0.641 test accuracy:  66.0%
# epoch: 7 training loss:  0.667 training accuracy:  62.6%  test loss:  0.631 test accuracy:  66.0%
# epoch: 8 training loss:  0.662 training accuracy:  64.8%  test loss:  0.684 test accuracy:  64.6%
# epoch: 9 training loss:  0.664 training accuracy:  65.0%  test loss:  0.636 test accuracy:  66.0%
# epoch: 10 training loss:  0.674 training accuracy:  65.1%  test loss:  0.653 test accuracy:  63.9%
# epoch: 11 training loss:  0.638 training accuracy:  64.6%  test loss:  0.633 test accuracy:  66.7%
# epoch: 12 training loss:  0.648 training accuracy:  64.3%  test loss:  0.618 test accuracy:  64.6%
# epoch: 13 training loss:  0.673 training accuracy:  64.6%  test loss:  0.607 test accuracy:  67.3%
# epoch: 14 training loss:  0.650 training accuracy:  65.5%  test loss:  0.607 test accuracy:  67.3%
# epoch: 15 training loss:  0.632 training accuracy:  63.9%  test loss:  0.623 test accuracy:  65.3%
# epoch: 16 training loss:  0.635 training accuracy:  64.3%  test loss:  0.616 test accuracy:  66.7%
# epoch: 17 training loss:  0.651 training accuracy:  62.8%  test loss:  0.617 test accuracy:  64.6%
# epoch: 18 training loss:  0.648 training accuracy:  65.3%  test loss:  0.619 test accuracy:  65.3%
# epoch: 19 training loss:  0.654 training accuracy:  65.1%  test loss:  0.600 test accuracy:  66.0%
# epoch: 20 training loss:  0.649 training accuracy:  62.8%  test loss:  0.601 test accuracy:  66.7%
# epoch: 21 training loss:  0.649 training accuracy:  64.8%  test loss:  0.623 test accuracy:  63.9%
# epoch: 22 training loss:  0.642 training accuracy:  62.1%  test loss:  0.609 test accuracy:  66.0%
# epoch: 23 training loss:  0.641 training accuracy:  64.5%  test loss:  0.627 test accuracy:  66.7%
# epoch: 24 training loss:  0.629 training accuracy:  66.5%  test loss:  0.635 test accuracy:  66.0%
# epoch: 25 training loss:  0.640 training accuracy:  64.8%  test loss:  0.634 test accuracy:  66.7%
# epoch: 26 training loss:  0.630 training accuracy:  64.5%  test loss:  0.609 test accuracy:  66.0%
# epoch: 27 training loss:  0.622 training accuracy:  67.2%  test loss:  0.608 test accuracy:  63.3%
# epoch: 28 training loss:  0.636 training accuracy:  63.8%  test loss:  0.602 test accuracy:  70.7%
# epoch: 29 training loss:  0.637 training accuracy:  65.1%  test loss:  0.615 test accuracy:  63.9%
# epoch: 30 training loss:  0.656 training accuracy:  64.8%  test loss:  0.614 test accuracy:  63.9%
# epoch: 31 training loss:  0.633 training accuracy:  67.0%  test loss:  0.625 test accuracy:  70.1%
# epoch: 32 training loss:  0.625 training accuracy:  64.5%  test loss:  0.607 test accuracy:  66.7%
# epoch: 33 training loss:  0.622 training accuracy:  63.9%  test loss:  0.614 test accuracy:  68.0%
# epoch: 34 training loss:  0.616 training accuracy:  64.6%  test loss:  0.612 test accuracy:  66.7%
# epoch: 35 training loss:  0.626 training accuracy:  65.8%  test loss:  0.614 test accuracy:  68.7%
# epoch: 36 training loss:  0.631 training accuracy:  67.5%  test loss:  0.612 test accuracy:  67.3%
# epoch: 37 training loss:  0.615 training accuracy:  65.5%  test loss:  0.603 test accuracy:  63.9%
# epoch: 38 training loss:  0.613 training accuracy:  64.3%  test loss:  0.626 test accuracy:  64.6%
# epoch: 39 training loss:  0.637 training accuracy:  65.3%  test loss:  0.582 test accuracy:  67.3%
# epoch: 40 training loss:  0.621 training accuracy:  65.3%  test loss:  0.612 test accuracy:  66.7%
# epoch: 41 training loss:  0.622 training accuracy:  64.1%  test loss:  0.604 test accuracy:  66.0%
# epoch: 42 training loss:  0.638 training accuracy:  66.8%  test loss:  0.633 test accuracy:  67.3%
# epoch: 43 training loss:  0.627 training accuracy:  66.8%  test loss:  0.600 test accuracy:  68.0%
# epoch: 44 training loss:  0.615 training accuracy:  66.0%  test loss:  0.612 test accuracy:  68.7%
# epoch: 45 training loss:  0.601 training accuracy:  67.9%  test loss:  0.632 test accuracy:  66.7%
# epoch: 46 training loss:  0.589 training accuracy:  70.1%  test loss:  0.645 test accuracy:  66.0%
# epoch: 47 training loss:  0.615 training accuracy:  67.7%  test loss:  0.631 test accuracy:  63.9%
# epoch: 48 training loss:  0.591 training accuracy:  69.9%  test loss:  0.648 test accuracy:  68.0%
# epoch: 49 training loss:  0.602 training accuracy:  69.7%  test loss:  0.649 test accuracy:  68.7%
# epoch: 50 training loss:  0.618 training accuracy:  69.6%  test loss:  0.647 test accuracy:  68.7%
# epoch: 51 training loss:  0.610 training accuracy:  66.5%  test loss:  0.610 test accuracy:  67.3%
# epoch: 52 training loss:  0.608 training accuracy:  68.9%  test loss:  0.605 test accuracy:  69.4%
# epoch: 53 training loss:  0.624 training accuracy:  67.3%  test loss:  0.616 test accuracy:  64.6%
# epoch: 54 training loss:  0.596 training accuracy:  68.2%  test loss:  0.606 test accuracy:  68.7%
# epoch: 55 training loss:  0.597 training accuracy:  69.0%  test loss:  0.628 test accuracy:  68.7%
# epoch: 56 training loss:  0.606 training accuracy:  68.7%  test loss:  0.644 test accuracy:  66.0%
# epoch: 57 training loss:  0.597 training accuracy:  68.4%  test loss:  0.627 test accuracy:  68.0%
# epoch: 58 training loss:  0.589 training accuracy:  70.7%  test loss:  0.658 test accuracy:  65.3%
# epoch: 59 training loss:  0.600 training accuracy:  67.7%  test loss:  0.607 test accuracy:  69.4%
# epoch: 60 training loss:  0.588 training accuracy:  68.7%  test loss:  0.616 test accuracy:  68.0%
# epoch: 61 training loss:  0.580 training accuracy:  71.3%  test loss:  0.628 test accuracy:  66.0%
# epoch: 62 training loss:  0.565 training accuracy:  70.9%  test loss:  0.622 test accuracy:  68.0%
# epoch: 63 training loss:  0.615 training accuracy:  70.4%  test loss:  0.626 test accuracy:  68.0%
# epoch: 64 training loss:  0.570 training accuracy:  73.3%  test loss:  0.607 test accuracy:  70.7%
# epoch: 65 training loss:  0.575 training accuracy:  71.6%  test loss:  0.688 test accuracy:  65.3%
# epoch: 66 training loss:  0.592 training accuracy:  68.5%  test loss:  0.612 test accuracy:  62.6%
# epoch: 67 training loss:  0.602 training accuracy:  70.4%  test loss:  0.593 test accuracy:  66.7%
# epoch: 68 training loss:  0.557 training accuracy:  73.0%  test loss:  0.629 test accuracy:  67.3%
# epoch: 69 training loss:  0.568 training accuracy:  71.4%  test loss:  0.584 test accuracy:  71.4%
# epoch: 70 training loss:  0.613 training accuracy:  69.0%  test loss:  0.602 test accuracy:  66.7%
# epoch: 71 training loss:  0.593 training accuracy:  69.0%  test loss:  0.600 test accuracy:  68.0%
# epoch: 72 training loss:  0.577 training accuracy:  73.3%  test loss:  0.584 test accuracy:  68.0%
# epoch: 73 training loss:  0.588 training accuracy:  72.6%  test loss:  0.615 test accuracy:  66.0%
# epoch: 74 training loss:  0.573 training accuracy:  70.6%  test loss:  0.611 test accuracy:  69.4%
# epoch: 75 training loss:  0.570 training accuracy:  70.9%  test loss:  0.634 test accuracy:  64.6%
# epoch: 76 training loss:  0.571 training accuracy:  70.2%  test loss:  0.601 test accuracy:  69.4%
# epoch: 77 training loss:  0.585 training accuracy:  69.7%  test loss:  0.578 test accuracy:  70.1%
# epoch: 78 training loss:  0.574 training accuracy:  72.6%  test loss:  0.605 test accuracy:  69.4%
# epoch: 79 training loss:  0.552 training accuracy:  72.6%  test loss:  0.593 test accuracy:  67.3%
# epoch: 80 training loss:  0.543 training accuracy:  74.5%  test loss:  0.636 test accuracy:  67.3%
# epoch: 81 training loss:  0.543 training accuracy:  77.6%  test loss:  0.578 test accuracy:  68.0%
# epoch: 82 training loss:  0.571 training accuracy:  74.5%  test loss:  0.631 test accuracy:  67.3%
# epoch: 83 training loss:  0.556 training accuracy:  72.6%  test loss:  0.604 test accuracy:  71.4%
# epoch: 84 training loss:  0.568 training accuracy:  70.7%  test loss:  0.589 test accuracy:  66.0%
# epoch: 85 training loss:  0.556 training accuracy:  72.6%  test loss:  0.621 test accuracy:  67.3%
# epoch: 86 training loss:  0.556 training accuracy:  73.0%  test loss:  0.620 test accuracy:  66.7%
# epoch: 87 training loss:  0.565 training accuracy:  72.4%  test loss:  0.647 test accuracy:  59.9%
# epoch: 88 training loss:  0.592 training accuracy:  71.8%  test loss:  0.578 test accuracy:  68.0%
# epoch: 89 training loss:  0.559 training accuracy:  70.9%  test loss:  0.592 test accuracy:  68.7%
# epoch: 90 training loss:  0.518 training accuracy:  76.9%  test loss:  0.662 test accuracy:  65.3%
# epoch: 91 training loss:  0.577 training accuracy:  74.3%  test loss:  0.660 test accuracy:  65.3%
# epoch: 92 training loss:  0.568 training accuracy:  73.8%  test loss:  0.649 test accuracy:  68.7%
# epoch: 93 training loss:  0.575 training accuracy:  72.3%  test loss:  0.642 test accuracy:  63.9%
# epoch: 94 training loss:  0.594 training accuracy:  72.3%  test loss:  0.619 test accuracy:  68.7%
# epoch: 95 training loss:  0.566 training accuracy:  75.5%  test loss:  0.668 test accuracy:  66.7%
# epoch: 96 training loss:  0.537 training accuracy:  74.1%  test loss:  0.687 test accuracy:  67.3%
# epoch: 97 training loss:  0.552 training accuracy:  75.3%  test loss:  0.635 test accuracy:  66.0%
# epoch: 98 training loss:  0.555 training accuracy:  73.8%  test loss:  0.667 test accuracy:  65.3%
# epoch: 99 training loss:  0.561 training accuracy:  72.3%  test loss:  0.663 test accuracy:  61.9%
# epoch: 100 training loss:  0.528 training accuracy:  73.8%  test loss:  0.614 test accuracy:  63.9%
# epoch: 101 training loss:  0.535 training accuracy:  74.8%  test loss:  0.636 test accuracy:  62.6%
# epoch: 102 training loss:  0.532 training accuracy:  76.2%  test loss:  0.597 test accuracy:  68.0%
# epoch: 103 training loss:  0.524 training accuracy:  76.7%  test loss:  0.600 test accuracy:  66.0%
# epoch: 104 training loss:  0.548 training accuracy:  75.2%  test loss:  0.641 test accuracy:  68.0%
# epoch: 105 training loss:  0.560 training accuracy:  74.7%  test loss:  0.648 test accuracy:  68.0%
# epoch: 106 training loss:  0.539 training accuracy:  72.4%  test loss:  0.629 test accuracy:  66.7%
# epoch: 107 training loss:  0.553 training accuracy:  75.5%  test loss:  0.636 test accuracy:  70.7%
# epoch: 108 training loss:  0.541 training accuracy:  75.7%  test loss:  0.618 test accuracy:  71.4%
# epoch: 109 training loss:  0.542 training accuracy:  75.2%  test loss:  0.626 test accuracy:  72.1%
# epoch: 110 training loss:  0.560 training accuracy:  73.5%  test loss:  0.639 test accuracy:  71.4%
# epoch: 111 training loss:  0.531 training accuracy:  73.6%  test loss:  0.619 test accuracy:  69.4%
# epoch: 112 training loss:  0.520 training accuracy:  75.5%  test loss:  0.644 test accuracy:  66.7%
# epoch: 113 training loss:  0.538 training accuracy:  77.4%  test loss:  0.710 test accuracy:  63.9%
# epoch: 114 training loss:  0.512 training accuracy:  78.4%  test loss:  0.669 test accuracy:  67.3%
# epoch: 115 training loss:  0.514 training accuracy:  76.9%  test loss:  0.667 test accuracy:  64.6%
# epoch: 116 training loss:  0.510 training accuracy:  78.4%  test loss:  0.654 test accuracy:  66.0%
# epoch: 117 training loss:  0.546 training accuracy:  73.3%  test loss:  0.639 test accuracy:  66.7%
# epoch: 118 training loss:  0.531 training accuracy:  73.5%  test loss:  0.629 test accuracy:  65.3%
# epoch: 119 training loss:  0.541 training accuracy:  75.5%  test loss:  0.658 test accuracy:  65.3%
# epoch: 120 training loss:  0.510 training accuracy:  77.6%  test loss:  0.657 test accuracy:  64.6%
# epoch: 121 training loss:  0.539 training accuracy:  74.3%  test loss:  0.622 test accuracy:  63.9%
# epoch: 122 training loss:  0.545 training accuracy:  77.9%  test loss:  0.667 test accuracy:  63.9%
# epoch: 123 training loss:  0.531 training accuracy:  75.3%  test loss:  0.600 test accuracy:  67.3%
# epoch: 124 training loss:  0.514 training accuracy:  77.9%  test loss:  0.660 test accuracy:  65.3%
# epoch: 125 training loss:  0.533 training accuracy:  75.7%  test loss:  0.602 test accuracy:  68.7%
# epoch: 126 training loss:  0.491 training accuracy:  78.7%  test loss:  0.634 test accuracy:  63.9%
# epoch: 127 training loss:  0.523 training accuracy:  75.7%  test loss:  0.642 test accuracy:  62.6%
# epoch: 128 training loss:  0.488 training accuracy:  79.6%  test loss:  0.651 test accuracy:  64.6%
# epoch: 129 training loss:  0.536 training accuracy:  74.3%  test loss:  0.607 test accuracy:  65.3%
# epoch: 130 training loss:  0.493 training accuracy:  75.7%  test loss:  0.635 test accuracy:  68.0%
# epoch: 131 training loss:  0.502 training accuracy:  77.0%  test loss:  0.618 test accuracy:  67.3%
# epoch: 132 training loss:  0.488 training accuracy:  79.4%  test loss:  0.646 test accuracy:  66.7%
# epoch: 133 training loss:  0.523 training accuracy:  76.0%  test loss:  0.650 test accuracy:  68.0%
# epoch: 134 training loss:  0.515 training accuracy:  75.3%  test loss:  0.614 test accuracy:  71.4%
# epoch: 135 training loss:  0.506 training accuracy:  77.0%  test loss:  0.664 test accuracy:  64.6%
# epoch: 136 training loss:  0.488 training accuracy:  75.0%  test loss:  0.648 test accuracy:  65.3%
# epoch: 137 training loss:  0.484 training accuracy:  77.7%  test loss:  0.689 test accuracy:  62.6%
# epoch: 138 training loss:  0.504 training accuracy:  75.9%  test loss:  0.647 test accuracy:  62.6%
# epoch: 139 training loss:  0.501 training accuracy:  76.0%  test loss:  0.609 test accuracy:  66.7%
# epoch: 140 training loss:  0.484 training accuracy:  80.3%  test loss:  0.644 test accuracy:  63.3%
# epoch: 141 training loss:  0.487 training accuracy:  79.4%  test loss:  0.651 test accuracy:  69.4%
# epoch: 142 training loss:  0.537 training accuracy:  76.4%  test loss:  0.588 test accuracy:  67.3%
# epoch: 143 training loss:  0.506 training accuracy:  76.2%  test loss:  0.581 test accuracy:  68.7%
# epoch: 144 training loss:  0.474 training accuracy:  79.3%  test loss:  0.644 test accuracy:  65.3%
# epoch: 145 training loss:  0.483 training accuracy:  78.9%  test loss:  0.619 test accuracy:  64.6%
# epoch: 146 training loss:  0.502 training accuracy:  78.7%  test loss:  0.654 test accuracy:  61.9%
# epoch: 147 training loss:  0.519 training accuracy:  79.4%  test loss:  0.705 test accuracy:  66.0%
# epoch: 148 training loss:  0.465 training accuracy:  80.6%  test loss:  0.742 test accuracy:  62.6%
# epoch: 149 training loss:  0.481 training accuracy:  80.3%  test loss:  0.681 test accuracy:  61.9%
# epoch: 150 training loss:  0.484 training accuracy:  80.3%  test loss:  0.684 test accuracy:  62.6%
# epoch: 151 training loss:  0.513 training accuracy:  78.1%  test loss:  0.684 test accuracy:  66.0%
# epoch: 152 training loss:  0.483 training accuracy:  79.8%  test loss:  0.677 test accuracy:  67.3%
# epoch: 153 training loss:  0.491 training accuracy:  78.7%  test loss:  0.729 test accuracy:  61.2%
# epoch: 154 training loss:  0.470 training accuracy:  80.3%  test loss:  0.670 test accuracy:  67.3%
# epoch: 155 training loss:  0.552 training accuracy:  73.6%  test loss:  0.642 test accuracy:  66.7%
# epoch: 156 training loss:  0.510 training accuracy:  76.9%  test loss:  0.652 test accuracy:  61.2%
# epoch: 157 training loss:  0.488 training accuracy:  78.4%  test loss:  0.673 test accuracy:  64.6%
# epoch: 158 training loss:  0.531 training accuracy:  75.7%  test loss:  0.697 test accuracy:  59.2%
# epoch: 159 training loss:  0.477 training accuracy:  79.9%  test loss:  0.742 test accuracy:  62.6%
# epoch: 160 training loss:  0.462 training accuracy:  80.4%  test loss:  0.777 test accuracy:  61.9%
# epoch: 161 training loss:  0.497 training accuracy:  78.1%  test loss:  0.760 test accuracy:  61.2%
# epoch: 162 training loss:  0.466 training accuracy:  79.8%  test loss:  0.721 test accuracy:  59.9%
# epoch: 163 training loss:  0.512 training accuracy:  75.7%  test loss:  0.674 test accuracy:  62.6%
# epoch: 164 training loss:  0.513 training accuracy:  77.4%  test loss:  0.663 test accuracy:  62.6%
# epoch: 165 training loss:  0.516 training accuracy:  72.4%  test loss:  0.655 test accuracy:  61.9%
# epoch: 166 training loss:  0.502 training accuracy:  77.6%  test loss:  0.695 test accuracy:  65.3%
# epoch: 167 training loss:  0.491 training accuracy:  77.7%  test loss:  0.692 test accuracy:  61.2%
# epoch: 168 training loss:  0.507 training accuracy:  75.7%  test loss:  0.688 test accuracy:  60.5%
# epoch: 169 training loss:  0.482 training accuracy:  77.0%  test loss:  0.707 test accuracy:  63.9%
# epoch: 170 training loss:  0.459 training accuracy:  79.4%  test loss:  0.709 test accuracy:  61.9%
# epoch: 171 training loss:  0.498 training accuracy:  77.9%  test loss:  0.682 test accuracy:  61.9%
# epoch: 172 training loss:  0.452 training accuracy:  80.8%  test loss:  0.701 test accuracy:  61.9%
# epoch: 173 training loss:  0.519 training accuracy:  78.4%  test loss:  0.723 test accuracy:  60.5%
# epoch: 174 training loss:  0.467 training accuracy:  79.6%  test loss:  0.721 test accuracy:  59.9%
# epoch: 175 training loss:  0.493 training accuracy:  77.7%  test loss:  0.715 test accuracy:  63.3%
# epoch: 176 training loss:  0.458 training accuracy:  80.8%  test loss:  0.730 test accuracy:  66.7%
# epoch: 177 training loss:  0.481 training accuracy:  80.6%  test loss:  0.778 test accuracy:  63.3%
# epoch: 178 training loss:  0.448 training accuracy:  78.4%  test loss:  0.732 test accuracy:  63.3%
# epoch: 179 training loss:  0.497 training accuracy:  81.0%  test loss:  0.754 test accuracy:  60.5%
# epoch: 180 training loss:  0.438 training accuracy:  82.0%  test loss:  0.738 test accuracy:  59.9%
# epoch: 181 training loss:  0.465 training accuracy:  79.8%  test loss:  0.738 test accuracy:  63.9%
# epoch: 182 training loss:  0.440 training accuracy:  80.8%  test loss:  0.681 test accuracy:  63.3%
# epoch: 183 training loss:  0.485 training accuracy:  78.1%  test loss:  0.694 test accuracy:  63.9%
# epoch: 184 training loss:  0.487 training accuracy:  79.8%  test loss:  0.727 test accuracy:  66.7%
# epoch: 185 training loss:  0.447 training accuracy:  81.1%  test loss:  0.733 test accuracy:  62.6%
# epoch: 186 training loss:  0.475 training accuracy:  80.1%  test loss:  0.692 test accuracy:  66.7%
# epoch: 187 training loss:  0.475 training accuracy:  79.9%  test loss:  0.738 test accuracy:  63.3%
# epoch: 188 training loss:  0.473 training accuracy:  79.9%  test loss:  0.684 test accuracy:  66.7%
# epoch: 189 training loss:  0.492 training accuracy:  80.4%  test loss:  0.685 test accuracy:  65.3%
# epoch: 190 training loss:  0.454 training accuracy:  79.4%  test loss:  0.754 test accuracy:  61.9%
# epoch: 191 training loss:  0.484 training accuracy:  80.1%  test loss:  0.655 test accuracy:  63.9%
# epoch: 192 training loss:  0.467 training accuracy:  79.6%  test loss:  0.689 test accuracy:  63.3%
# epoch: 193 training loss:  0.475 training accuracy:  81.3%  test loss:  0.692 test accuracy:  64.6%
# epoch: 194 training loss:  0.465 training accuracy:  82.3%  test loss:  0.627 test accuracy:  66.0%
# epoch: 195 training loss:  0.467 training accuracy:  82.3%  test loss:  0.680 test accuracy:  68.7%
# epoch: 196 training loss:  0.438 training accuracy:  82.1%  test loss:  0.812 test accuracy:  63.3%
# epoch: 197 training loss:  0.471 training accuracy:  81.3%  test loss:  0.730 test accuracy:  63.3%
# epoch: 198 training loss:  0.494 training accuracy:  79.3%  test loss:  0.688 test accuracy:  63.3%
# epoch: 199 training loss:  0.467 training accuracy:  79.4%  test loss:  0.686 test accuracy:  66.7%
# PointNet(
#   (transform): Transform(
#     (input_transform): Tnet(
#       (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=9, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (feature_transform): Tnet(
#       (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#       (fc1): Linear(in_features=1024, out_features=512, bias=True)
#       (fc2): Linear(in_features=512, out_features=256, bias=True)
#       (fc3): Linear(in_features=256, out_features=4096, bias=True)
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=3, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=64, bias=True)
#     (fc4): Linear(in_features=64, out_features=128, bias=True)
#     (fc5): Linear(in_features=128, out_features=1024, bias=True)
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=2, bias=True)
#   (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (logsoftmax): LogSoftmax(dim=1)
#   (loss_fn): CrossEntropyLoss()
# )

# %%
def show_graph(path,device):
    data = torch.load(path, map_location=device) # by doing map_location=device, you can use trained model on GPU --> to test on CPU
    statsrec = data["stats"]
    fig, ax1 = plt.subplots()
    plt.plot(statsrec[0], 'r', label = 'training loss', )
    plt.plot(statsrec[2], 'g', label = 'test loss' )
    plt.legend(loc='lower right')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training and test loss, and test accuracy')
    ax2=ax1.twinx()
    ax2.plot(statsrec[1], 'm', label = 'training accuracy')
    ax2.plot(statsrec[3], 'b', label = 'test accuracy')
    ax2.set_ylabel('accuracy')
    plt.legend(loc='upper right')
    fig.savefig("roc.svg")
    plt.show()

# %%
device = torch.device('cuda:0')
show_graph(path ="./result/3multibranch_test.pt",device = "cuda")

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import functions as fun
pointnet_copy = PointNet(classes=2)
model_path = "./pointnet_2000pt.pth"
load_model(pointnet_copy,model_path)

y_true = []
y_pred = []
y_pred_result = []
y_probs = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,_,_,labels in valid_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) 
        y_probs.extend(outputs)

from pointnetfunct.evaluation import show_cm_dl,show_graph,print_values,draw_rocgraph

draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_2branch_AOC", interval=0.04)
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_2branch_CM")
print_values (y_true, y_pred_result)

# %% [markdown]
# Multi head

# %% [markdown]
# 3multihead

# %%
import functions
pointnet_mh = PointNet_3Multihead(classes=2)
run_model_3multi_head_dnn(train_loader_input = train_loader,
                        vaild_loader_input = valid_loader,
                        nepochs = 100, 
                        modelnet = pointnet_mh,
                        results_path = "./result", 
                        filename = "/3multibranch_test.pt"
                        model_name="pointnet_3branch_modal_2000pt.pth")
# Out:
# epoch: 0 training loss:  0.687 training accuracy:  65.6%  test loss:  0.670 test accuracy:  64.6%
# epoch: 1 training loss:  0.660 training accuracy:  68.4%  test loss:  0.597 test accuracy:  71.4%
# epoch: 2 training loss:  0.641 training accuracy:  68.4%  test loss:  0.647 test accuracy:  68.0%
# epoch: 3 training loss:  0.638 training accuracy:  66.8%  test loss:  0.586 test accuracy:  67.3%
# epoch: 4 training loss:  0.638 training accuracy:  67.2%  test loss:  0.601 test accuracy:  68.7%
# epoch: 5 training loss:  0.644 training accuracy:  66.7%  test loss:  0.565 test accuracy:  72.8%
# epoch: 6 training loss:  0.604 training accuracy:  69.6%  test loss:  0.599 test accuracy:  69.4%
# epoch: 7 training loss:  0.611 training accuracy:  68.5%  test loss:  0.567 test accuracy:  69.4%
# epoch: 8 training loss:  0.582 training accuracy:  71.1%  test loss:  0.527 test accuracy:  75.5%
# epoch: 9 training loss:  0.612 training accuracy:  70.9%  test loss:  0.586 test accuracy:  70.7%
# epoch: 10 training loss:  0.589 training accuracy:  72.4%  test loss:  0.557 test accuracy:  70.7%
# epoch: 11 training loss:  0.607 training accuracy:  69.4%  test loss:  0.569 test accuracy:  72.8%
# epoch: 12 training loss:  0.586 training accuracy:  72.6%  test loss:  0.594 test accuracy:  68.7%
# epoch: 13 training loss:  0.600 training accuracy:  67.3%  test loss:  0.555 test accuracy:  71.4%
# epoch: 14 training loss:  0.601 training accuracy:  71.6%  test loss:  0.563 test accuracy:  69.4%
# epoch: 15 training loss:  0.601 training accuracy:  71.8%  test loss:  0.588 test accuracy:  70.7%
# epoch: 16 training loss:  0.579 training accuracy:  71.4%  test loss:  0.565 test accuracy:  72.8%
# epoch: 17 training loss:  0.583 training accuracy:  71.8%  test loss:  0.536 test accuracy:  72.8%
# epoch: 18 training loss:  0.591 training accuracy:  73.1%  test loss:  0.577 test accuracy:  69.4%
# epoch: 19 training loss:  0.574 training accuracy:  72.3%  test loss:  0.529 test accuracy:  72.8%
# epoch: 20 training loss:  0.581 training accuracy:  73.1%  test loss:  0.536 test accuracy:  72.8%
# epoch: 21 training loss:  0.578 training accuracy:  73.5%  test loss:  0.540 test accuracy:  70.7%
# epoch: 22 training loss:  0.569 training accuracy:  71.4%  test loss:  0.538 test accuracy:  74.8%
# epoch: 23 training loss:  0.585 training accuracy:  74.1%  test loss:  0.535 test accuracy:  71.4%
# epoch: 24 training loss:  0.569 training accuracy:  73.6%  test loss:  0.575 test accuracy:  70.1%
# epoch: 25 training loss:  0.574 training accuracy:  72.3%  test loss:  0.545 test accuracy:  73.5%
# epoch: 26 training loss:  0.563 training accuracy:  71.1%  test loss:  0.548 test accuracy:  74.1%
# epoch: 27 training loss:  0.574 training accuracy:  73.3%  test loss:  0.574 test accuracy:  72.8%
# epoch: 28 training loss:  0.548 training accuracy:  73.6%  test loss:  0.574 test accuracy:  70.7%
# epoch: 29 training loss:  0.554 training accuracy:  74.5%  test loss:  0.558 test accuracy:  72.1%
# epoch: 30 training loss:  0.564 training accuracy:  71.3%  test loss:  0.621 test accuracy:  66.0%
# epoch: 31 training loss:  0.559 training accuracy:  71.8%  test loss:  0.539 test accuracy:  76.2%
# epoch: 32 training loss:  0.573 training accuracy:  71.8%  test loss:  0.559 test accuracy:  72.1%
# epoch: 33 training loss:  0.568 training accuracy:  72.6%  test loss:  0.544 test accuracy:  71.4%
# epoch: 34 training loss:  0.559 training accuracy:  74.3%  test loss:  0.544 test accuracy:  70.1%
# epoch: 35 training loss:  0.550 training accuracy:  74.5%  test loss:  0.545 test accuracy:  70.1%
# epoch: 36 training loss:  0.565 training accuracy:  73.5%  test loss:  0.569 test accuracy:  68.7%
# epoch: 37 training loss:  0.561 training accuracy:  74.7%  test loss:  0.595 test accuracy:  67.3%
# epoch: 38 training loss:  0.563 training accuracy:  71.6%  test loss:  0.553 test accuracy:  69.4%
# epoch: 39 training loss:  0.570 training accuracy:  72.1%  test loss:  0.552 test accuracy:  71.4%
# epoch: 40 training loss:  0.556 training accuracy:  73.8%  test loss:  0.576 test accuracy:  70.7%
# epoch: 41 training loss:  0.539 training accuracy:  74.0%  test loss:  0.550 test accuracy:  70.7%
# epoch: 42 training loss:  0.542 training accuracy:  73.1%  test loss:  0.572 test accuracy:  70.7%
# epoch: 43 training loss:  0.560 training accuracy:  72.3%  test loss:  0.535 test accuracy:  69.4%
# epoch: 44 training loss:  0.558 training accuracy:  74.5%  test loss:  0.535 test accuracy:  74.8%
# epoch: 45 training loss:  0.568 training accuracy:  72.8%  test loss:  0.556 test accuracy:  72.1%
# epoch: 46 training loss:  0.545 training accuracy:  73.1%  test loss:  0.547 test accuracy:  71.4%
# epoch: 47 training loss:  0.543 training accuracy:  72.6%  test loss:  0.600 test accuracy:  68.7%
# epoch: 48 training loss:  0.524 training accuracy:  74.7%  test loss:  0.587 test accuracy:  71.4%
# epoch: 49 training loss:  0.537 training accuracy:  73.8%  test loss:  0.510 test accuracy:  74.1%
# epoch: 50 training loss:  0.560 training accuracy:  73.6%  test loss:  0.543 test accuracy:  70.7%
# epoch: 51 training loss:  0.559 training accuracy:  72.6%  test loss:  0.567 test accuracy:  68.7%
# epoch: 52 training loss:  0.523 training accuracy:  76.9%  test loss:  0.549 test accuracy:  70.7%
# epoch: 53 training loss:  0.553 training accuracy:  72.4%  test loss:  0.530 test accuracy:  74.8%
# epoch: 54 training loss:  0.537 training accuracy:  73.8%  test loss:  0.540 test accuracy:  75.5%
# epoch: 55 training loss:  0.524 training accuracy:  73.6%  test loss:  0.551 test accuracy:  73.5%
# epoch: 56 training loss:  0.525 training accuracy:  76.4%  test loss:  0.515 test accuracy:  73.5%
# epoch: 57 training loss:  0.532 training accuracy:  75.0%  test loss:  0.584 test accuracy:  72.1%
# epoch: 58 training loss:  0.526 training accuracy:  75.7%  test loss:  0.555 test accuracy:  72.1%
# epoch: 59 training loss:  0.526 training accuracy:  75.5%  test loss:  0.543 test accuracy:  77.6%
# epoch: 60 training loss:  0.527 training accuracy:  75.7%  test loss:  0.554 test accuracy:  72.8%
# epoch: 61 training loss:  0.517 training accuracy:  75.3%  test loss:  0.557 test accuracy:  71.4%
# epoch: 62 training loss:  0.527 training accuracy:  76.7%  test loss:  0.569 test accuracy:  71.4%
# epoch: 63 training loss:  0.553 training accuracy:  73.6%  test loss:  0.535 test accuracy:  70.7%
# epoch: 64 training loss:  0.521 training accuracy:  76.0%  test loss:  0.569 test accuracy:  72.8%
# epoch: 65 training loss:  0.535 training accuracy:  74.8%  test loss:  0.535 test accuracy:  74.1%
# epoch: 66 training loss:  0.545 training accuracy:  74.0%  test loss:  0.503 test accuracy:  74.8%
# epoch: 67 training loss:  0.508 training accuracy:  77.6%  test loss:  0.509 test accuracy:  74.8%
# epoch: 68 training loss:  0.523 training accuracy:  74.8%  test loss:  0.522 test accuracy:  75.5%
# epoch: 69 training loss:  0.521 training accuracy:  75.7%  test loss:  0.533 test accuracy:  75.5%
# epoch: 70 training loss:  0.537 training accuracy:  73.5%  test loss:  0.500 test accuracy:  72.1%
# epoch: 71 training loss:  0.546 training accuracy:  75.0%  test loss:  0.516 test accuracy:  73.5%
# epoch: 72 training loss:  0.483 training accuracy:  77.9%  test loss:  0.530 test accuracy:  70.1%
# epoch: 73 training loss:  0.503 training accuracy:  78.4%  test loss:  0.539 test accuracy:  72.8%
# epoch: 74 training loss:  0.509 training accuracy:  77.0%  test loss:  0.544 test accuracy:  71.4%
# epoch: 75 training loss:  0.501 training accuracy:  78.2%  test loss:  0.556 test accuracy:  68.7%
# epoch: 76 training loss:  0.534 training accuracy:  75.5%  test loss:  0.561 test accuracy:  73.5%
# epoch: 77 training loss:  0.533 training accuracy:  78.4%  test loss:  0.511 test accuracy:  74.8%
# epoch: 78 training loss:  0.515 training accuracy:  76.5%  test loss:  0.543 test accuracy:  75.5%
# epoch: 79 training loss:  0.514 training accuracy:  75.7%  test loss:  0.513 test accuracy:  76.2%
# epoch: 80 training loss:  0.483 training accuracy:  78.7%  test loss:  0.569 test accuracy:  68.7%
# epoch: 81 training loss:  0.485 training accuracy:  78.1%  test loss:  0.534 test accuracy:  73.5%
# epoch: 82 training loss:  0.483 training accuracy:  80.6%  test loss:  0.502 test accuracy:  74.8%
# epoch: 83 training loss:  0.484 training accuracy:  79.8%  test loss:  0.536 test accuracy:  71.4%
# epoch: 84 training loss:  0.499 training accuracy:  79.3%  test loss:  0.551 test accuracy:  72.8%
# epoch: 85 training loss:  0.509 training accuracy:  75.9%  test loss:  0.569 test accuracy:  73.5%
# epoch: 86 training loss:  0.516 training accuracy:  76.7%  test loss:  0.572 test accuracy:  71.4%
# epoch: 87 training loss:  0.506 training accuracy:  76.9%  test loss:  0.538 test accuracy:  67.3%
# epoch: 88 training loss:  0.490 training accuracy:  81.5%  test loss:  0.547 test accuracy:  71.4%
# epoch: 89 training loss:  0.519 training accuracy:  75.7%  test loss:  0.556 test accuracy:  70.7%
# epoch: 90 training loss:  0.482 training accuracy:  78.2%  test loss:  0.564 test accuracy:  69.4%
# epoch: 91 training loss:  0.485 training accuracy:  80.1%  test loss:  0.553 test accuracy:  72.8%
# epoch: 92 training loss:  0.479 training accuracy:  78.7%  test loss:  0.553 test accuracy:  73.5%
# epoch: 93 training loss:  0.476 training accuracy:  80.3%  test loss:  0.540 test accuracy:  73.5%
# epoch: 94 training loss:  0.471 training accuracy:  79.4%  test loss:  0.553 test accuracy:  71.4%
# epoch: 95 training loss:  0.508 training accuracy:  78.2%  test loss:  0.549 test accuracy:  69.4%
# epoch: 96 training loss:  0.493 training accuracy:  78.2%  test loss:  0.566 test accuracy:  74.1%
# epoch: 97 training loss:  0.511 training accuracy:  78.2%  test loss:  0.571 test accuracy:  70.1%
# epoch: 98 training loss:  0.507 training accuracy:  75.9%  test loss:  0.539 test accuracy:  70.7%
# epoch: 99 training loss:  0.480 training accuracy:  78.4%  test loss:  0.598 test accuracy:  69.4%
# epoch: 100 training loss:  0.459 training accuracy:  78.9%  test loss:  0.605 test accuracy:  69.4%
# epoch: 101 training loss:  0.454 training accuracy:  82.5%  test loss:  0.563 test accuracy:  69.4%
# epoch: 102 training loss:  0.458 training accuracy:  78.1%  test loss:  0.541 test accuracy:  70.1%
# epoch: 103 training loss:  0.470 training accuracy:  80.4%  test loss:  0.599 test accuracy:  64.6%
# epoch: 104 training loss:  0.446 training accuracy:  81.1%  test loss:  0.549 test accuracy:  67.3%
# epoch: 105 training loss:  0.516 training accuracy:  78.6%  test loss:  0.578 test accuracy:  68.7%
# epoch: 106 training loss:  0.448 training accuracy:  80.4%  test loss:  0.589 test accuracy:  64.6%
# epoch: 107 training loss:  0.465 training accuracy:  80.8%  test loss:  0.567 test accuracy:  68.7%
# epoch: 108 training loss:  0.489 training accuracy:  79.6%  test loss:  0.543 test accuracy:  72.1%
# epoch: 109 training loss:  0.443 training accuracy:  82.0%  test loss:  0.615 test accuracy:  68.0%
# epoch: 110 training loss:  0.484 training accuracy:  79.4%  test loss:  0.575 test accuracy:  67.3%
# epoch: 111 training loss:  0.453 training accuracy:  80.3%  test loss:  0.632 test accuracy:  65.3%
# epoch: 112 training loss:  0.481 training accuracy:  79.8%  test loss:  0.545 test accuracy:  72.1%
# epoch: 113 training loss:  0.475 training accuracy:  78.1%  test loss:  0.606 test accuracy:  73.5%
# epoch: 114 training loss:  0.468 training accuracy:  80.1%  test loss:  0.585 test accuracy:  72.1%
# epoch: 115 training loss:  0.475 training accuracy:  80.6%  test loss:  0.595 test accuracy:  69.4%
# epoch: 116 training loss:  0.436 training accuracy:  79.6%  test loss:  0.625 test accuracy:  70.1%
# epoch: 117 training loss:  0.434 training accuracy:  82.0%  test loss:  0.597 test accuracy:  71.4%
# epoch: 118 training loss:  0.437 training accuracy:  79.9%  test loss:  0.601 test accuracy:  68.0%
# epoch: 119 training loss:  0.470 training accuracy:  80.3%  test loss:  0.631 test accuracy:  69.4%
# epoch: 120 training loss:  0.442 training accuracy:  81.6%  test loss:  0.592 test accuracy:  71.4%
# epoch: 121 training loss:  0.460 training accuracy:  79.8%  test loss:  0.607 test accuracy:  72.1%
# epoch: 122 training loss:  0.483 training accuracy:  80.8%  test loss:  0.571 test accuracy:  69.4%
# epoch: 123 training loss:  0.456 training accuracy:  80.6%  test loss:  0.648 test accuracy:  67.3%
# epoch: 124 training loss:  0.453 training accuracy:  82.0%  test loss:  0.551 test accuracy:  72.1%
# epoch: 125 training loss:  0.457 training accuracy:  81.0%  test loss:  0.607 test accuracy:  71.4%
# epoch: 126 training loss:  0.459 training accuracy:  81.5%  test loss:  0.608 test accuracy:  69.4%
# epoch: 127 training loss:  0.502 training accuracy:  79.4%  test loss:  0.521 test accuracy:  74.8%
# epoch: 128 training loss:  0.449 training accuracy:  80.6%  test loss:  0.556 test accuracy:  70.7%
# epoch: 129 training loss:  0.453 training accuracy:  80.1%  test loss:  0.556 test accuracy:  72.1%
# epoch: 130 training loss:  0.427 training accuracy:  82.3%  test loss:  0.595 test accuracy:  74.1%
# epoch: 131 training loss:  0.458 training accuracy:  81.8%  test loss:  0.606 test accuracy:  73.5%
# epoch: 132 training loss:  0.441 training accuracy:  82.0%  test loss:  0.565 test accuracy:  69.4%
# epoch: 133 training loss:  0.425 training accuracy:  82.7%  test loss:  0.557 test accuracy:  73.5%
# epoch: 134 training loss:  0.427 training accuracy:  82.1%  test loss:  0.674 test accuracy:  65.3%
# epoch: 135 training loss:  0.410 training accuracy:  82.3%  test loss:  0.622 test accuracy:  69.4%
# epoch: 136 training loss:  0.435 training accuracy:  82.0%  test loss:  0.598 test accuracy:  72.1%
# epoch: 137 training loss:  0.396 training accuracy:  85.2%  test loss:  0.626 test accuracy:  70.1%
# epoch: 138 training loss:  0.470 training accuracy:  77.9%  test loss:  0.584 test accuracy:  72.8%
# epoch: 139 training loss:  0.454 training accuracy:  82.3%  test loss:  0.565 test accuracy:  71.4%
# epoch: 140 training loss:  0.470 training accuracy:  78.2%  test loss:  0.551 test accuracy:  70.1%
# epoch: 141 training loss:  0.424 training accuracy:  82.3%  test loss:  0.603 test accuracy:  67.3%
# epoch: 142 training loss:  0.448 training accuracy:  79.9%  test loss:  0.588 test accuracy:  71.4%
# epoch: 143 training loss:  0.481 training accuracy:  80.3%  test loss:  0.558 test accuracy:  74.1%
# epoch: 144 training loss:  0.418 training accuracy:  83.2%  test loss:  0.605 test accuracy:  71.4%
# epoch: 145 training loss:  0.429 training accuracy:  82.3%  test loss:  0.661 test accuracy:  68.7%
# epoch: 146 training loss:  0.448 training accuracy:  79.8%  test loss:  0.585 test accuracy:  68.0%
# epoch: 147 training loss:  0.434 training accuracy:  79.4%  test loss:  0.608 test accuracy:  68.0%
# epoch: 148 training loss:  0.437 training accuracy:  83.2%  test loss:  0.594 test accuracy:  68.0%
# epoch: 149 training loss:  0.434 training accuracy:  83.8%  test loss:  0.539 test accuracy:  75.5%
# epoch: 150 training loss:  0.480 training accuracy:  81.8%  test loss:  0.581 test accuracy:  69.4%
# epoch: 151 training loss:  0.427 training accuracy:  83.7%  test loss:  0.609 test accuracy:  68.7%
# epoch: 152 training loss:  0.469 training accuracy:  81.3%  test loss:  0.573 test accuracy:  73.5%
# epoch: 153 training loss:  0.408 training accuracy:  82.0%  test loss:  0.649 test accuracy:  68.7%
# epoch: 154 training loss:  0.399 training accuracy:  84.5%  test loss:  0.682 test accuracy:  69.4%
# epoch: 155 training loss:  0.425 training accuracy:  82.8%  test loss:  0.643 test accuracy:  66.7%
# epoch: 156 training loss:  0.425 training accuracy:  83.2%  test loss:  0.636 test accuracy:  69.4%
# epoch: 157 training loss:  0.456 training accuracy:  80.3%  test loss:  0.658 test accuracy:  68.7%
# epoch: 158 training loss:  0.431 training accuracy:  81.8%  test loss:  0.617 test accuracy:  68.0%
# epoch: 159 training loss:  0.400 training accuracy:  83.7%  test loss:  0.615 test accuracy:  70.7%
# epoch: 160 training loss:  0.398 training accuracy:  84.9%  test loss:  0.634 test accuracy:  69.4%
# epoch: 161 training loss:  0.421 training accuracy:  83.0%  test loss:  0.702 test accuracy:  68.7%
# epoch: 162 training loss:  0.416 training accuracy:  83.0%  test loss:  0.570 test accuracy:  73.5%
# epoch: 163 training loss:  0.431 training accuracy:  83.5%  test loss:  0.534 test accuracy:  72.8%
# epoch: 164 training loss:  0.394 training accuracy:  83.0%  test loss:  0.568 test accuracy:  72.8%
# epoch: 165 training loss:  0.389 training accuracy:  85.2%  test loss:  0.641 test accuracy:  71.4%
# epoch: 166 training loss:  0.388 training accuracy:  84.4%  test loss:  0.688 test accuracy:  68.0%
# epoch: 167 training loss:  0.401 training accuracy:  84.4%  test loss:  0.653 test accuracy:  72.8%
# epoch: 168 training loss:  0.369 training accuracy:  84.5%  test loss:  0.659 test accuracy:  71.4%
# epoch: 169 training loss:  0.428 training accuracy:  84.0%  test loss:  0.624 test accuracy:  70.1%
# epoch: 170 training loss:  0.398 training accuracy:  82.1%  test loss:  0.648 test accuracy:  67.3%
# epoch: 171 training loss:  0.389 training accuracy:  86.4%  test loss:  0.785 test accuracy:  64.6%
# epoch: 172 training loss:  0.401 training accuracy:  86.2%  test loss:  0.670 test accuracy:  66.0%
# epoch: 173 training loss:  0.436 training accuracy:  83.7%  test loss:  0.607 test accuracy:  72.1%
# epoch: 174 training loss:  0.433 training accuracy:  80.6%  test loss:  0.645 test accuracy:  65.3%
# epoch: 175 training loss:  0.418 training accuracy:  83.2%  test loss:  0.693 test accuracy:  67.3%
# epoch: 176 training loss:  0.374 training accuracy:  85.7%  test loss:  0.721 test accuracy:  63.9%
# epoch: 177 training loss:  0.395 training accuracy:  84.9%  test loss:  0.758 test accuracy:  66.7%
# epoch: 178 training loss:  0.432 training accuracy:  82.1%  test loss:  0.670 test accuracy:  66.7%
# epoch: 179 training loss:  0.414 training accuracy:  82.3%  test loss:  0.605 test accuracy:  70.7%
# epoch: 180 training loss:  0.456 training accuracy:  79.1%  test loss:  0.582 test accuracy:  72.1%
# epoch: 181 training loss:  0.404 training accuracy:  83.3%  test loss:  0.723 test accuracy:  66.7%
# epoch: 182 training loss:  0.401 training accuracy:  84.4%  test loss:  0.672 test accuracy:  67.3%
# epoch: 183 training loss:  0.447 training accuracy:  83.0%  test loss:  0.690 test accuracy:  67.3%
# epoch: 184 training loss:  0.412 training accuracy:  83.5%  test loss:  0.649 test accuracy:  66.7%
# epoch: 185 training loss:  0.410 training accuracy:  82.8%  test loss:  0.698 test accuracy:  67.3%
# epoch: 186 training loss:  0.377 training accuracy:  86.2%  test loss:  0.678 test accuracy:  68.7%
# epoch: 187 training loss:  0.455 training accuracy:  80.6%  test loss:  0.711 test accuracy:  66.0%
# epoch: 188 training loss:  0.399 training accuracy:  82.5%  test loss:  0.699 test accuracy:  66.7%
# epoch: 189 training loss:  0.413 training accuracy:  84.2%  test loss:  0.702 test accuracy:  66.7%
# epoch: 190 training loss:  0.415 training accuracy:  84.2%  test loss:  0.751 test accuracy:  66.0%
# epoch: 191 training loss:  0.399 training accuracy:  83.3%  test loss:  0.678 test accuracy:  68.0%
# epoch: 192 training loss:  0.401 training accuracy:  84.0%  test loss:  0.650 test accuracy:  72.8%
# epoch: 193 training loss:  0.407 training accuracy:  82.0%  test loss:  0.610 test accuracy:  68.7%
# epoch: 194 training loss:  0.375 training accuracy:  86.4%  test loss:  0.719 test accuracy:  66.0%
# epoch: 195 training loss:  0.377 training accuracy:  85.5%  test loss:  0.668 test accuracy:  67.3%
# epoch: 196 training loss:  0.375 training accuracy:  85.2%  test loss:  0.699 test accuracy:  70.1%
# epoch: 197 training loss:  0.360 training accuracy:  85.7%  test loss:  0.748 test accuracy:  70.1%
# epoch: 198 training loss:  0.368 training accuracy:  87.4%  test loss:  0.785 test accuracy:  70.1%
# epoch: 199 training loss:  0.405 training accuracy:  84.4%  test loss:  0.721 test accuracy:  68.0%

# %%
device = torch.device('cuda:0')
show_graph(path ="./result/3multibranch_test.pt",device = "cuda")

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import functions as fun
pointnet_copy = PointNet(classes=2)
model_path = "./pointnet_3branch_modal_2000pt.pth"
load_model(pointnet_copy,model_path)

y_true = []
y_pred = []
y_pred_result = []
y_probs = []
pointnet_copy = pointnet_copy.to("cpu")
with torch.no_grad():
    for inputs_v,_,_,labels in valid_loader:
        inputs_v = inputs_v.to(torch.float32)
        inputs_v = inputs_v.squeeze(1).permute(0, 2, 1)
        labels = labels.to(torch.long)
        outputs = pointnet_copy.forward(inputs_v)
        
        #print(torch.exp(outputs))

        outputs_value = (torch.max(torch.exp(outputs), 1)[0]).data.cpu().numpy()
        outputs_result = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
        
        
        #print(outputs)
        y_pred.extend(outputs_value)
        y_pred_result.extend(outputs_result)
            
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) 
        y_probs.extend(outputs)

from pointnetfunct.evaluation import show_cm_dl,show_graph,print_values,draw_rocgraph

draw_rocgraph(y_pred_result,y_true, y_probs, name="1000pt_2branch_AOC", interval=0.04)
show_cm_dl(y_true, y_pred,y_pred_result,name="1000pt_2branch_CM")
print_values (y_true, y_pred_result)
